# %% [markdown]
# # Index

# %% [markdown]
# ## A - E

# %% [markdown]
# ### A
#
# * A Probabilistic Analysis of the Efficiency of Automated Software Testing &mdash; [Greybox Fuzzing (Background)](GreyboxFuzzer.ipynb#Background)
# * a solution &mdash; [Concolic Fuzzing (Solving Constraints)](ConcolicFuzzer.ipynb#Solving-Constraints)
# * `A()` &mdash; [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `A1_GRAMMAR` &mdash; [Parsing Inputs (Excursion: Grammars and Derivation Trees)](Parser.ipynb#Excursion:-Grammars-and-Derivation-Trees), [Parsing Inputs (Recursion)](Parser.ipynb#Recursion), [Parsing Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Exercise 8: First Set of a Nonterminal)](Parser.ipynb#Exercise-8:-First-Set-of-a-Nonterminal), [Parsing Inputs (Exercise 9: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-9:-Follow-Set-of-a-Nonterminal)
# * `A2_GRAMMAR` &mdash; [Parsing Inputs (Excursion: Grammars and Derivation Trees)](Parser.ipynb#Excursion:-Grammars-and-Derivation-Trees), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `A3_GRAMMAR` &mdash; [Parsing Inputs (Ambiguous Parsing)](Parser.ipynb#Ambiguous-Parsing)
# * Abstract Syntax Tree &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * `abs_max()` &mdash; [Concolic Fuzzing (Example: Absolute Maximum)](ConcolicFuzzer.ipynb#Example:-Absolute-Maximum), [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `abs_value()` &mdash; [Concolic Fuzzing (Example: Absolute Maximum)](ConcolicFuzzer.ipynb#Example:-Absolute-Maximum), [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * actions &mdash; [Testing Graphical User Interfaces (Retrieving User Interface Actions)](GUIFuzzer.ipynb#Retrieving-User-Interface-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Retrieving Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Retrieving-Actions)
# * `ACTIONS` &mdash; [Testing Graphical User Interfaces (Exploring Large Sites)](GUIFuzzer.ipynb#Exploring-Large-Sites), [Testing Graphical User Interfaces (Exploring Large Sites)](GUIFuzzer.ipynb#Exploring-Large-Sites), [Testing Graphical User Interfaces (Exploring Large Sites)](GUIFuzzer.ipynb#Exploring-Large-Sites)
# * `add()` &mdash; [Parsing Inputs (Columns)](Parser.ipynb#Columns)
# * add-operator &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation)
# * `addDebug()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `addTo()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `add_call()` &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `add_calls()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `add_child()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `add_coverage()` &mdash; [Grammar Coverage (Tracking Expansions while Fuzzing)](GrammarCoverageFuzzer.ipynb#Tracking-Expansions-while-Fuzzing), [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions)
# * `add_element()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `add_fragment()` &mdash; [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool)
# * `add_group()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_int_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_metavar_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_new_airport()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `add_new_airport_2()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `add_parameter()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_parent()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `add_parents()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `add_result()` &mdash; [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results)
# * `add_str_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_to_fragment_pool()` &mdash; [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool), [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation)
# * `add_trace()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class)
# * `add_transitive()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `add_tree()` &mdash; [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions), [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees)
# * `add_tree_coverage()` &mdash; [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage)
# * `add_type_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `__add__()` &mdash; [Tracking Information Flow (Concatenation)](InformationFlow.ipynb#Concatenation), [Concolic Fuzzing (Concatenation of Strings)](ConcolicFuzzer.ipynb#Concatenation-of-Strings)
# * `advance()` &mdash; [Parsing Inputs (Items)](Parser.ipynb#Items), [Parsing Inputs (States)](Parser.ipynb#States)
# * `AdvancedMutationFuzzer` class &mdash; [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing)
# * `AdvMutant` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `AdvMutator` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `AdvPMIterator` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `AdvStmtDeletionMutator` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * AFL &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Greybox Fuzzing (Greybox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Greybox-Mutation-based-Fuzzing)
# * `AFLFastSchedule` class &mdash; [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing)
# * `AFLGoSchedule` class &mdash; [Greybox Fuzzing (Improved Directed Power Schedule)](GreyboxFuzzer.ipynb#Improved-Directed-Power-Schedule)
# * AFLSmart &mdash; [Greybox Fuzzing with Grammars (Fuzzing with Input Regions)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Input-Regions), [Greybox Fuzzing with Grammars (Background)](GreyboxGrammarFuzzer.ipynb#Background)
# * `AFLSmartSchedule` class &mdash; [Greybox Fuzzing with Grammars (Focusing on Valid Seeds)](GreyboxGrammarFuzzer.ipynb#Focusing-on-Valid-Seeds)
# * `airport_codes_repOK()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * Alex framework &mdash; [Testing Graphical User Interfaces (Background)](GUIFuzzer.ipynb#Background)
# * all &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example), [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults), [Greybox Fuzzing with Grammars (Lessons Learned)](GreyboxGrammarFuzzer.ipynb#Lessons-Learned), [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer), [When To Stop Fuzzing (Discovery Probability Quantifies Residual Risk)](WhenToStopFuzzing.ipynb#Discovery-Probability-Quantifies-Residual-Risk)
# * all paths &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * all seeds &mdash; [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing)
# * `all_terminals()` &mdash; [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion)
# * `alternate_reductions()` &mdash; [Reducing Failure-Inducing Inputs (Alternate Expansions)](Reducer.ipynb#Alternate-Expansions)
# * `AlternatingSequence` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * alternatives &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * American fuzzy lop &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * American Fuzzy Lop &mdash; [Greybox Fuzzing (AFL: An Effective Greybox Fuzzer)](GreyboxFuzzer.ipynb#AFL:-An-Effective-Greybox-Fuzzer)
# * American Fuzzy Lop](http://lcamtuf.coredump.cx/afl/) (AFL) was released. Since then, AFL has become one of the most successful fuzzing tools and comes in many flavors, e.g., [AFLFast](https://github.com/mboehme/aflfast), [AFLGo](https://github.com/aflgo/aflgo), and [AFLSmart &mdash; [Mutation-Based Fuzzing (Fuzzing with Mutations)](MutationFuzzer.ipynb#Fuzzing-with-Mutations)
# * angr &mdash; [Symbolic Fuzzing (Background)](SymbolicFuzzer.ipynb#Background)
# * `annotate_arg()` &mdash; [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types)
# * `annotate_edge()` &mdash; [Efficient Grammar Fuzzing (Excursion: Source code and example for `display_annotated_tree()`)](GrammarFuzzer.ipynb#Excursion:-Source-code-and-example-for-`display_annotated_tree()`)
# * `annotate_function_ast_with_invariants()` &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `annotate_function_ast_with_types()` &mdash; [Mining Function Specifications (Annotating Functions with Mined Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Mined-Types)
# * `annotate_function_with_invariants()` &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `annotate_function_with_types()` &mdash; [Mining Function Specifications (Annotating Functions with Mined Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Mined-Types)
# * `annotate_invariants()` &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `annotate_node()` &mdash; [Efficient Grammar Fuzzing (Excursion: Source code and example for `display_annotated_tree()`)](GrammarFuzzer.ipynb#Excursion:-Source-code-and-example-for-`display_annotated_tree()`)
# * `annotate_types()` &mdash; [Mining Function Specifications (Annotating Functions with Mined Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Mined-Types)
# * any &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`)
# * `any_possible_expansions()` &mdash; [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree)
# * `any_sqrt()` &mdash; [Mining Function Specifications (Specifications and Assertions)](DynamicInvariants.ipynb#Specifications-and-Assertions)
# * `append_from_dictionary()` &mdash; [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt)
# * `apply_new_definition()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `apply_result()` &mdash; [Fuzzing with Generators (Generating Elements before Expansion)](GeneratorGrammarFuzzer.ipynb#Generating-Elements-before-Expansion)
# * `apply_twice()` &mdash; [Fuzzing with Generators (Functions Called Before Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-Before-Expansion)
# * arbitrary &mdash; [Parsing Inputs (Excursion: Testing the Parsers)](Parser.ipynb#Excursion:-Testing-the-Parsers)
# * `arc()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `ArcCoverage` class &mdash; [Concolic Fuzzing (Tracking Constraints)](ConcolicFuzzer.ipynb#Tracking-Constraints)
# * `arcs()` &mdash; [Concolic Fuzzing (Tracking Constraints)](ConcolicFuzzer.ipynb#Tracking-Constraints)
# * `arc_8()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `arguments()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `ARGUMENTS_SYMBOL` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * arithmetic expressions &mdash; [Fuzzing with Grammars (Arithmetic Expressions)](Grammars.ipynb#Arithmetic-Expressions)
# * `arith_expr()` &mdash; [Mutation Analysis (Exercise 1: Arithmetic Expression Mutators)](MutationAnalysis.ipynb#Exercise-1:-Arithmetic-Expression-Mutators)
# * `AR` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `ascii_chr()` &mdash; [Fuzzing in the Large (Excursion: `escapelines()` implementatipn)](FuzzingInTheLarge.ipynb#Excursion:-`escapelines()`-implementatipn)
# * `ASCII_STRING_GRAMMAR` &mdash; [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis), [Fuzzing APIs (Strings)](APIFuzzer.ipynb#Strings), [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis)
# * `assertEquals()` &mdash; [Introduction to Software Testing (Automating Test Execution)](Intro_Testing.ipynb#Automating-Test-Execution)
# * assertion &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `assignEnergy()` &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules), [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing), [Greybox Fuzzing (Directed Power Schedule)](GreyboxFuzzer.ipynb#Directed-Power-Schedule), [Greybox Fuzzing (Improved Directed Power Schedule)](GreyboxFuzzer.ipynb#Improved-Directed-Power-Schedule), [Greybox Fuzzing with Grammars (Focusing on Valid Seeds)](GreyboxGrammarFuzzer.ipynb#Focusing-on-Valid-Seeds)
# * assignment &mdash; [Fuzzing: Breaking Things with Random Inputs (A Testing Assignment)](Fuzzer.ipynb#A-Testing-Assignment)
# * `assignments()` &mdash; [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker)
# * `AssignmentTracker` class &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `AssignmentVars` class &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `at()` &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack)
# * `ATTR_GRAMMAR` &mdash; [Fuzzing with Generators (Exercise 2: Attribute Grammars)](GeneratorGrammarFuzzer.ipynb#Exercise-2:-Attribute-Grammars)
# * `at_dot()` &mdash; [Parsing Inputs (Items)](Parser.ipynb#Items)
# * Automata theory &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `autopep8()` &mdash; [Testing Configurations (Autopep8 Setup)](ConfigurationFuzzer.ipynb#Autopep8-Setup)
# * `average_length_until_full_coverage()` &mdash; [Grammar Coverage (Putting Things Together)](GrammarCoverageFuzzer.ipynb#Putting-Things-Together)
# * `A_Class` class &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy), [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)

# %% [markdown]
# ### B
#
# * `B()` &mdash; [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `back()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * Backus-Naur form &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts)
# * `bad_fitness()` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `bar()` &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)
# * before &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `BetterHTTPRequestHandler` class &mdash; [Testing Web Applications (Part 1: Silent Failures)](WebFuzzer.ipynb#Part-1:-Silent-Failures), [Testing Web Applications (Part 2: Sanitized HTML)](WebFuzzer.ipynb#Part-2:-Sanitized-HTML), [Testing Web Applications (Part 3: Sanitized SQL)](WebFuzzer.ipynb#Part-3:-Sanitized-SQL), [Testing Web Applications (Part 4: A Robust Server)](WebFuzzer.ipynb#Part-4:-A-Robust-Server)
# * `BETTER_HTML_INTERNAL_SERVER_ERROR` &mdash; [Testing Web Applications (Part 1: Silent Failures)](WebFuzzer.ipynb#Part-1:-Silent-Failures)
# * binary reduction of dependency graphs &mdash; [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)
# * `BinaryProgramRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `binomial()` &mdash; [Concolic Fuzzing (Example: Binomial Coefficient)](ConcolicFuzzer.ipynb#Example:-Binomial-Coefficient)
# * `BinOpMutator` class &mdash; [Mutation Analysis (Exercise 1: Arithmetic Expression Mutators)](MutationAnalysis.ipynb#Exercise-1:-Arithmetic-Expression-Mutators), [Mutation Analysis (Exercise 1: Arithmetic Expression Mutators)](MutationAnalysis.ipynb#Exercise-1:-Arithmetic-Expression-Mutators)
# * `BIRD` &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * `bit()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * bitmap origins &mdash; [Tracking Information Flow (Tracking Individual Characters)](InformationFlow.ipynb#Tracking-Individual-Characters)
# * `BIT_OPS` &mdash; [Concolic Fuzzing (Exercise 2: Bit Manipulation)](ConcolicFuzzer.ipynb#Exercise-2:-Bit-Manipulation)
# * black-box testing &mdash; [Code Coverage (Black-Box Testing)](Coverage.ipynb#Black-Box-Testing)
# * `BletchleyPark` class &mdash; [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma), [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations), [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * blog post &mdash; [Mutation-Based Fuzzing (Exercise 3)](MutationFuzzer.ipynb#Exercise-3), [Greybox Fuzzing (Solving the Maze)](GreyboxFuzzer.ipynb#Solving-the-Maze), [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background), [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * BNF &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts)
# * `BODY` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * Bomba &mdash; [When To Stop Fuzzing (The Enigma Machine)](WhenToStopFuzzing.ipynb#The-Enigma-Machine)
# * `__bool__()` &mdash; [Concolic Fuzzing (Registering Predicates on Conditionals)](ConcolicFuzzer.ipynb#Registering-Predicates-on-Conditionals), [Concolic Fuzzing (Using an Integer in a Boolean Context)](ConcolicFuzzer.ipynb#Using-an-Integer-in-a-Boolean-Context), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `BoostedBletchleyPark` class &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * Branch coverage &mdash; [Code Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * `BranchCoverage` class &mdash; [Code Coverage (Part 1: Compute branch coverage)](Coverage.ipynb#Part-1:-Compute-branch-coverage)
# * `BranchTransformer` class &mdash; [Search-Based Fuzzing (Instrumenting Source Code Automatically)](SearchBasedFuzzer.ipynb#Instrumenting-Source-Code-Automatically)
# * `branch_coverage()` &mdash; [Code Coverage (Part 1: Compute branch coverage)](Coverage.ipynb#Part-1:-Compute-branch-coverage)
# * `break_max_attempts()` &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * `break_message()` &mdash; [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma), [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations), [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations), [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * `break_n_messages()` &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * "Browser Fuzzing at Mozilla" &mdash; [Fuzzing in the Large (Background)](FuzzingInTheLarge.ipynb#Background)
# * `BROWSER` &mdash; [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium), [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium)
# * `buggy_my_sqrt_with_postcondition()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * `B_Class` class &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)

# %% [markdown]
# ### C
#
# * C preprocessor &mdash; [Testing Configurations (Exercise 1: #ifdef Configuration Fuzzing)](ConfigurationFuzzer.ipynb#Exercise-1:-#ifdef-Configuration-Fuzzing)
# * `C()` &mdash; [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * C-Reduce &mdash; [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)
# * `CachingReducer` class &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * `calculate_distance()` &mdash; [Search-Based Fuzzing (Defining a Search Landscape: Fitness functions)](SearchBasedFuzzer.ipynb#Defining-a-Search-Landscape:-Fitness-functions)
# * call &mdash; [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations)
# * call graph &mdash; [Greybox Fuzzing (Solving the Maze)](GreyboxFuzzer.ipynb#Solving-the-Maze)
# * call stack &mdash; [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input)
# * `CallCarver` class &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `called_functions()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `callers()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `CallGrammarMiner` class &mdash; [Carving Unit Tests (A Grammar Miner for Calls)](Carver.ipynb#A-Grammar-Miner-for-Calls), [Carving Unit Tests (Initial Grammar)](Carver.ipynb#Initial-Grammar), [Carving Unit Tests (A Grammar from Arguments)](Carver.ipynb#A-Grammar-from-Arguments), [Carving Unit Tests (A Grammar from Calls)](Carver.ipynb#A-Grammar-from-Calls), [Carving Unit Tests (A Grammar from all Calls)](Carver.ipynb#A-Grammar-from-all-Calls)
# * `callgraph()` &mdash; [Control Flow Graph (Call Graph Helpers)](ControlFlow.ipynb#Call-Graph-Helpers)
# * calls &mdash; [Greybox Fuzzing (Computing Function-Level Distance)](GreyboxFuzzer.ipynb#Computing-Function-Level-Distance)
# * `calls()` &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `CallStack` class &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack)
# * `CallTracker` class &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls)
# * `call_string()` &mdash; [Carving Unit Tests (Serializing Objects)](Carver.ipynb#Serializing-Objects)
# * `CALL_SYMBOL` &mdash; [Carving Unit Tests (Initial Grammar)](Carver.ipynb#Initial-Grammar)
# * `call_value()` &mdash; [Carving Unit Tests (Serializing Objects)](Carver.ipynb#Serializing-Objects)
# * `__call__()` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer)
# * `cancel()` &mdash; [Timeout (Variant 1: Unix (using signals, efficient))](Timeout.ipynb#Variant-1:-Unix-(using-signals,-efficient)), [Timeout (Variant 2: Generic / Windows (using trace, not very efficient))](Timeout.ipynb#Variant-2:-Generic-/-Windows-(using-trace,-not-very-efficient))
# * `canonical()` &mdash; [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars)
# * `can_be_satisfied()` &mdash; [Symbolic Fuzzing (Exercise 2: Statically checking if a loop should be unrolled further)](SymbolicFuzzer.ipynb#Exercise-2:-Statically-checking-if-a-loop-should-be-unrolled-further)
# * `capitalize()` &mdash; [Tracking Information Flow (String methods that do not change origin)](InformationFlow.ipynb#String-methods-that-do-not-change-origin)
# * `Carver` class &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `cc()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * CFG &mdash; [Parsing Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars), [Parsing Inputs (End of Excursion)](Parser.ipynb#End-of-Excursion), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser), [Parsing Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `CFGNode` class &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * CFGs &mdash; [Parsing Inputs (Excursion: Implementing `EarleyParser`)](Parser.ipynb#Excursion:-Implementing-`EarleyParser`), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `CFLAGS` &mdash; [Fuzzing in the Large (Collecting Code Coverage)](FuzzingInTheLarge.ipynb#Collecting-Code-Coverage)
# * CFLs &mdash; [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `cgi_decode()` &mdash; [Code Coverage (A CGI Decoder)](Coverage.ipynb#A-CGI-Decoder), [Search-Based Fuzzing (Testing a More Complex Program)](SearchBasedFuzzer.ipynb#Testing-a-More-Complex-Program), [Concolic Fuzzing (Example: Decoding CGI Strings)](ConcolicFuzzer.ipynb#Example:-Decoding-CGI-Strings), [Control Flow Graph (cgi_decode)](ControlFlow.ipynb#cgi_decode)
# * `cgi_decode_instrumented()` &mdash; [Search-Based Fuzzing (Instrumenting Source Code Automatically)](SearchBasedFuzzer.ipynb#Instrumenting-Source-Code-Automatically)
# * `cgi_decode_traced()` &mdash; [Code Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions)
# * `cgi_encode()` &mdash; [Testing Web Applications (Excursion: Implementing cgi_decode())](WebFuzzer.ipynb#Excursion:-Implementing-cgi_decode())
# * `CGI_GRAMMAR` &mdash; [Testing Web Applications (Mining Grammars for Web Pages)](WebFuzzer.ipynb#Mining-Grammars-for-Web-Pages)
# * `CG` &mdash; [Greybox Fuzzing (Computing Function-Level Distance)](GreyboxFuzzer.ipynb#Computing-Function-Level-Distance)
# * chapter on parsers](Parser.ipynb) that coarse grammars do not work well for fuzzing when the input format includes details expressed only in code. That is, even though we have the formal specification of CSV files ([RFC 4180 &mdash; [Mining Input Grammars (A Grammar Challenge)](GrammarMiner.ipynb#A-Grammar-Challenge)
# * character level &mdash; [Tracking Information Flow (Tracking Individual Characters)](InformationFlow.ipynb#Tracking-Individual-Characters)
# * `CHARACTERS_WITHOUT_QUOTE` &mdash; [Fuzzing with Grammars (Exercise 1: A JSON Grammar)](Grammars.ipynb#Exercise-1:-A-JSON-Grammar)
# * `CHARGE_GRAMMAR` &mdash; [Fuzzing with Generators (Example: Numeric Ranges)](GeneratorGrammarFuzzer.ipynb#Example:-Numeric-Ranges)
# * `chart_parse()` &mdash; [Parsing Inputs (The Parsing Algorithm)](Parser.ipynb#The-Parsing-Algorithm)
# * `CHAR_WIDTH` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `check()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `checkpoint()` &mdash; [Symbolic Fuzzing (Fuzzing with Simple Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Simple-Symbolic-Fuzzer)
# * checksum &mdash; [Tracking Information Flow (Tracking Individual Characters)](InformationFlow.ipynb#Tracking-Individual-Characters)
# * `check_grammar()` &mdash; [Efficient Grammar Fuzzing (Excursion: `check_grammar()` implementation)](GrammarFuzzer.ipynb#Excursion:-`check_grammar()`-implementation), [Probabilistic Grammar Fuzzing (Expanding by Probability)](ProbabilisticGrammarFuzzer.ipynb#Expanding-by-Probability)
# * `check_param()` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `check_time()` &mdash; [Timeout (Variant 2: Generic / Windows (using trace, not very efficient))](Timeout.ipynb#Variant-2:-Generic-/-Windows-(using-trace,-not-very-efficient))
# * `check_triangle()` &mdash; [Symbolic Fuzzing (Obtaining Path Conditions for Coverage)](SymbolicFuzzer.ipynb#Obtaining-Path-Conditions-for-Coverage), [Control Flow Graph (check_triangle)](ControlFlow.ipynb#check_triangle)
# * child nodes &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * children &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `CHILDREN` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees), [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * choice expressions &mdash; [Parsing Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `ChoiceNode` class &mdash; [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * `Choice` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `choose()` &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules)
# * `choose_a_node_to_explore()` &mdash; [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser)
# * `choose_covered_node_expansion()` &mdash; [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Probabilistic Grammar Fuzzing (Exercise 1: Probabilistic Fuzzing with Coverage)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1:-Probabilistic-Fuzzing-with-Coverage)
# * `choose_node_expansion()` &mdash; [Efficient Grammar Fuzzing (Picking a Children Alternative to be Expanded)](GrammarFuzzer.ipynb#Picking-a-Children-Alternative-to-be-Expanded), [Grammar Coverage (Tracking Expansions while Fuzzing)](GrammarCoverageFuzzer.ipynb#Tracking-Expansions-while-Fuzzing), [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Grammar Coverage (Excursion: Implementing `choose_node_expansion()`)](GrammarCoverageFuzzer.ipynb#Excursion:-Implementing-`choose_node_expansion()`), [Probabilistic Grammar Fuzzing (Expanding by Probability)](ProbabilisticGrammarFuzzer.ipynb#Expanding-by-Probability), [Probabilistic Grammar Fuzzing (Exercise 1: Probabilistic Fuzzing with Coverage)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1:-Probabilistic-Fuzzing-with-Coverage)
# * `choose_path()` &mdash; [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * `choose_tree_expansion()` &mdash; [Efficient Grammar Fuzzing (Excursion: `expand_tree_once()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_tree_once()`-implementation), [Fuzzing with Generators (Ordering Expansions)](GeneratorGrammarFuzzer.ipynb#Ordering-Expansions)
# * `choose_uncovered_node_expansion()` &mdash; [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Probabilistic Grammar Fuzzing (Exercise 1: Probabilistic Fuzzing with Coverage)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1:-Probabilistic-Fuzzing-with-Coverage)
# * `chosen()` &mdash; [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * Class Diagrams &mdash; [Academic Prototyping (Replicable Experiments)](AcademicPrototyping.ipynb#Replicable-Experiments)
# * `CLASS_COLOR` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names), [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `CLASS_FONT` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names), [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `class_hierarchy()` &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)
# * `class_items()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `_class_items()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `class_methods()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `class_methods_string()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `class_set()` &mdash; [Class Diagrams (Getting a Class Tree)](ClassDiagram.ipynb#Getting-a-Class-Tree)
# * `class_tree()` &mdash; [Class Diagrams (Getting a Class Tree)](ClassDiagram.ipynb#Getting-a-Class-Tree)
# * `class_vars()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `class_vars_string()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `clean_grammar()` &mdash; [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining)
# * `clear_httpd_messages()` &mdash; [Testing Web Applications (Logging)](WebFuzzer.ipynb#Logging)
# * `clear_origin()` &mdash; [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins)
# * `clear_symbol_table()` &mdash; [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses)
# * `clear_taint()` &mdash; [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins)
# * `click()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `clock()` &mdash; [Timer (Measuring Time)](Timer.ipynb#Measuring-Time)
# * `coalesce()` &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class), [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * code coverage &mdash; [Code Coverage](Coverage.ipynb#Code-Coverage)
# * code snippet from StackOverflow &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * `code_repOK()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `collapse_if_too_large()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks)
# * `collect_conditions()` &mdash; [Academic Prototyping (Static Analysis in Python: Still Easy)](AcademicPrototyping.ipynb#Static-Analysis-in-Python:-Still-Easy), [Prototyping with Python (Static Analysis in Python: Still Easy)](PrototypingWithPython.ipynb#Static-Analysis-in-Python:-Still-Easy)
# * `collect_path_conditions()` &mdash; [Academic Prototyping (A Symbolic Test Generator)](AcademicPrototyping.ipynb#A-Symbolic-Test-Generator), [Prototyping with Python (A Symbolic Test Generator)](PrototypingWithPython.ipynb#A-Symbolic-Test-Generator)
# * colors &mdash; [Tracking Information Flow (Tracking Individual Characters)](InformationFlow.ipynb#Tracking-Individual-Characters)
# * `column()` &mdash; [Tracking Information Flow (Representing Tables)](InformationFlow.ipynb#Representing-Tables), [Concolic Fuzzing (Example: Database)](ConcolicFuzzer.ipynb#Example:-Database)
# * `Column` class &mdash; [Parsing Inputs (Columns)](Parser.ipynb#Columns), [Parsing Inputs (Columns)](Parser.ipynb#Columns), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `combination()` &mdash; [Concolic Fuzzing (Example: Binomial Coefficient)](ConcolicFuzzer.ipynb#Example:-Binomial-Coefficient)
# * commas &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `comma_split()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `COMMENT_CHAR_WIDTH` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `Comment` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * comparison node &mdash; [Control Flow Graph (fib)](ControlFlow.ipynb#fib)
# * Competent Programmer Hypothesis &mdash; [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults)
# * compiler testing &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background), [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)
# * complement of the input samples &mdash; [Probabilistic Grammar Fuzzing (Testing Uncommon Features)](ProbabilisticGrammarFuzzer.ipynb#Testing-Uncommon-Features)
# * `complete()` &mdash; [Parsing Inputs (Completing Processing)](Parser.ipynb#Completing-Processing), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `compute_dominator()` &mdash; [Control Flow Graph (Supporting Functions)](ControlFlow.ipynb#Supporting-Functions)
# * `compute_flow()` &mdash; [Control Flow Graph (Supporting Functions)](ControlFlow.ipynb#Supporting-Functions)
# * `compute_gcd()` &mdash; [Control Flow Graph (gcd)](ControlFlow.ipynb#gcd)
# * concolic &mdash; [Symbolic Fuzzing (Check Before You Loop)](SymbolicFuzzer.ipynb#Check-Before-You-Loop)
# * concolic execution &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow), [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer)
# * Concolic Execution &mdash; [Concolic Fuzzing (Solving Constraints)](ConcolicFuzzer.ipynb#Solving-Constraints)
# * `concolic()` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names)
# * `ConcolicDB` class &mdash; [Concolic Fuzzing (Example: Database)](ConcolicFuzzer.ipynb#Example:-Database)
# * `ConcolicGrammarFuzzer` class &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer), [Concolic Fuzzing (Pruning and Updating)](ConcolicFuzzer.ipynb#Pruning-and-Updating), [Concolic Fuzzing (Pruning and Updating)](ConcolicFuzzer.ipynb#Pruning-and-Updating)
# * `ConcolicTracer` class &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Translating to the SMT Expression Format)](ConcolicFuzzer.ipynb#Translating-to-the-SMT-Expression-Format), [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names), [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names), [Concolic Fuzzing (Evaluating the Concolic Expressions)](ConcolicFuzzer.ipynb#Evaluating-the-Concolic-Expressions), [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer), [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer)
# * concrete syntax tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `condition()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * conditional compilation &mdash; [Testing Configurations (Exercise 1: #ifdef Configuration Fuzzing)](ConfigurationFuzzer.ipynb#Exercise-1:-#ifdef-Configuration-Fuzzing)
# * `CONDITION` &mdash; [Code Coverage (Exercise 2: Branch Coverage)](Coverage.ipynb#Exercise-2:-Branch-Coverage), [Code Coverage (Exercise 2: Branch Coverage)](Coverage.ipynb#Exercise-2:-Branch-Coverage), [Code Coverage (Exercise 2: Branch Coverage)](Coverage.ipynb#Exercise-2:-Branch-Coverage)
# * `CONSTRAINED_VAR_GRAMMAR` &mdash; [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses), [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses), [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses), [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses), [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses), [Fuzzing with Generators (Ordering Expansions)](GeneratorGrammarFuzzer.ipynb#Ordering-Expansions), [Fuzzing with Generators (Ordering Expansions)](GeneratorGrammarFuzzer.ipynb#Ordering-Expansions)
# * constraint &mdash; [Fuzzing with Generators (Functions Called After Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-After-Expansion)
# * `CONSTRAINT` &mdash; [Fuzzing with Constraints (Quantifiers)](FuzzingWithConstraints.ipynb#Quantifiers)
# * `construct_callgraph()` &mdash; [Control Flow Graph (Call Graph Helpers)](ControlFlow.ipynb#Call-Graph-Helpers)
# * context-free grammars &mdash; [Fuzzing with Grammars (Grammars)](Grammars.ipynb#Grammars)
# * `CONTEXT` &mdash; [Fuzzing with Constraints (Quantifiers)](FuzzingWithConstraints.ipynb#Quantifiers)
# * `Context` class &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * contract &mdash; [Mining Function Specifications (Why Generic Error Checking is Not Enough)](DynamicInvariants.ipynb#Why-Generic-Error-Checking-is-Not-Enough)
# * `convert()` &mdash; [Tracking Information Flow (Inserting Data)](InformationFlow.ipynb#Inserting-Data)
# * `convert_ebnf_grammar()` &mdash; [Fuzzing with Grammars (All Together)](Grammars.ipynb#All-Together)
# * `convert_ebnf_operators()` &mdash; [Fuzzing with Grammars (Expanding Operators)](Grammars.ipynb#Expanding-Operators)
# * `convert_ebnf_parentheses()` &mdash; [Fuzzing with Grammars (Expanding Parenthesized Expressions)](Grammars.ipynb#Expanding-Parenthesized-Expressions)
# * `copy()` &mdash; [Parsing Inputs (States)](Parser.ipynb#States), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Symbolic Fuzzing (Tracking Assignments)](SymbolicFuzzer.ipynb#Tracking-Assignments)
# * `COUNTER` &mdash; [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names), [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names)
# * `CountingGreyboxFuzzer` class &mdash; [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing)
# * `counts()` &mdash; [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions)
# * `count_expansions()` &mdash; [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions)
# * `count_nodes()` &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation)
# * Coupling Effect &mdash; [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults)
# * coverage criteria &mdash; [Code Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * `coverage()` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Code Coverage (Part 1: Compute branch coverage)](Coverage.ipynb#Part-1:-Compute-branch-coverage), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * Coverage-based Greybox Fuzzing as Markov Chain &mdash; [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing)
# * `Coverage` class &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * `cpp_identifiers()` &mdash; [Testing Configurations (Part 1: Extract Preprocessor Variables)](ConfigurationFuzzer.ipynb#Part-1:-Extract-Preprocessor-Variables)
# * `crange()` &mdash; [Fuzzing with Grammars (Character Classes)](Grammars.ipynb#Character-Classes)
# * `crashme()` &mdash; [Greybox Fuzzing (Runners and a Sample Program)](GreyboxFuzzer.ipynb#Runners-and-a-Sample-Program)
# * `crash_if_too_long()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Buffer Overflows)](Fuzzer.ipynb#Buffer-Overflows)
# * `crawl()` &mdash; [Testing Web Applications (Excursion: Implementing a Crawler)](WebFuzzer.ipynb#Excursion:-Implementing-a-Crawler)
# * crawler &mdash; [Testing Web Applications (Crawling User Interfaces)](WebFuzzer.ipynb#Crawling-User-Interfaces)
# * `create()` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (Create)](InformationFlow.ipynb#Create), [Tracking Information Flow (Part 2: Arithmetic expressions)](InformationFlow.ipynb#Part-2:-Arithmetic-expressions), [Concolic Fuzzing (A Proxy Class for Booleans)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Booleans), [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (A Proxy Class for Strings)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Strings), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `create_assignments()` &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker), [Mining Input Grammars (Scope Tracker)](GrammarMiner.ipynb#Scope-Tracker), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `create_call_stack()` &mdash; [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `create_candidate()` &mdash; [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing), [Greybox Fuzzing with Grammars (Fragment-Based Fuzzing)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Fuzzing), [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing)
# * `create_context()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `create_foo_py()` &mdash; [Testing Configurations (Creating Autopep8 Options)](ConfigurationFuzzer.ipynb#Creating-Autopep8-Options)
# * `create_instrumented_function()` &mdash; [Search-Based Fuzzing (Instrumenting Source Code Automatically)](SearchBasedFuzzer.ipynb#Instrumenting-Source-Code-Automatically)
# * `create_population()` &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * `create_table()` &mdash; [Tracking Information Flow (Representing Tables)](InformationFlow.ipynb#Representing-Tables)
# * `create_tracker()` &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Recover Grammar)](GrammarMiner.ipynb#Recover-Grammar), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `create_tree_miner()` &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Recover Grammar)](GrammarMiner.ipynb#Recover-Grammar), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * cross-site scripting &mdash; [Testing Web Applications (Cross-Site Scripting Attacks)](WebFuzzer.ipynb#Cross-Site-Scripting-Attacks)
# * crossover &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * `crossover()` &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * CSmith &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * CSV &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * current &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `C_Class` class &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)
# * `C_SAMPLE_GRAMMAR` &mdash; [Parsing Inputs (Excursion: Implementing `EarleyParser`)](Parser.ipynb#Excursion:-Implementing-`EarleyParser`)
# * `C` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)

# %% [markdown]
# ### D
#
# * DAIKON dynamic invariant detector](https://plse.cs.washington.edu/daikon/) can be considered the mother of function specification miners.  Continuously maintained and extended for more than 20 years, it mines likely invariants in the style of this chapter for a variety of languages, including C, C++, C#, Eiffel, F#, Java, Perl, and Visual Basic.  On top of the functionality discussed above, it holds a rich catalog of patterns for likely invariants, supports data invariants, can eliminate invariants that are implied by others, and determines statistical confidence to disregard unlikely invariants.  The corresponding paper \cite{Ernst2001} is one of the seminal and most-cited papers of Software Engineering.  A multitude of works have been published based on DAIKON and detecting invariants; see this [curated list &mdash; [Mining Function Specifications (Background)](DynamicInvariants.ipynb#Background)
# * data dictionary &mdash; [Testing Web Applications (Leaking Internal Information)](WebFuzzer.ipynb#Leaking-Internal-Information)
# * database &mdash; [Testing Web Applications (Storing Orders)](WebFuzzer.ipynb#Storing-Orders)
# * `db_select()` &mdash; [Concolic Fuzzing (Example: Database)](ConcolicFuzzer.ipynb#Example:-Database)
# * `DB` &mdash; [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Tracking Untrusted Input)](InformationFlow.ipynb#Tracking-Untrusted-Input), [Tracking Information Flow (TaintedDB)](InformationFlow.ipynb#TaintedDB), [Concolic Fuzzing (Example: Database)](ConcolicFuzzer.ipynb#Example:-Database)
# * `DB` class &mdash; [Tracking Information Flow (A Vulnerable Database)](InformationFlow.ipynb#A-Vulnerable-Database), [Tracking Information Flow (Representing Tables)](InformationFlow.ipynb#Representing-Tables), [Tracking Information Flow (Representing Tables)](InformationFlow.ipynb#Representing-Tables), [Tracking Information Flow (Representing Tables)](InformationFlow.ipynb#Representing-Tables), [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Selecting Data)](InformationFlow.ipynb#Selecting-Data), [Tracking Information Flow (Selecting Data)](InformationFlow.ipynb#Selecting-Data), [Tracking Information Flow (Selecting Data)](InformationFlow.ipynb#Selecting-Data), [Tracking Information Flow (Inserting Data)](InformationFlow.ipynb#Inserting-Data), [Tracking Information Flow (Inserting Data)](InformationFlow.ipynb#Inserting-Data), [Tracking Information Flow (Updating Data)](InformationFlow.ipynb#Updating-Data), [Tracking Information Flow (Deleting Data)](InformationFlow.ipynb#Deleting-Data)
# * debugger &mdash; [Introduction to Software Testing (Debugging a Function)](Intro_Testing.ipynb#Debugging-a-Function)
# * `DEBUG` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `declarations()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `decorator()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions), [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers)
# * `decrange()` &mdash; [Probabilistic Grammar Fuzzing (Probabilities in Context)](ProbabilisticGrammarFuzzer.ipynb#Probabilities-in-Context)
# * `default_edge_attr()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`)
# * `default_graph_attr()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`)
# * `default_node_attr()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`)
# * `DEFAULT_ORIGIN` &mdash; [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins)
# * `DEFAULT_STYLE` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * deferred parsing &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Fuzzing)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Fuzzing)
# * `defined_in()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `defined_vars()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `DefineTracker` class &mdash; [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker)
# * `define_expr()` &mdash; [Fuzzing with Grammars (Part 1 (b): Alternative representations)](Grammars.ipynb#Part-1-(b):-Alternative-representations)
# * `define_ex_grammar()` &mdash; [Fuzzing with Grammars (Part 1 (b): Alternative representations)](Grammars.ipynb#Part-1-(b):-Alternative-representations)
# * `define_grammar()` &mdash; [Fuzzing with Grammars (Part 1 (a): One Single Function)](Grammars.ipynb#Part-1-(a):-One-Single-Function)
# * `define_id()` &mdash; [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses)
# * `define_name()` &mdash; [Fuzzing with Grammars (Part 1 (b): Alternative representations)](Grammars.ipynb#Part-1-(b):-Alternative-representations)
# * `define_symbolic_vars()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `def_used_nonterminals()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `is_valid_grammar()`)](Grammars.ipynb#Excursion:-Implementing-`is_valid_grammar()`)
# * degree of validity &mdash; [Greybox Fuzzing with Grammars (Determining Symbol Regions)](GreyboxGrammarFuzzer.ipynb#Determining-Symbol-Regions)
# * `degree_of_validity()` &mdash; [Greybox Fuzzing with Grammars (Focusing on Valid Seeds)](GreyboxGrammarFuzzer.ipynb#Focusing-on-Valid-Seeds)
# * `DELAY_AFTER_CHECK` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `DELAY_AFTER_CLICK` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `DELAY_AFTER_FILL` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `DELAY_AFTER_SUBMIT` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `delete_element()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `delete_fragment()` &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation)
# * `delete_last_character()` &mdash; [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt)
# * `delete_random_character()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators)
# * `DELETE` &mdash; [Testing Web Applications (SQL Injection Attacks)](WebFuzzer.ipynb#SQL-Injection-Attacks)
# * `DeltaDebuggingReducer` class &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * Dependencies &mdash; [Academic Prototyping (Replicable Experiments)](AcademicPrototyping.ipynb#Replicable-Experiments)
# * derivation tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `determineGaps()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `deterministic_reduction()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `DiagramItem` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `DIAGRAM_CLASS` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `Diagram` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `DictMutator` class &mdash; [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt), [Greybox Fuzzing with Grammars (Fuzzing with Dictionaries)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Dictionaries)
# * `diff()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * different &mdash; [Mining Input Grammars (Problems with the Grammar Miner with Reassignment)](GrammarMiner.ipynb#Problems-with-the-Grammar-Miner-with-Reassignment)
# * `DIGIT_GRAMMAR` &mdash; [Fuzzing with Grammars (Representing Grammars in Python)](Grammars.ipynb#Representing-Grammars-in-Python)
# * Directed Greybox Fuzzing](https://mboehme.github.io/paper/CCS17.pdf)" \cite{boehme2017greybox} and check out the implementation into AFL at [http://github.com/aflgo/aflgo &mdash; [Greybox Fuzzing (Improved Directed Power Schedule)](GreyboxFuzzer.ipynb#Improved-Directed-Power-Schedule)
# * `DirectedSchedule` class &mdash; [Greybox Fuzzing (Directed Power Schedule)](GreyboxFuzzer.ipynb#Directed-Power-Schedule)
# * discovery &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * discovery probability &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * `display_annotated_tree()` &mdash; [Efficient Grammar Fuzzing (Excursion: Source code and example for `display_annotated_tree()`)](GrammarFuzzer.ipynb#Excursion:-Source-code-and-example-for-`display_annotated_tree()`)
# * `display_class_hierarchy()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `display_class_node()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `display_class_trees()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `display_httpd_message()` &mdash; [Testing Web Applications (Logging)](WebFuzzer.ipynb#Logging)
# * `display_legend()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `display_stack()` &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack)
# * `display_trace_tree()` &mdash; [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class)
# * `display_tree()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`)
# * `distance_character()` &mdash; [Search-Based Fuzzing (Branch Distances)](SearchBasedFuzzer.ipynb#Branch-Distances)
# * `docstring()` &mdash; [Class Diagrams (Getting Docs)](ClassDiagram.ipynb#Getting-Docs)
# * `doc_class_methods()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `DOC_INDENT` &mdash; [Class Diagrams (Getting Docs)](ClassDiagram.ipynb#Getting-Docs)
# * Domato &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `dot_escape()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`)
# * `doubleenumerate()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `down()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `do_call()` &mdash; [Fuzzing APIs (Synthesizing Code)](APIFuzzer.ipynb#Synthesizing-Code)
# * `do_check()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `do_click()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `do_delete()` &mdash; [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Deleting Data)](InformationFlow.ipynb#Deleting-Data)
# * `do_fill()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `do_GET()` &mdash; [Testing Web Applications (Handling HTTP Requests)](WebFuzzer.ipynb#Handling-HTTP-Requests)
# * `do_HEAD()` &mdash; [Testing Web Applications (Other HTTP commands)](WebFuzzer.ipynb#Other-HTTP-commands)
# * `do_insert()` &mdash; [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Inserting Data)](InformationFlow.ipynb#Inserting-Data)
# * `do_select()` &mdash; [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Selecting Data)](InformationFlow.ipynb#Selecting-Data)
# * `do_submit()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `do_update()` &mdash; [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Updating Data)](InformationFlow.ipynb#Updating-Data)
# * Dragon Book &mdash; [Efficient Grammar Fuzzing (Background)](GrammarFuzzer.ipynb#Background)
# * Driller &mdash; [Symbolic Fuzzing (Background)](SymbolicFuzzer.ipynb#Background)
# * `duplicate_context()` &mdash; [Grammar Coverage (Extending Grammars for Context Coverage Programmatically)](GrammarCoverageFuzzer.ipynb#Extending-Grammars-for-Context-Coverage-Programmatically)
# * `_duplicate_context()` &mdash; [Grammar Coverage (Excursion: Implementing `_duplicate_context()`)](GrammarCoverageFuzzer.ipynb#Excursion:-Implementing-`_duplicate_context()`)
# * during &mdash; [Greybox Fuzzing (Lessons Learned)](GreyboxFuzzer.ipynb#Lessons-Learned)
# * dynamic analysis &mdash; [Code Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions)
# * dynamic taint &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * dynamic taint analysis &mdash; [Tracking Information Flow (The Evil of Eval)](InformationFlow.ipynb#The-Evil-of-Eval)
# * dynamic taints &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `D_Class` class &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy), [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)

# %% [markdown]
# ### E
#
# * `e()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * Earley parser &mdash; [Parsing Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * `EarleyParser` class &mdash; [Parsing Inputs (The Parsing Algorithm)](Parser.ipynb#The-Parsing-Algorithm), [Parsing Inputs (Predicting States)](Parser.ipynb#Predicting-States), [Parsing Inputs (Scanning Tokens)](Parser.ipynb#Scanning-Tokens), [Parsing Inputs (Completing Processing)](Parser.ipynb#Completing-Processing), [Parsing Inputs (Filling the Chart)](Parser.ipynb#Filling-the-Chart), [Parsing Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing Inputs (Parsing Paths)](Parser.ipynb#Parsing-Paths), [Parsing Inputs (Parsing Forests)](Parser.ipynb#Parsing-Forests), [Parsing Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing Inputs (Ambiguous Parsing)](Parser.ipynb#Ambiguous-Parsing), [Parsing Inputs (Nullable)](Parser.ipynb#Nullable)
# * `earley_complete()` &mdash; [Parsing Inputs (Completing Processing)](Parser.ipynb#Completing-Processing)
# * EBNF &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts)
# * `ebnf_grammar()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * "Effective Software Testing: A Developer's Guide" &mdash; [Introduction to Software Testing (Background)](Intro_Testing.ipynb#Background)
# * `elapsed_time()` &mdash; [Timer (Measuring Time)](Timer.ipynb#Measuring-Time)
# * elements &mdash; [When To Stop Fuzzing (The Kenngruppenbuch)](WhenToStopFuzzing.ipynb#The-Kenngruppenbuch), [When To Stop Fuzzing (The Kenngruppenbuch)](WhenToStopFuzzing.ipynb#The-Kenngruppenbuch)
# * ELSE &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * embed the finite state machine into a grammar &mdash; [Testing Graphical User Interfaces (State Machines as Grammars)](GUIFuzzer.ipynb#State-Machines-as-Grammars)
# * `EmbeddedInvariantAnnotator` class &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `EmbeddedInvariantTransformer` class &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * EMI Project &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `End` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * energy &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules)
# * `EnhancedExtractor` class &mdash; [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * Enigma &mdash; [When To Stop Fuzzing](WhenToStopFuzzing.ipynb#When-To-Stop-Fuzzing)
# * Enigma machines &mdash; [When To Stop Fuzzing (The Enigma Machine)](WhenToStopFuzzing.ipynb#The-Enigma-Machine)
# * `EnigmaMachine` class &mdash; [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma), [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma)
# * `enter()` &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack)
# * `__enter__()` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Error Handling (Catching Errors)](ExpectError.ipynb#Catching-Errors), [Timer (Measuring Time)](Timer.ipynb#Measuring-Time), [Timeout (Variant 1: Unix (using signals, efficient))](Timeout.ipynb#Variant-1:-Unix-(using-signals,-efficient)), [Timeout (Variant 2: Generic / Windows (using trace, not very efficient))](Timeout.ipynb#Variant-2:-Generic-/-Windows-(using-trace,-not-very-efficient))
# * `EOF` &mdash; [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks), [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks), [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks), [Parsing Inputs (Exercise 9: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-9:-Follow-Set-of-a-Nonterminal), [Parsing Inputs (Exercise 9: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-9:-Follow-Set-of-a-Nonterminal), [Parsing Inputs (Exercise 9: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-9:-Follow-Set-of-a-Nonterminal)
# * epsilon expansion &mdash; [Fuzzing with Grammars (Excursion: Implementing `convert_ebnf_grammar()`)](Grammars.ipynb#Excursion:-Implementing-`convert_ebnf_grammar()`), [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion)
# * `EPSILON` &mdash; [Introduction to Software Testing (Automating Test Execution)](Intro_Testing.ipynb#Automating-Test-Execution), [Parsing Inputs (The Aycock Epsilon Fix)](Parser.ipynb#The-Aycock-Epsilon-Fix), [Parsing Inputs (Exercise 8: First Set of a Nonterminal)](Parser.ipynb#Exercise-8:-First-Set-of-a-Nonterminal), [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * Equivalent mutants &mdash; [Mutation Analysis (The Problem of  Equivalent Mutants)](MutationAnalysis.ipynb#The-Problem-of--Equivalent-Mutants)
# * `__eq__()` &mdash; [Parsing Inputs (States)](Parser.ipynb#States), [Concolic Fuzzing (Equality between Integers)](ConcolicFuzzer.ipynb#Equality-between-Integers), [Concolic Fuzzing (Equality between Strings)](ConcolicFuzzer.ipynb#Equality-between-Strings), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `escape()` &mdash; [Class Diagrams (Getting Docs)](ClassDiagram.ipynb#Getting-Docs)
# * `escapelines()` &mdash; [Fuzzing in the Large (Excursion: `escapelines()` implementatipn)](FuzzingInTheLarge.ipynb#Excursion:-`escapelines()`-implementatipn)
# * `escape_doc()` &mdash; [Class Diagrams (Getting Docs)](ClassDiagram.ipynb#Getting-Docs)
# * Estimating the population size for capture-recapture data with unequal catchability &mdash; [When To Stop Fuzzing (Background)](WhenToStopFuzzing.ipynb#Background)
# * `EvalMysteryRunner` class &mdash; [Reducing Failure-Inducing Inputs (Lexical Reduction vs. Syntactic Rules)](Reducer.ipynb#Lexical-Reduction-vs.-Syntactic-Rules)
# * `evaluate_condition()` &mdash; [Search-Based Fuzzing (Instrumentation for Atomic Conditions)](SearchBasedFuzzer.ipynb#Instrumentation-for-Atomic-Conditions), [Search-Based Fuzzing (Instrumentation for Atomic Conditions)](SearchBasedFuzzer.ipynb#Instrumentation-for-Atomic-Conditions)
# * `evaluate_population()` &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * `eval_function()` &mdash; [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion)
# * `eval_with_exception()` &mdash; [Fuzzing with Generators (Example: Negative Expressions)](GeneratorGrammarFuzzer.ipynb#Example:-Negative-Expressions)
# * even more &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `EvenFasterGrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * excellent library from Tab Atkins jr. &mdash; [Railroad Diagrams](RailroadDiagrams.ipynb#Railroad-Diagrams)
# * `executable()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `ExerciseGrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Exercise 4: Alternate Random Expansions)](GrammarFuzzer.ipynb#Exercise-4:-Alternate-Random-Expansions)
# * `__exit__()` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Error Handling (Catching Errors)](ExpectError.ipynb#Catching-Errors), [Error Handling (Catching Timeouts)](ExpectError.ipynb#Catching-Timeouts), [Timer (Measuring Time)](Timer.ipynb#Measuring-Time), [Timeout (Variant 1: Unix (using signals, efficient))](Timeout.ipynb#Variant-1:-Unix-(using-signals,-efficient)), [Timeout (Variant 2: Generic / Windows (using trace, not very efficient))](Timeout.ipynb#Variant-2:-Generic-/-Windows-(using-trace,-not-very-efficient))
# * `expandtabs()` &mdash; [Tracking Information Flow (Expand Tabs)](InformationFlow.ipynb#Expand-Tabs)
# * `expand_node()` &mdash; [Efficient Grammar Fuzzing (Excursion: `expand_node_randomly()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_randomly()`-implementation), [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion), [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation)
# * `expand_node_by_cost()` &mdash; [Efficient Grammar Fuzzing (Excursion: `expand_node_by_cost()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_by_cost()`-implementation)
# * `expand_node_max_cost()` &mdash; [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation)
# * `expand_node_min_cost()` &mdash; [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion)
# * `expand_node_randomly()` &mdash; [Efficient Grammar Fuzzing (Excursion: `expand_node_randomly()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_randomly()`-implementation), [Efficient Grammar Fuzzing (Exercise 4: Alternate Random Expansions)](GrammarFuzzer.ipynb#Exercise-4:-Alternate-Random-Expansions), [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * `expand_tree()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementation of three-phase `expand_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementation-of-three-phase-`expand_tree()`)
# * `expand_tree_once()` &mdash; [Efficient Grammar Fuzzing (Excursion: `expand_tree_once()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_tree_once()`-implementation), [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing)
# * `expand_tree_with_strategy()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementation of three-phase `expand_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementation-of-three-phase-`expand_tree()`)
# * `expand_tstate()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * expansion alternatives &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * expansion rules &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * `ExpansionCountMiner` class &mdash; [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions), [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions), [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions)
# * `ExpansionError` class &mdash; [Fuzzing with Grammars (A Simple Grammar Fuzzer)](Grammars.ipynb#A-Simple-Grammar-Fuzzer)
# * `expansion_cost()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing Cost Functions)](GrammarFuzzer.ipynb#Excursion:-Implementing-Cost-Functions), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer)
# * `expansion_coverage()` &mdash; [Grammar Coverage (Keeping Track of Expansions)](GrammarCoverageFuzzer.ipynb#Keeping-Track-of-Expansions)
# * `expansion_key()` &mdash; [Grammar Coverage (Keeping Track of Expansions)](GrammarCoverageFuzzer.ipynb#Keeping-Track-of-Expansions)
# * `expansion_to_children()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `expansion_to_children()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`expansion_to_children()`), [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion), [Efficient Grammar Fuzzing (Exercise 1: Caching Method Results)](GrammarFuzzer.ipynb#Exercise-1:-Caching-Method-Results)
# * `ExpectError` class &mdash; [Error Handling (Catching Errors)](ExpectError.ipynb#Catching-Errors)
# * `ExpectTimeout` class &mdash; [Error Handling (Catching Timeouts)](ExpectError.ipynb#Catching-Timeouts)
# * exploit &mdash; [Greybox Fuzzing with Grammars (Parsing and Recombining JavaScript, or How to Make 50,000 USD in Four Weeks)](GreyboxGrammarFuzzer.ipynb#Parsing-and-Recombining-JavaScript,-or-How-to-Make-50,000-USD-in-Four-Weeks)
# * `explore()` &mdash; [Symbolic Fuzzing (Stepwise Exploration of Paths)](SymbolicFuzzer.ipynb#Stepwise-Exploration-of-Paths)
# * `explore_all()` &mdash; [Testing Graphical User Interfaces (Covering States)](GUIFuzzer.ipynb#Covering-States)
# * `expression_clause()` &mdash; [Tracking Information Flow (Selecting Data)](InformationFlow.ipynb#Selecting-Data)
# * `expression_grammar_fn()` &mdash; [Fuzzing with Grammars (Exercise 4: Defining Grammars as Functions (Advanced))](Grammars.ipynb#Exercise-4:-Defining-Grammars-as-Functions-(Advanced))
# * `EXPR_GRAMMAR_BNF` &mdash; [Efficient Grammar Fuzzing (An Insufficient Algorithm)](GrammarFuzzer.ipynb#An-Insufficient-Algorithm)
# * `EXPR_GRAMMAR` &mdash; [Grammar Coverage (Covering Grammar Elements)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Elements), [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Grammar Coverage (End of Excursion)](GrammarCoverageFuzzer.ipynb#End-of-Excursion), [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars), [Fuzzing with Generators (Example: More Numeric Ranges)](GeneratorGrammarFuzzer.ipynb#Example:-More-Numeric-Ranges)
# * `exp_opt()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `opts()`)](Grammars.ipynb#Excursion:-Implementing-`opts()`)
# * `exp_opts()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `opts()`)](Grammars.ipynb#Excursion:-Implementing-`opts()`)
# * `exp_order()` &mdash; [Fuzzing with Generators (Ordering Expansions)](GeneratorGrammarFuzzer.ipynb#Ordering-Expansions)
# * `exp_post_expansion_function()` &mdash; [Fuzzing with Generators (A Class for Integrating Constraints)](GeneratorGrammarFuzzer.ipynb#A-Class-for-Integrating-Constraints)
# * `exp_pre_expansion_function()` &mdash; [Fuzzing with Generators (A Class for Integrating Constraints)](GeneratorGrammarFuzzer.ipynb#A-Class-for-Integrating-Constraints)
# * `exp_prob()` &mdash; [Probabilistic Grammar Fuzzing (Specifying Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Specifying-Probabilities)
# * `exp_probabilities()` &mdash; [Probabilistic Grammar Fuzzing (Distributing Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Distributing-Probabilities)
# * `exp_string()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `opts()`)](Grammars.ipynb#Excursion:-Implementing-`opts()`)
# * `extended_nonterminals()` &mdash; [Fuzzing with Grammars (Expanding Operators)](Grammars.ipynb#Expanding-Operators)
# * `extend_grammar()` &mdash; [Fuzzing with Grammars (Extending Grammars)](Grammars.ipynb#Extending-Grammars)
# * `extract_a_node()` &mdash; [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * `extract_a_tree()` &mdash; [Parsing Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser)
# * `extract_constraints()` &mdash; [Symbolic Fuzzing (Extracting All Constraints)](SymbolicFuzzer.ipynb#Extracting-All-Constraints), [Symbolic Fuzzing (Check Before You Loop)](SymbolicFuzzer.ipynb#Check-Before-You-Loop)
# * `extract_node()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`)
# * `extract_trees()` &mdash; [Parsing Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing Inputs (Ambiguous Parsing)](Parser.ipynb#Ambiguous-Parsing), [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser)
# * `extract_vars()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * extremely efficient &mdash; [Greybox Fuzzing (Directed Power Schedule)](GreyboxFuzzer.ipynb#Directed-Power-Schedule)
# * `E_GRAMMAR_1` &mdash; [Parsing Inputs (The Aycock Epsilon Fix)](Parser.ipynb#The-Aycock-Epsilon-Fix)

# %% [markdown]
# ## F - J

# %% [markdown]
# ### F
#
# * factorial value &mdash; [Concolic Fuzzing (Tracking Constraints)](ConcolicFuzzer.ipynb#Tracking-Constraints)
# * `factorial()` &mdash; [Concolic Fuzzing (Tracking Constraints)](ConcolicFuzzer.ipynb#Tracking-Constraints), [Concolic Fuzzing (Example: Binomial Coefficient)](ConcolicFuzzer.ipynb#Example:-Binomial-Coefficient)
# * `fail_test()` &mdash; [Error Handling (Catching Errors)](ExpectError.ipynb#Catching-Errors)
# * `FAIL` &mdash; [Fuzzing: Breaking Things with Random Inputs (Synopsis)](Fuzzer.ipynb#Synopsis), [Fuzzing: Breaking Things with Random Inputs (Synopsis)](Fuzzer.ipynb#Synopsis), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runners)](Fuzzer.ipynb#Runners), [Fuzzing: Breaking Things with Random Inputs (Runners)](Fuzzer.ipynb#Runners), [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis), [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis), [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis), [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis), [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis), [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis)
# * `FasterGrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Exercise 1: Caching Method Results)](GrammarFuzzer.ipynb#Exercise-1:-Caching-Method-Results)
# * `fib()` &mdash; [Control Flow Graph (fib)](ControlFlow.ipynb#fib)
# * `FILE` &mdash; [Fuzzing: Breaking Things with Random Inputs (Creating Input Files)](Fuzzer.ipynb#Creating-Input-Files)
# * `fill()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `fill_chart()` &mdash; [Parsing Inputs (Filling the Chart)](Parser.ipynb#Filling-the-Chart)
# * `FilteredLeoParser` class &mdash; [Parsing Inputs (Exercise 6: Filtered Earley Parser)](Parser.ipynb#Exercise-6:-Filtered-Earley-Parser)
# * `FINAL_STATE` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `find()` &mdash; [Concolic Fuzzing (Finding Substrings)](ConcolicFuzzer.ipynb#Finding-Substrings)
# * `find_alternatives()` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * `find_comma()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `find_contents()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `find_element()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `find_executable()` &mdash; [Testing Configurations (Autopep8 Setup)](ConfigurationFuzzer.ipynb#Autopep8-Setup)
# * `find_expansion()` &mdash; [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion)
# * `find_grammar()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `_find_reachable_nonterminals()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `is_valid_grammar()`)](Grammars.ipynb#Excursion:-Implementing-`is_valid_grammar()`)
# * `finish()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations)
# * `finished()` &mdash; [Parsing Inputs (Items)](Parser.ipynb#Items), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * Finite Neighborhood Hypothesis &mdash; [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults)
# * finite state machine &mdash; [Testing Graphical User Interfaces (User Interfaces as Finite State Machines)](GUIFuzzer.ipynb#User-Interfaces-as-Finite-State-Machines)
# * finite state machines &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * first &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `firstset()` &mdash; [Parsing Inputs (Exercise 8: First Set of a Nonterminal)](Parser.ipynb#Exercise-8:-First-Set-of-a-Nonterminal)
# * `firstset_()` &mdash; [Parsing Inputs (Exercise 8: First Set of a Nonterminal)](Parser.ipynb#Exercise-8:-First-Set-of-a-Nonterminal)
# * `first_digit_via_log()` &mdash; [Probabilistic Grammar Fuzzing (The Law of Leading Digits)](ProbabilisticGrammarFuzzer.ipynb#The-Law-of-Leading-Digits)
# * `first_digit_via_string()` &mdash; [Probabilistic Grammar Fuzzing (The Law of Leading Digits)](ProbabilisticGrammarFuzzer.ipynb#The-Law-of-Leading-Digits)
# * `first_expr()` &mdash; [Parsing Inputs (Exercise 8: First Set of a Nonterminal)](Parser.ipynb#Exercise-8:-First-Set-of-a-Nonterminal)
# * `first` and `follow` &mdash; [Parsing Inputs (Exercise 8: First Set of a Nonterminal)](Parser.ipynb#Exercise-8:-First-Set-of-a-Nonterminal)
# * fitness &mdash; [Search-Based Fuzzing (Defining a Search Landscape: Fitness functions)](SearchBasedFuzzer.ipynb#Defining-a-Search-Landscape:-Fitness-functions)
# * fitness function &mdash; [Search-Based Fuzzing (Defining a Search Landscape: Fitness functions)](SearchBasedFuzzer.ipynb#Defining-a-Search-Landscape:-Fitness-functions)
# * `fixed_cgi_decode()` &mdash; [Code Coverage (Exercise 1: Fixing `cgi_decode()`)](Coverage.ipynb#Exercise-1:-Fixing-`cgi_decode()`)
# * `fixpoint()` &mdash; [Parsing Inputs (Fixpoint)](Parser.ipynb#Fixpoint)
# * `fix_luhn_checksum()` &mdash; [Fuzzing with Generators (Functions Called After Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-After-Expansion)
# * `flatten()` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `flip_random_character()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Search-Based Fuzzing (Global Search)](SearchBasedFuzzer.ipynb#Global-Search)
# * `FLOAT_BINARY_OPS` &mdash; [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `FLOAT_BOOL_OPS` &mdash; [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `float_grammar_with_range()` &mdash; [Fuzzing APIs (Floats)](APIFuzzer.ipynb#Floats)
# * `FLOAT_GRAMMAR` &mdash; [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis), [Fuzzing APIs (Floats)](APIFuzzer.ipynb#Floats), [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis)
# * `fmt()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `followset()` &mdash; [Parsing Inputs (Exercise 9: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-9:-Follow-Set-of-a-Nonterminal)
# * `followset_()` &mdash; [Parsing Inputs (Exercise 9: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-9:-Follow-Set-of-a-Nonterminal)
# * `follow_link()` &mdash; [Testing Graphical User Interfaces (Link Element Actions)](GUIFuzzer.ipynb#Link-Element-Actions)
# * `foo()` &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy), [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy), [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)
# * for-loop &mdash; [Control Flow Graph (fib)](ControlFlow.ipynb#fib)
# * `forest()` &mdash; [Parsing Inputs (Parsing Forests)](Parser.ipynb#Parsing-Forests), [Parsing Inputs (Exercise 6: Filtered Earley Parser)](Parser.ipynb#Exercise-6:-Filtered-Earley-Parser)
# * formal languages &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages), [Fuzzing with Grammars (A Natural Language Grammar)](Grammars.ipynb#A-Natural-Language-Grammar)
# * `format()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * FormatFuzzer &mdash; [Greybox Fuzzing with Grammars (Background)](GreyboxGrammarFuzzer.ipynb#Background)
# * `FormHTMLParser` class &mdash; [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields), [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields), [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields)
# * fragment &mdash; [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool), [Greybox Fuzzing with Grammars (Lessons Learned)](GreyboxGrammarFuzzer.ipynb#Lessons-Learned)
# * `FragmentMutator` class &mdash; [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool), [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool), [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation)
# * `fragments()` &mdash; [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker)
# * `FRAGMENT_LEN` &mdash; [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `frame_module()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `fresh_name()` &mdash; [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names)
# * `fsm_diagram()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `fsm_last_state_symbol()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `fsm_path()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `FunctionCoverageRunner` class &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `FunctionRunner` class &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `functions_with_invariants()` &mdash; [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `functions_with_invariants_ast()` &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `function_names()` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * `function_symbol()` &mdash; [Carving Unit Tests (A Grammar from Calls)](Carver.ipynb#A-Grammar-from-Calls)
# * `function_with_invariants()` &mdash; [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `function_with_invariants_ast()` &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `funct_parser()` &mdash; [Fuzzing with Grammars (Exercise 4: Defining Grammars as Functions (Advanced))](Grammars.ipynb#Exercise-4:-Defining-Grammars-as-Functions-(Advanced))
# * fuzz &mdash; [Mutation Analysis (Seeding Artificial Faults with Mutation Analysis)](MutationAnalysis.ipynb#Seeding-Artificial-Faults-with-Mutation-Analysis)
# * `fuzz()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing), [Efficient Grammar Fuzzing (Putting it all Together)](GrammarFuzzer.ipynb#Putting-it-all-Together), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer), [Concolic Fuzzing (The fuzzing method)](ConcolicFuzzer.ipynb#The-fuzzing-method), [Concolic Fuzzing (Pruning and Updating)](ConcolicFuzzer.ipynb#Pruning-and-Updating), [Symbolic Fuzzing (Fuzzing with Simple Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Simple-Symbolic-Fuzzer)
# * `fuzzed_url_element()` &mdash; [Fuzzing APIs (Synthesizing Oracles)](APIFuzzer.ipynb#Synthesizing-Oracles)
# * fuzzer &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * `fuzzer()` &mdash; [Fuzzing: Breaking Things with Random Inputs (A Simple Fuzzer)](Fuzzer.ipynb#A-Simple-Fuzzer)
# * `Fuzzer` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * fuzzing &mdash; [Fuzzing: Breaking Things with Random Inputs](Fuzzer.ipynb#Fuzzing:-Breaking-Things-with Random Inputs), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG)
# * fuzzingbook.org &mdash; [Carving Unit Tests (System Tests vs Unit Tests)](Carver.ipynb#System-Tests-vs-Unit-Tests), [Testing Graphical User Interfaces (Exploring Large Sites)](GUIFuzzer.ipynb#Exploring-Large-Sites)
# * `FUZZINGBOOK_SWAG` &mdash; [Testing Web Applications (Taking Orders)](WebFuzzer.ipynb#Taking-Orders), [Testing Web Applications (Taking Orders)](WebFuzzer.ipynb#Taking-Orders), [Testing Web Applications (Taking Orders)](WebFuzzer.ipynb#Taking-Orders)
# * FuzzManager &mdash; [Fuzzing in the Large (Running a Crash Server)](FuzzingInTheLarge.ipynb#Running-a-Crash-Server), [Fuzzing in the Large (Excursion: Setting up the Server)](FuzzingInTheLarge.ipynb#Excursion:-Setting-up-the-Server)
# * FuzzManager coverage page &mdash; [Fuzzing in the Large (Collecting Code Coverage)](FuzzingInTheLarge.ipynb#Collecting-Code-Coverage)
# * FuzzManager crashes page &mdash; [Fuzzing in the Large (End of Excursion)](FuzzingInTheLarge.ipynb#End-of-Excursion)
# * FuzzManager](https://github.com/MozillaSecurity/FuzzManager).  Its [GitHub page &mdash; [Fuzzing in the Large (Background)](FuzzingInTheLarge.ipynb#Background)
# * `fuzz_tree()` &mdash; [Efficient Grammar Fuzzing (Putting it all Together)](GrammarFuzzer.ipynb#Putting-it-all-Together), [Fuzzing with Generators (Support for Python Generators)](GeneratorGrammarFuzzer.ipynb#Support-for-Python-Generators), [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion), [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing), [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer)

# %% [markdown]
# ### G
#
# * gcd &mdash; [Symbolic Fuzzing (Fuzzing with Advanced Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Advanced-Symbolic-Fuzzer)
# * `gcd()` &mdash; [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations), [Symbolic Fuzzing (Problems with the Simple Fuzzer)](SymbolicFuzzer.ipynb#Problems-with-the-Simple-Fuzzer), [Control Flow Graph (gcd)](ControlFlow.ipynb#gcd)
# * geckodriver program &mdash; [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium)
# * `generate_good_tile()` &mdash; [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * `generate_maze_code()` &mdash; [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * `generate_mutant()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `generate_print_maze()` &mdash; [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * `generate_target_tile()` &mdash; [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * `generate_trap_tile()` &mdash; [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * generation-based &mdash; [Greybox Fuzzing (Greybox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Greybox-Mutation-based-Fuzzing)
# * generator function in Python &mdash; [Fuzzing with Generators (Support for Python Generators)](GeneratorGrammarFuzzer.ipynb#Support-for-Python-Generators)
# * `GeneratorGrammarFuzzer` class &mdash; [Fuzzing with Generators (A Class for Integrating Constraints)](GeneratorGrammarFuzzer.ipynb#A-Class-for-Integrating-Constraints), [Fuzzing with Generators (Generating Elements before Expansion)](GeneratorGrammarFuzzer.ipynb#Generating-Elements-before-Expansion), [Fuzzing with Generators (Generating Elements before Expansion)](GeneratorGrammarFuzzer.ipynb#Generating-Elements-before-Expansion), [Fuzzing with Generators (Support for Python Generators)](GeneratorGrammarFuzzer.ipynb#Support-for-Python-Generators), [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion), [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion), [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion), [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion), [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing), [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing), [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing), [Fuzzing with Generators (Ordering Expansions)](GeneratorGrammarFuzzer.ipynb#Ordering-Expansions)
# * `GenericTimeout` class &mdash; [Timeout (Variant 2: Generic / Windows (using trace, not very efficient))](Timeout.ipynb#Variant-2:-Generic-/-Windows-(using-trace,-not-very-efficient))
# * Genetic Algorithm &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * `genetic_algorithm()` &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * `gen_cfg()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (Supporting Functions)](ControlFlow.ipynb#Supporting-Functions)
# * `gen_fn_summary()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * Geometric Mean &mdash; [Greybox Fuzzing (Computing Function-Level Distance)](GreyboxFuzzer.ipynb#Computing-Function-Level-Distance)
# * `__getFunctions__()` &mdash; [Greybox Fuzzing (Directed Power Schedule)](GreyboxFuzzer.ipynb#Directed-Power-Schedule)
# * `__getitem__()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Tracking Information Flow (Index)](InformationFlow.ipynb#Index), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (Producing Substrings)](ConcolicFuzzer.ipynb#Producing-Substrings), [Testing Configurations (Part 3: Mine a Configuration Grammar)](ConfigurationFuzzer.ipynb#Part-3:-Mine-a-Configuration-Grammar)
# * `getPathID()` &mdash; [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing)
# * `getTraceHash()` &mdash; [When To Stop Fuzzing (Trace Coverage)](WhenToStopFuzzing.ipynb#Trace-Coverage)
# * `get_all_paths()` &mdash; [Symbolic Fuzzing (Generating All Possible Paths)](SymbolicFuzzer.ipynb#Generating-All-Possible-Paths), [Symbolic Fuzzing (Generating All Paths)](SymbolicFuzzer.ipynb#Generating-All-Paths), [Symbolic Fuzzing (Exercise 2: Statically checking if a loop should be unrolled further)](SymbolicFuzzer.ipynb#Exercise-2:-Statically-checking-if-a-loop-should-be-unrolled-further), [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer)
# * `get_all_vars()` &mdash; [Concolic Fuzzing (Hack to use the ASCII value of a character.)](ConcolicFuzzer.ipynb#Hack-to-use-the-ASCII-value-of-a-character.)
# * `get_alternatives()` &mdash; [Fuzzing with Grammars (Exercise 4: Defining Grammars as Functions (Advanced))](Grammars.ipynb#Exercise-4:-Defining-Grammars-as-Functions-(Advanced))
# * `get_annotations()` &mdash; [Symbolic Fuzzing (The Control Flow Graph)](SymbolicFuzzer.ipynb#The-Control-Flow-Graph)
# * `get_arguments()` &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `get_callgraph()` &mdash; [Control Flow Graph (Call Graph Helpers)](ControlFlow.ipynb#Call-Graph-Helpers)
# * `get_cfg()` &mdash; [Control Flow Graph (Supporting Functions)](ControlFlow.ipynb#Supporting-Functions)
# * `get_children()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * `get_defining_function()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `get_derivation_tree()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `get_expression()` &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * `get_field_values()` &mdash; [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders)
# * `get_fitness()` &mdash; [Search-Based Fuzzing (Instrumentation)](SearchBasedFuzzer.ipynb#Instrumentation)
# * `get_fitness_cgi()` &mdash; [Search-Based Fuzzing (Fitness Function to Create Valid Hexadecimal Inputs)](SearchBasedFuzzer.ipynb#Fitness-Function-to-Create-Valid-Hexadecimal-Inputs)
# * `get_func()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `get_grammar()` &mdash; [Testing Web Applications (A Fuzzer for Web Forms)](WebFuzzer.ipynb#A-Fuzzer-for-Web-Forms), [Testing Web Applications (Fully Automatic Web Attacks)](WebFuzzer.ipynb#Fully-Automatic-Web-Attacks)
# * `get_html()` &mdash; [Testing Web Applications (A Fuzzer for Web Forms)](WebFuzzer.ipynb#A-Fuzzer-for-Web-Forms)
# * `get_mutation_count()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `get_newpath()` &mdash; [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class)
# * `get_next_path()` &mdash; [Symbolic Fuzzing (Fuzzing with Simple Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Simple-Symbolic-Fuzzer), [Symbolic Fuzzing (Generating All Paths)](SymbolicFuzzer.ipynb#Generating-All-Paths)
# * `get_path_to_root()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Symbolic Fuzzing (Stepwise Exploration of Paths)](SymbolicFuzzer.ipynb#Stepwise-Exploration-of-Paths)
# * `get_qualified_name()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `get_registry()` &mdash; [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry)
# * `get_registry_idx()` &mdash; [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry)
# * `get_replacements()` &mdash; [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining)
# * `get_symbolicparams()` &mdash; [Symbolic Fuzzing (The Control Flow Graph)](SymbolicFuzzer.ipynb#The-Control-Flow-Graph)
# * `get_top()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `GET` &mdash; [Testing Web Applications (Handling HTTP Requests)](WebFuzzer.ipynb#Handling-HTTP-Requests), [Testing Web Applications (Other HTTP commands)](WebFuzzer.ipynb#Other-HTTP-commands), [Testing Web Applications (A Fuzzer for Web Forms)](WebFuzzer.ipynb#A-Fuzzer-for-Web-Forms)
# * `__ge__()` &mdash; [Concolic Fuzzing (Comparisons between Integers)](ConcolicFuzzer.ipynb#Comparisons-between-Integers)
# * globally &mdash; [Search-Based Fuzzing (Global Search)](SearchBasedFuzzer.ipynb#Global-Search)
# * GNU bc &mdash; [Mutation-Based Fuzzing (Part 2: Guided Mutations)](MutationFuzzer.ipynb#Part-2:-Guided-Mutations)
# * grammar constructors &mdash; [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis), [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis)
# * grammar fuzzing &mdash; [Fuzzing with Grammars (Arithmetic Expressions)](Grammars.ipynb#Arithmetic-Expressions)
# * `grammar()` &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `GrammarCoverageFuzzer` class &mdash; [Grammar Coverage (Determining yet Uncovered Children)](GrammarCoverageFuzzer.ipynb#Determining-yet-Uncovered-Children), [Grammar Coverage (Excursion: Implementing `new_coverage()`)](GrammarCoverageFuzzer.ipynb#Excursion:-Implementing-`new_coverage()`), [Grammar Coverage (Excursion: Implementing `choose_node_expansion()`)](GrammarCoverageFuzzer.ipynb#Excursion:-Implementing-`choose_node_expansion()`)
# * `GrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Excursion: `check_grammar()` implementation)](GrammarFuzzer.ipynb#Excursion:-`check_grammar()`-implementation), [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion), [Efficient Grammar Fuzzing (Picking a Children Alternative to be Expanded)](GrammarFuzzer.ipynb#Picking-a-Children-Alternative-to-be-Expanded), [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion), [Efficient Grammar Fuzzing (Excursion: `expand_node_randomly()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_randomly()`-implementation), [Efficient Grammar Fuzzing (Excursion: `expand_node_randomly()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_randomly()`-implementation), [Efficient Grammar Fuzzing (Excursion: `expand_node_randomly()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_randomly()`-implementation), [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree), [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree), [Efficient Grammar Fuzzing (Excursion: `expand_tree_once()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_tree_once()`-implementation), [Efficient Grammar Fuzzing (Excursion: Implementing Cost Functions)](GrammarFuzzer.ipynb#Excursion:-Implementing-Cost-Functions), [Efficient Grammar Fuzzing (Excursion: `expand_node_by_cost()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_by_cost()`-implementation), [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion), [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion), [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation), [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation), [Efficient Grammar Fuzzing (Excursion: Implementation of three-phase `expand_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementation-of-three-phase-`expand_tree()`), [Efficient Grammar Fuzzing (Putting it all Together)](GrammarFuzzer.ipynb#Putting-it-all-Together)
# * Grammarinator &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `GrammarMiner` class &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Recover Grammar)](GrammarMiner.ipynb#Recover-Grammar)
# * `GrammarReducer` class &mdash; [Reducing Failure-Inducing Inputs (Excursion: A Class for Reducing with Grammars)](Reducer.ipynb#Excursion:-A-Class-for-Reducing-with-Grammars), [Reducing Failure-Inducing Inputs (Finding Subtrees)](Reducer.ipynb#Finding-Subtrees), [Reducing Failure-Inducing Inputs (Alternate Expansions)](Reducer.ipynb#Alternate-Expansions), [Reducing Failure-Inducing Inputs (Both Strategies Together)](Reducer.ipynb#Both-Strategies-Together), [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy), [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy), [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy), [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy), [Reducing Failure-Inducing Inputs (A Depth-Oriented Strategy)](Reducer.ipynb#A-Depth-Oriented-Strategy)
# * grammars &mdash; [Fuzzing with Grammars (Grammars)](Grammars.ipynb#Grammars)
# * `graph_attr()` &mdash; [Efficient Grammar Fuzzing (Excursion: Source code and example for `display_annotated_tree()`)](GrammarFuzzer.ipynb#Excursion:-Source-code-and-example-for-`display_annotated_tree()`)
# * greybox fuzzer &mdash; [Greybox Fuzzing (AFL: An Effective Greybox Fuzzer)](GreyboxFuzzer.ipynb#AFL:-An-Effective-Greybox-Fuzzer), [Greybox Fuzzing (Lessons Learned)](GreyboxFuzzer.ipynb#Lessons-Learned)
# * `GreyboxFuzzer` class &mdash; [Greybox Fuzzing (Greybox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Greybox-Mutation-based-Fuzzing)
# * `GreyboxGrammarFuzzer` class &mdash; [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing)
# * `__gt__()` &mdash; [Concolic Fuzzing (Comparisons between Integers)](ConcolicFuzzer.ipynb#Comparisons-between-Integers)
# * GUI Ripping &mdash; [Testing Graphical User Interfaces (Background)](GUIFuzzer.ipynb#Background)
# * `GUICoverageFuzzer` class &mdash; [Testing Graphical User Interfaces (Covering States)](GUIFuzzer.ipynb#Covering-States), [Testing Graphical User Interfaces (Covering States)](GUIFuzzer.ipynb#Covering-States)
# * `GUIFuzzer` class &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `GUIGrammarMiner` class &mdash; [Testing Graphical User Interfaces (Retrieving Actions)](GUIFuzzer.ipynb#Retrieving-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Retrieving Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Retrieving-Actions), [Testing Graphical User Interfaces (Input Element Actions)](GUIFuzzer.ipynb#Input-Element-Actions), [Testing Graphical User Interfaces (Button Element Actions)](GUIFuzzer.ipynb#Button-Element-Actions), [Testing Graphical User Interfaces (Link Element Actions)](GUIFuzzer.ipynb#Link-Element-Actions), [Testing Graphical User Interfaces (Link Element Actions)](GUIFuzzer.ipynb#Link-Element-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars), [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `GUIRunner` class &mdash; [Testing Graphical User Interfaces (Executing User Interface Actions)](GUIFuzzer.ipynb#Executing-User-Interface-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `GUI_GRAMMAR` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)

# %% [markdown]
# ### H
#
# * `h()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `handle_endtag()` &mdash; [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields)
# * `handle_order()` &mdash; [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders), [Testing Web Applications (Part 4: A Robust Server)](WebFuzzer.ipynb#Part-4:-A-Robust-Server)
# * `handle_starttag()` &mdash; [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields), [Testing Web Applications (Crawling User Interfaces)](WebFuzzer.ipynb#Crawling-User-Interfaces)
# * `hang_if_no_space()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks), [Concolic Fuzzing (Excursion: Implementing SimpleConcolicFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-SimpleConcolicFuzzer)
# * `__hash__()` &mdash; [Parsing Inputs (States)](Parser.ipynb#States)
# * `has_origin()` &mdash; [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins)
# * `has_taint()` &mdash; [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins)
# * HDD &mdash; [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)
# * `HEADLESS` &mdash; [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium), [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium)
# * `HEAD` &mdash; [Testing Web Applications (Other HTTP commands)](WebFuzzer.ipynb#Other-HTTP-commands)
# * heartbeat &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * `heartbeat()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Information Leaks)](Fuzzer.ipynb#Information-Leaks)
# * HeartBleed announcement page &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * HeartBleed bug &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * `hello()` &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls)
# * `helper()` &mdash; [Parsing Inputs (Fixpoint)](Parser.ipynb#Fixpoint)
# * heuristic &mdash; [Search-Based Fuzzing](SearchBasedFuzzer.ipynb#Search-Based-Fuzzing)
# * Hierarchical Delta Debugging &mdash; [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)
# * higher coverage &mdash; [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing)
# * `highlight_node()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * highly accurate &mdash; [When To Stop Fuzzing (Evaluating the Discovery Probability Estimate)](WhenToStopFuzzing.ipynb#Evaluating-the-Discovery-Probability-Estimate)
# * `high_charge()` &mdash; [Fuzzing with Generators (Functions Called Before Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-Before-Expansion)
# * `hillclimber()` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `hillclimb_cgi()` &mdash; [Search-Based Fuzzing (Hillclimbing Valid Hexadecimal Inputs)](SearchBasedFuzzer.ipynb#Hillclimbing-Valid-Hexadecimal-Inputs)
# * `hillclimb_cgi_limited()` &mdash; [Search-Based Fuzzing (Evolutionary Search)](SearchBasedFuzzer.ipynb#Evolutionary-Search)
# * `hl_node()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `hl_predicate()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * hook into `__new__()` &mdash; [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings)
# * `HorizontalChoice` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * HTML injection &mdash; [Testing Web Applications (HTML Injection Attacks)](WebFuzzer.ipynb#HTML-Injection-Attacks)
# * HTML parser &mdash; [Greybox Fuzzing (A Complex Example: HTMLParser)](GreyboxFuzzer.ipynb#A-Complex-Example:-HTMLParser)
# * `HTMLGrammarMiner` class &mdash; [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields), [Testing Web Applications (Mining Grammars for Web Pages)](WebFuzzer.ipynb#Mining-Grammars-for-Web-Pages), [Testing Web Applications (Mining Grammars for Web Pages)](WebFuzzer.ipynb#Mining-Grammars-for-Web-Pages)
# * HTMLParser &mdash; [When To Stop Fuzzing (Measuring Trace Coverage over Time)](WhenToStopFuzzing.ipynb#Measuring-Trace-Coverage-over-Time)
# * `HTML_INTERNAL_SERVER_ERROR` &mdash; [Testing Web Applications (Internal Errors)](WebFuzzer.ipynb#Internal-Errors)
# * `HTML_NOT_FOUND` &mdash; [Testing Web Applications (Page Not Found)](WebFuzzer.ipynb#Page-Not-Found)
# * `HTML_ORDER_FORM` &mdash; [Testing Web Applications (Taking Orders)](WebFuzzer.ipynb#Taking-Orders)
# * `HTML_ORDER_RECEIVED` &mdash; [Testing Web Applications (Order Confirmation)](WebFuzzer.ipynb#Order-Confirmation)
# * `html_parser()` &mdash; [When To Stop Fuzzing (Part 2: Population)](WhenToStopFuzzing.ipynb#Part-2:-Population)
# * `HTML_TERMS_AND_CONDITIONS` &mdash; [Testing Web Applications (Terms and Conditions)](WebFuzzer.ipynb#Terms-and-Conditions)
# * `HTTPD_MESSAGE_QUEUE` &mdash; [Testing Web Applications (Logging)](WebFuzzer.ipynb#Logging)
# * `http_program()` &mdash; [Mutation-Based Fuzzing (Fuzzing a URL Parser)](MutationFuzzer.ipynb#Fuzzing-a-URL-Parser)
# * `hundred_inputs()` &mdash; [Code Coverage ( Coverage of Basic Fuzzing)](Coverage.ipynb#-Coverage-of-Basic-Fuzzing)
# * hypothesis package &mdash; [Fuzzing APIs (Background)](APIFuzzer.ipynb#Background)
# * Hypothesis](https://hypothesis.works) fuzzer has a number of type-specific shrinking strategies; this [blog article &mdash; [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)

# %% [markdown]
# ### I
#
# * `i()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `identifiers_with_types()` &mdash; [Symbolic Fuzzing (Check Before You Loop)](SymbolicFuzzer.ipynb#Check-Before-You-Loop)
# * `identifier_grammar_fn()` &mdash; [Fuzzing with Grammars (Part 2: Extended Grammars)](Grammars.ipynb#Part-2:-Extended-Grammars)
# * `idx()` &mdash; [Parsing Inputs (States)](Parser.ipynb#States)
# * `ID` &mdash; [Fuzzing with Constraints (Matching Expansion Elements)](FuzzingWithConstraints.ipynb#Matching-Expansion-Elements)
# * IF &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `ignored()` &mdash; [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * immediate &mdash; [Fuzzing with Constraints (Accessing Elements)](FuzzingWithConstraints.ipynb#Accessing-Elements)
# * immutable &mdash; [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings)
# * `import_code()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * in order &mdash; [Parsing Inputs (Unify Key)](Parser.ipynb#Unify-Key)
# * in the same method invocation &mdash; [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations)
# * in this very popular XKCD comic &mdash; [Testing Web Applications (SQL Injection Attacks)](WebFuzzer.ipynb#SQL-Injection-Attacks)
# * in-memory database &mdash; [Tracking Information Flow (A Vulnerable Database)](InformationFlow.ipynb#A-Vulnerable-Database)
# * incidence frequency &mdash; [When To Stop Fuzzing (Exercises)](WhenToStopFuzzing.ipynb#Exercises)
# * `increment()` &mdash; [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * `indent()` &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack)
# * `ineffective_test_1()` &mdash; [Mutation Analysis (Why Structural Coverage is Not Enough)](MutationAnalysis.ipynb#Why-Structural-Coverage-is-Not-Enough)
# * `ineffective_test_2()` &mdash; [Mutation Analysis (Why Structural Coverage is Not Enough)](MutationAnalysis.ipynb#Why-Structural-Coverage-is-Not-Enough)
# * inferring loop invariants &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * `informationflow_init_1()` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators)
# * `informationflow_init_2()` &mdash; [Tracking Information Flow (General wrappers)](InformationFlow.ipynb#General-wrappers)
# * `informationflow_init_3()` &mdash; [Tracking Information Flow (Methods yet to be translated)](InformationFlow.ipynb#Methods-yet-to-be-translated)
# * inherit &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `initialize()` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators), [Concolic Fuzzing (Binary Operators for Integers)](ConcolicFuzzer.ipynb#Binary-Operators-for-Integers)
# * `INITIALIZER_LIST` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators)
# * `initial_grammar()` &mdash; [Carving Unit Tests (Initial Grammar)](Carver.ipynb#Initial-Grammar)
# * `init_concolic_1()` &mdash; [Concolic Fuzzing (Binary Operators for Integers)](ConcolicFuzzer.ipynb#Binary-Operators-for-Integers)
# * `init_concolic_2()` &mdash; [Concolic Fuzzing (Integer Unary Operators)](ConcolicFuzzer.ipynb#Integer-Unary-Operators)
# * `init_concolic_3()` &mdash; [Concolic Fuzzing (Trip Wire)](ConcolicFuzzer.ipynb#Trip-Wire)
# * `init_concolic_4()` &mdash; [Concolic Fuzzing (Exercise 2: Bit Manipulation)](ConcolicFuzzer.ipynb#Exercise-2:-Bit-Manipulation)
# * `init_db()` &mdash; [Testing Web Applications (Storing Orders)](WebFuzzer.ipynb#Storing-Orders)
# * `init_tainted_grammar()` &mdash; [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer)
# * `init_tree()` &mdash; [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion)
# * `__init__()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Exercise 2: Run Simulated Troff)](Fuzzer.ipynb#Exercise-2:-Run-Simulated-Troff), [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules), [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules), [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing), [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing), [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt), [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt), [Greybox Fuzzing (Directed Power Schedule)](GreyboxFuzzer.ipynb#Directed-Power-Schedule), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Exercise 1: Caching Method Results)](GrammarFuzzer.ipynb#Exercise-1:-Caching-Method-Results), [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation), [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage), [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?), [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class), [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars), [Parsing Inputs (Columns)](Parser.ipynb#Columns), [Parsing Inputs (Items)](Parser.ipynb#Items), [Parsing Inputs (States)](Parser.ipynb#States), [Parsing Inputs (The Parsing Algorithm)](Parser.ipynb#The-Parsing-Algorithm), [Parsing Inputs (Nullable)](Parser.ipynb#Nullable), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions), [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing), [Fuzzing with Generators (Generators and Probabilistic Fuzzing)](GeneratorGrammarFuzzer.ipynb#Generators-and-Probabilistic-Fuzzing), [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage), [Greybox Fuzzing with Grammars (Fuzzing with Dictionaries)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Dictionaries), [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool), [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing), [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation), [Greybox Fuzzing with Grammars (Focusing on Valid Seeds)](GreyboxGrammarFuzzer.ipynb#Focusing-on-Valid-Seeds), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Lexical Reduction vs. Syntactic Rules)](Reducer.ipynb#Lexical-Reduction-vs.-Syntactic-Rules), [Reducing Failure-Inducing Inputs (Excursion: A Class for Reducing with Grammars)](Reducer.ipynb#Excursion:-A-Class-for-Reducing-with-Grammars), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Mining Input Grammars (Vars)](GrammarMiner.ipynb#Vars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Scope Tracker)](GrammarMiner.ipynb#Scope-Tracker), [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects), [Tracking Information Flow (A Vulnerable Database)](InformationFlow.ipynb#A-Vulnerable-Database), [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (Taint Aware Fuzzing)](InformationFlow.ipynb#Taint-Aware-Fuzzing), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (Slices)](InformationFlow.ipynb#Slices), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer), [Tracking Information Flow (Part 1: Creation)](InformationFlow.ipynb#Part-1:-Creation), [Tracking Information Flow (Part 4: Passing taints from strings to integers)](InformationFlow.ipynb#Part-4:-Passing-taints-from-strings-to-integers), [Concolic Fuzzing (Excursion: Implementing ConcolicTracer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicTracer), [Concolic Fuzzing (A Proxy Class for Booleans)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Booleans), [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (A Proxy Class for Strings)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Strings), [Concolic Fuzzing (An Iterator Class for Strings)](ConcolicFuzzer.ipynb#An-Iterator-Class-for-Strings), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Tracking Assignments)](SymbolicFuzzer.ipynb#Tracking-Assignments), [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types), [Mining Function Specifications (Extracting Invariants)](DynamicInvariants.ipynb#Extracting-Invariants), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Carving Unit Tests (A Grammar Miner for Calls)](Carver.ipynb#A-Grammar-Miner-for-Calls), [Testing Web Applications (Fuzzing with Unexpected Values)](WebFuzzer.ipynb#Fuzzing-with-Unexpected-Values), [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields), [Testing Web Applications (A Fuzzer for Web Forms)](WebFuzzer.ipynb#A-Fuzzer-for-Web-Forms), [Testing Web Applications (Fully Automatic Web Attacks)](WebFuzzer.ipynb#Fully-Automatic-Web-Attacks), [Testing Web Applications (Fully Automatic Web Attacks)](WebFuzzer.ipynb#Fully-Automatic-Web-Attacks), [Testing Graphical User Interfaces (Retrieving Actions)](GUIFuzzer.ipynb#Retrieving-Actions), [Testing Graphical User Interfaces (Executing User Interface Actions)](GUIFuzzer.ipynb#Executing-User-Interface-Actions), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Covering States)](GUIFuzzer.ipynb#Covering-States), [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma), [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma), [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations), [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations), [Error Handling (Catching Errors)](ExpectError.ipynb#Catching-Errors), [Error Handling (Catching Timeouts)](ExpectError.ipynb#Catching-Timeouts), [Timer (Measuring Time)](Timer.ipynb#Measuring-Time), [Timeout (Variant 1: Unix (using signals, efficient))](Timeout.ipynb#Variant-1:-Unix-(using-signals,-efficient)), [Timeout (Variant 2: Generic / Windows (using trace, not very efficient))](Timeout.ipynb#Variant-2:-Generic-/-Windows-(using-trace,-not-very-efficient)), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * "Input Invariants" &mdash; [Fuzzing with Constraints (Background)](FuzzingWithConstraints.ipynb#Background)
# * input string &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `InputStack` class &mdash; [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack)
# * `insert_assertions()` &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `insert_from_dictionary()` &mdash; [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt), [Greybox Fuzzing with Grammars (Fuzzing with Dictionaries)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Dictionaries)
# * `insert_into_tree()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `insert_random_character()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators)
# * `INSERT` &mdash; [Testing Web Applications (Storing Orders)](WebFuzzer.ipynb#Storing-Orders), [Testing Web Applications (SQL Injection Attacks)](WebFuzzer.ipynb#SQL-Injection-Attacks)
# * `instantiate_prop()` &mdash; [Mining Function Specifications (Instantiating Properties)](DynamicInvariants.ipynb#Instantiating-Properties)
# * `instantiate_prop_ast()` &mdash; [Mining Function Specifications (Instantiating Properties)](DynamicInvariants.ipynb#Instantiating-Properties)
# * instrumentation &mdash; [Search-Based Fuzzing (Instrumentation)](SearchBasedFuzzer.ipynb#Instrumentation)
# * `INTERNAL_ALIGNMENT` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `internal_msg2key()` &mdash; [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma)
# * `internal_server_error()` &mdash; [Testing Web Applications (Internal Errors)](WebFuzzer.ipynb#Internal-Errors), [Testing Web Applications (Part 1: Silent Failures)](WebFuzzer.ipynb#Part-1:-Silent-Failures)
# * `INT_BINARY_OPS` &mdash; [Concolic Fuzzing (Binary Operators for Integers)](ConcolicFuzzer.ipynb#Binary-Operators-for-Integers)
# * `int_grammar_with_range()` &mdash; [Fuzzing APIs (Integers)](APIFuzzer.ipynb#Integers)
# * `INT_GRAMMAR` &mdash; [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis), [Fuzzing APIs (Integers)](APIFuzzer.ipynb#Integers), [Fuzzing APIs (Synopsis)](APIFuzzer.ipynb#Synopsis)
# * `INT_UNARY_OPS` &mdash; [Concolic Fuzzing (Integer Unary Operators)](ConcolicFuzzer.ipynb#Integer-Unary-Operators)
# * `__int__()` &mdash; [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers)
# * invalid &mdash; [Greybox Fuzzing with Grammars (Fuzzing with Input Regions)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Input-Regions)
# * `InvariantAnnotator` class &mdash; [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers), [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers)
# * invariants &mdash; [Mining Function Specifications (Specifying and Checking Invariants)](DynamicInvariants.ipynb#Specifying-and-Checking-Invariants)
# * `invariants()` &mdash; [Mining Function Specifications (Extracting Invariants)](DynamicInvariants.ipynb#Extracting-Invariants)
# * `InvariantTracker` class &mdash; [Mining Function Specifications (Extracting Invariants)](DynamicInvariants.ipynb#Extracting-Invariants), [Mining Function Specifications (Extracting Invariants)](DynamicInvariants.ipynb#Extracting-Invariants)
# * `INVARIANT_PROPERTIES` &mdash; [Mining Function Specifications (Defining Properties)](DynamicInvariants.ipynb#Defining-Properties)
# * `INVENTORY_GRAMMAR_F` &mdash; [Tracking Information Flow (Excursion: Defining a SQL grammar)](InformationFlow.ipynb#Excursion:-Defining-a-SQL-grammar)
# * `INVENTORY_GRAMMAR_NEW` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * `INVENTORY_GRAMMAR` &mdash; [Tracking Information Flow (Excursion: Defining a SQL grammar)](InformationFlow.ipynb#Excursion:-Defining-a-SQL-grammar)
# * `INVENTORY_METHODS` &mdash; [Mining Input Grammars (A Simple Grammar Miner)](GrammarMiner.ipynb#A-Simple-Grammar-Miner)
# * `INVENTORY` &mdash; [Mining Input Grammars (A Grammar Challenge)](GrammarMiner.ipynb#A-Grammar-Challenge), [Tracking Information Flow (A Vulnerable Database)](InformationFlow.ipynb#A-Vulnerable-Database), [Tracking Information Flow (End of Excursion)](InformationFlow.ipynb#End-of-Excursion)
# * inverse &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * `invert_expansion()` &mdash; [Probabilistic Grammar Fuzzing (Testing Uncommon Features)](ProbabilisticGrammarFuzzer.ipynb#Testing-Uncommon-Features)
# * `invert_probs()` &mdash; [Probabilistic Grammar Fuzzing (Testing Uncommon Features)](ProbabilisticGrammarFuzzer.ipynb#Testing-Uncommon-Features)
# * `__invert__()` &mdash; [Concolic Fuzzing (Exercise 2: Bit Manipulation)](ConcolicFuzzer.ipynb#Exercise-2:-Bit-Manipulation)
# * `invoker()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `in_current_record()` &mdash; [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `in_scope()` &mdash; [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack)
# * `IP_ADDRESS_TOKENS` &mdash; [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions)
# * `isascii()` &mdash; [Fuzzing in the Large (Excursion: `escapelines()` implementatipn)](FuzzingInTheLarge.ipynb#Excursion:-`escapelines()`-implementatipn)
# * ISLa &mdash; [Fuzzing with Constraints](FuzzingWithConstraints.ipynb#Fuzzing-with-Constraints), [Fuzzing with Constraints (Specifying Constraints)](FuzzingWithConstraints.ipynb#Specifying-Constraints), [Fuzzing with Constraints (Synopsis)](FuzzingWithConstraints.ipynb#Synopsis)
# * ISLa project &mdash; [Fuzzing with Constraints (Background)](FuzzingWithConstraints.ipynb#Background)
# * `is_abstract()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `is_excluded()` &mdash; [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool)
# * `is_fragment()` &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `is_input_fragment()` &mdash; [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (Scope Tracker)](GrammarMiner.ipynb#Scope-Tracker)
# * `is_local_class()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `is_nonterminal()` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * `is_overloaded()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `is_permutation()` &mdash; [Introduction to Software Testing (Part 2: Random Inputs)](Intro_Testing.ipynb#Part-2:-Random-Inputs)
# * `is_public()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `is_sorted()` &mdash; [Introduction to Software Testing (Part 2: Random Inputs)](Intro_Testing.ipynb#Part-2:-Random-Inputs)
# * `is_valid_grammar()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `is_valid_grammar()`)](Grammars.ipynb#Excursion:-Implementing-`is_valid_grammar()`)
# * `is_valid_probabilistic_grammar()` &mdash; [Probabilistic Grammar Fuzzing (Checking Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Checking-Probabilities)
# * `is_valid_url()` &mdash; [Mutation-Based Fuzzing (Mutating URLs)](MutationFuzzer.ipynb#Mutating-URLs)
# * `is_var()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `is_z3_var()` &mdash; [Concolic Fuzzing (Hack to use the ASCII value of a character.)](ConcolicFuzzer.ipynb#Hack-to-use-the-ASCII-value-of-a-character.)
# * It is inefficient &mdash; [Efficient Grammar Fuzzing (An Insufficient Algorithm)](GrammarFuzzer.ipynb#An-Insufficient-Algorithm)
# * `Item` class &mdash; [Parsing Inputs (Items)](Parser.ipynb#Items), [Parsing Inputs (Items)](Parser.ipynb#Items)
# * iterable &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `iterate()` &mdash; [Fuzzing with Generators (Support for Python Generators)](GeneratorGrammarFuzzer.ipynb#Support-for-Python-Generators)
# * `IterativeEarleyParser` class &mdash; [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser), [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser), [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser)
# * iterator &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * iterator object &mdash; [Fuzzing with Generators (Support for Python Generators)](GeneratorGrammarFuzzer.ipynb#Support-for-Python-Generators)
# * `iter_paths()` &mdash; [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser)
# * `__iter__()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Tracking Information Flow (Slices)](InformationFlow.ipynb#Slices), [Concolic Fuzzing (Producing Substrings)](ConcolicFuzzer.ipynb#Producing-Substrings)

# %% [markdown]
# ### J
#
# * J-Reduce &mdash; [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)
# * JavaScript &mdash; [Testing Web Applications (Cross-Site Scripting Attacks)](WebFuzzer.ipynb#Cross-Site-Scripting-Attacks)
# * JerryScript &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `join()` &mdash; [Tracking Information Flow (Expand Tabs)](InformationFlow.ipynb#Expand-Tabs)
# * `js-vuln-db` &mdash; [Probabilistic Grammar Fuzzing (Exercise 2: Learning from Past Bugs)](ProbabilisticGrammarFuzzer.ipynb#Exercise-2:-Learning-from-Past-Bugs)
# * JSON specification &mdash; [Fuzzing with Grammars (Exercise 1: A JSON Grammar)](Grammars.ipynb#Exercise-1:-A-JSON-Grammar)
# * `JSON_GRAMMAR` &mdash; [Fuzzing with Grammars (Exercise 1: A JSON Grammar)](Grammars.ipynb#Exercise-1:-A-JSON-Grammar)

# %% [markdown]
# ## K - O

# %% [markdown]
# ### K
#
# * Kenngruppenbuch &mdash; [When To Stop Fuzzing (The Enigma Machine)](WhenToStopFuzzing.ipynb#The-Enigma-Machine)
# * keylogger &mdash; [Testing Web Applications (Cross-Site Scripting Attacks)](WebFuzzer.ipynb#Cross-Site-Scripting-Attacks)
# * killed &mdash; [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults)
# * KLEE &mdash; [Symbolic Fuzzing (Background)](SymbolicFuzzer.ipynb#Background)

# %% [markdown]
# ### L
#
# * lambda &mdash; [Fuzzing with Generators (Functions Called Before Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-Before-Expansion)
# * LangFuzz &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `LangFuzzer` class &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Fuzzing)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Fuzzing)
# * language specifications &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `LD_LIBRARY_PATH` &mdash; [Testing Configurations (Part 1: Getopt Fuzzing)](ConfigurationFuzzer.ipynb#Part-1:-Getopt-Fuzzing)
# * leaf &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `leave()` &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Mining Input Grammars (Input Stack)](GrammarMiner.ipynb#Input-Stack)
# * left to right &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `left()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `left_align()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `length()` &mdash; [Concolic Fuzzing (Length of Strings)](ConcolicFuzzer.ipynb#Length-of-Strings)
# * `__len__()` &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Concolic Fuzzing (Length of Strings)](ConcolicFuzzer.ipynb#Length-of-Strings), [Concolic Fuzzing (An Iterator Class for Strings)](ConcolicFuzzer.ipynb#An-Iterator-Class-for-Strings)
# * `LeoParser` class &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `leo_complete()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * less code coverage &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Fuzzing)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Fuzzing)
# * lexer &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * lexing &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * `__le__()` &mdash; [Concolic Fuzzing (Comparisons between Integers)](ConcolicFuzzer.ipynb#Comparisons-between-Integers)
# * line &mdash; [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations)
# * line numbers &mdash; [Mining Input Grammars (Grammar Miner with Reassignment)](GrammarMiner.ipynb#Grammar-Miner-with-Reassignment)
# * `linear_to_tree()` &mdash; [Parsing Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser)
# * `lineno()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `LinkHTMLParser` class &mdash; [Testing Web Applications (Crawling User Interfaces)](WebFuzzer.ipynb#Crawling-User-Interfaces)
# * `link_functions()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * list of all theories defined in SMT-LIB &mdash; [Fuzzing with Constraints (End of Excursion)](FuzzingWithConstraints.ipynb#End-of-Excursion)
# * `list_grammar()` &mdash; [Fuzzing APIs (Lists)](APIFuzzer.ipynb#Lists)
# * `LIST_GRAMMAR` &mdash; [Fuzzing APIs (Lists)](APIFuzzer.ipynb#Lists)
# * `list_length()` &mdash; [Mining Function Specifications (Some Examples)](DynamicInvariants.ipynb#Some-Examples)
# * `ljust()` &mdash; [Tracking Information Flow (Justify)](InformationFlow.ipynb#Justify)
# * LL &mdash; [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `ll()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `LL1Parser` class &mdash; [Parsing Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table), [Parsing Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table), [Parsing Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser)
# * LLVM Address Sanitizer &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * `loc()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * local host &mdash; [Testing Web Applications (Running the Server)](WebFuzzer.ipynb#Running-the-Server)
# * local optimum &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `log_call()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree)
# * `log_event()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `log_message()` &mdash; [Testing Web Applications (Logging)](WebFuzzer.ipynb#Logging)
# * `log_tree()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementation of three-phase `expand_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementation-of-three-phase-`expand_tree()`)
# * `LOG_VALUES` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `LONG_FOO` &mdash; [Testing Configurations (Exercise 1: #ifdef Configuration Fuzzing)](ConfigurationFuzzer.ipynb#Exercise-1:-#ifdef-Configuration-Fuzzing)
# * `long_running_test()` &mdash; [Error Handling (Catching Timeouts)](ExpectError.ipynb#Catching-Timeouts)
# * Loup Vaillant &mdash; [Parsing Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method)
# * `lower()` &mdash; [Tracking Information Flow (String methods that do not change origin)](InformationFlow.ipynb#String-methods-that-do-not-change-origin), [Concolic Fuzzing (Translating to Upper and Lower Equivalents)](ConcolicFuzzer.ipynb#Translating-to-Upper-and-Lower-Equivalents)
# * `LOW` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators)
# * LR &mdash; [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * LR parsing &mdash; [Parsing Inputs (Items)](Parser.ipynb#Items)
# * LR(k) &mdash; [Parsing Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser)
# * `LR0` &mdash; [Parsing Inputs (Items)](Parser.ipynb#Items)
# * `LR_GRAMMAR` &mdash; [Parsing Inputs (Recursion)](Parser.ipynb#Recursion), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `lr_graph()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `lstrip()` &mdash; [Tracking Information Flow (Strip)](InformationFlow.ipynb#Strip), [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends)
# * `__lt__()` &mdash; [Concolic Fuzzing (Comparisons between Integers)](ConcolicFuzzer.ipynb#Comparisons-between-Integers)
# * Luhn algorithm &mdash; [Fuzzing with Generators (Functions Called After Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-After-Expansion)
# * `luhn_checksum()` &mdash; [Fuzzing with Generators (Functions Called After Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-After-Expansion)
# * `LUHN_ODD_LOOKUP` &mdash; [Fuzzing with Generators (Functions Called After Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-After-Expansion)

# %% [markdown]
# ### M
#
# * `m()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * macros &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * majority of trigrams &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * `make_basic_str_wrapper()` &mdash; [Tracking Information Flow (General wrappers)](InformationFlow.ipynb#General-wrappers)
# * `make_float_binary_wrapper()` &mdash; [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `make_float_bool_wrapper()` &mdash; [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `make_grammar()` &mdash; [Parsing Inputs (Excursion: Testing the Parsers)](Parser.ipynb#Excursion:-Testing-the-Parsers)
# * `make_int_binary_wrapper()` &mdash; [Concolic Fuzzing (Binary Operators for Integers)](ConcolicFuzzer.ipynb#Binary-Operators-for-Integers), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `make_int_bit_wrapper()` &mdash; [Concolic Fuzzing (Exercise 2: Bit Manipulation)](ConcolicFuzzer.ipynb#Exercise-2:-Bit-Manipulation)
# * `make_int_unary_wrapper()` &mdash; [Concolic Fuzzing (Integer Unary Operators)](ConcolicFuzzer.ipynb#Integer-Unary-Operators)
# * `make_int_wrapper()` &mdash; [Tracking Information Flow (Part 2: Arithmetic expressions)](InformationFlow.ipynb#Part-2:-Arithmetic-expressions)
# * `make_rule()` &mdash; [Parsing Inputs (Excursion: Testing the Parsers)](Parser.ipynb#Excursion:-Testing-the-Parsers)
# * `make_split_wrapper()` &mdash; [Tracking Information Flow (Splits)](InformationFlow.ipynb#Splits)
# * `make_str_abort_wrapper()` &mdash; [Tracking Information Flow (Methods yet to be translated)](InformationFlow.ipynb#Methods-yet-to-be-translated), [Concolic Fuzzing (Trip Wire)](ConcolicFuzzer.ipynb#Trip-Wire)
# * `make_str_wrapper()` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators)
# * making up grammars with a dictionary in hand](https://lcamtuf.blogspot.com/2015/01/afl-fuzz-making-up-grammar-with.html) and [pulling JPEGs out of thin air &mdash; [Greybox Fuzzing with Grammars (Fuzzing with Dictionaries)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Dictionaries)
# * Marpa parser &mdash; [Parsing Inputs (More Earley Parsing)](Parser.ipynb#More-Earley-Parsing)
# * `math.isclose()` &mdash; [Introduction to Software Testing (Automating Test Execution)](Intro_Testing.ipynb#Automating-Test-Execution)
# * `MAX_DEPTH` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects), [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects), [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Check Before You Loop)](SymbolicFuzzer.ipynb#Check-Before-You-Loop), [Symbolic Fuzzing (Check Before You Loop)](SymbolicFuzzer.ipynb#Check-Before-You-Loop)
# * `_max_expansion_coverage()` &mdash; [Grammar Coverage (Computing Possible Expansions)](GrammarCoverageFuzzer.ipynb#Computing-Possible-Expansions)
# * `max_expansion_coverage()` &mdash; [Grammar Coverage (Computing Possible Expansions)](GrammarCoverageFuzzer.ipynb#Computing-Possible-Expansions)
# * `max_height()` &mdash; [Reducing Failure-Inducing Inputs (A Few Helpers)](Reducer.ipynb#A-Few-Helpers)
# * `MAX_ITER` &mdash; [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing)
# * `MAX_TRIES` &mdash; [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing)
# * `MAX` &mdash; [Search-Based Fuzzing (Representing Program Inputs as a Search Problem)](SearchBasedFuzzer.ipynb#Representing-Program-Inputs-as-a-Search-Problem), [Search-Based Fuzzing (Representing Program Inputs as a Search Problem)](SearchBasedFuzzer.ipynb#Representing-Program-Inputs-as-a-Search-Problem), [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example), [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example), [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `maze()` &mdash; [Greybox Fuzzing (Solving the Maze)](GreyboxFuzzer.ipynb#Solving-the-Maze), [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze), [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * `MazeMutator` class &mdash; [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt)
# * measure of progress &mdash; [When To Stop Fuzzing (Measuring Trace Coverage over Time)](WhenToStopFuzzing.ipynb#Measuring-Trace-Coverage-over-Time)
# * meta-heuristic &mdash; [Search-Based Fuzzing](SearchBasedFuzzer.ipynb#Search-Based-Fuzzing)
# * `metavars()` &mdash; [Mining Function Specifications (Extracting Meta-Variables)](DynamicInvariants.ipynb#Extracting-Meta-Variables)
# * `METHOD_COLOR` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `method_enter()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `method_exit()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `METHOD_FONT` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `method_init()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `method_statement()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `method_string()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `mine_arguments_grammar()` &mdash; [Carving Unit Tests (A Grammar from Arguments)](Carver.ipynb#A-Grammar-from-Arguments)
# * `mine_a_element_actions()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Retrieving Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Retrieving-Actions), [Testing Graphical User Interfaces (Link Element Actions)](GUIFuzzer.ipynb#Link-Element-Actions)
# * `mine_button_element_actions()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Retrieving Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Retrieving-Actions), [Testing Graphical User Interfaces (Button Element Actions)](GUIFuzzer.ipynb#Button-Element-Actions)
# * `mine_call_grammar()` &mdash; [Carving Unit Tests (A Grammar from all Calls)](Carver.ipynb#A-Grammar-from-all-Calls)
# * `mine_ebnf_grammar()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `mine_function_grammar()` &mdash; [Carving Unit Tests (A Grammar from Calls)](Carver.ipynb#A-Grammar-from-Calls)
# * `mine_grammar()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Web Applications (Mining Grammars for Web Pages)](WebFuzzer.ipynb#Mining-Grammars-for-Web-Pages)
# * `mine_input_element_actions()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Retrieving Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Retrieving-Actions), [Testing Graphical User Interfaces (Input Element Actions)](GUIFuzzer.ipynb#Input-Element-Actions)
# * `mine_probabilistic_grammar()` &mdash; [Probabilistic Grammar Fuzzing (Assigning Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Assigning-Probabilities)
# * `mine_state_actions()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Retrieving Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Retrieving-Actions)
# * `mine_state_grammar()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `MIN` &mdash; [Search-Based Fuzzing (Representing Program Inputs as a Search Problem)](SearchBasedFuzzer.ipynb#Representing-Program-Inputs-as-a-Search-Problem), [Search-Based Fuzzing (Representing Program Inputs as a Search Problem)](SearchBasedFuzzer.ipynb#Representing-Program-Inputs-as-a-Search-Problem), [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example), [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example), [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `missing_expansion_coverage()` &mdash; [Grammar Coverage (Tracking Expansions while Fuzzing)](GrammarCoverageFuzzer.ipynb#Tracking-Expansions-while-Fuzzing)
# * `__mod__()` &mdash; [Tracking Information Flow (mod)](InformationFlow.ipynb#mod)
# * MonkeyType &mdash; [Mining Function Specifications (Background)](DynamicInvariants.ipynb#Background)
# * more energy to seeds with a lower average distance &mdash; [Greybox Fuzzing (Directed Power Schedule)](GreyboxFuzzer.ipynb#Directed-Power-Schedule)
# * more valid inputs &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Fuzzing)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Fuzzing)
# * most &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * Mozilla's `grcov` tool &mdash; [Fuzzing in the Large (Collecting Code Coverage)](FuzzingInTheLarge.ipynb#Collecting-Code-Coverage)
# * `mseq()` &mdash; [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `MuBinOpAnalyzer` class &mdash; [Mutation Analysis (Exercise 1: Arithmetic Expression Mutators)](MutationAnalysis.ipynb#Exercise-1:-Arithmetic-Expression-Mutators)
# * `MuFunctionAnalyzer` class &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations), [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations)
# * multiple inheritance &mdash; [Probabilistic Grammar Fuzzing (Exercise 1: Probabilistic Fuzzing with Coverage)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1:-Probabilistic-Fuzzing-with-Coverage), [Fuzzing with Generators (All Together)](GeneratorGrammarFuzzer.ipynb#All-Together)
# * `MultipleChoice` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `MuProgramAnalyzer` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `mutable_visit()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * mutants &mdash; [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults)
# * `MutantTestRunner` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `Mutant` class &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations), [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations)
# * `mutate()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms), [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation)
# * mutated &mdash; [Search-Based Fuzzing (Global Search)](SearchBasedFuzzer.ipynb#Global-Search)
# * `mutated_gcd()` &mdash; [Mutation Analysis (The Problem of  Equivalent Mutants)](MutationAnalysis.ipynb#The-Problem-of--Equivalent-Mutants)
# * mutation &mdash; [Search-Based Fuzzing (Global Search)](SearchBasedFuzzer.ipynb#Global-Search)
# * mutation analysis &mdash; [Mutation Analysis (Synopsis)](MutationAnalysis.ipynb#Synopsis), [Mutation Analysis (Synopsis)](MutationAnalysis.ipynb#Synopsis)
# * mutation-based fuzzer &mdash; [Greybox Fuzzing (AFL: An Effective Greybox Fuzzer)](GreyboxFuzzer.ipynb#AFL:-An-Effective-Greybox-Fuzzer)
# * mutational fuzzing &mdash; [Mutation-Based Fuzzing](MutationFuzzer.ipynb#Mutation-Based-Fuzzing), [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs)
# * `MutationCoverageFuzzer` class &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `MutationFuzzer` class &mdash; [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Greybox Fuzzing (Compatibility)](GreyboxFuzzer.ipynb#Compatibility)
# * mutations &mdash; [Mutation Analysis](MutationAnalysis.ipynb#Mutation-Analysis), [Mutation Analysis (Seeding Artificial Faults with Mutation Analysis)](MutationAnalysis.ipynb#Seeding-Artificial-Faults-with-Mutation-Analysis)
# * `mutation_visit()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Exercise 1: Arithmetic Expression Mutators)](MutationAnalysis.ipynb#Exercise-1:-Arithmetic-Expression-Mutators)
# * mutator &mdash; [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing), [Greybox Fuzzing (Lessons Learned)](GreyboxFuzzer.ipynb#Lessons-Learned)
# * `mutator_object()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Exercise 1: Arithmetic Expression Mutators)](MutationAnalysis.ipynb#Exercise-1:-Arithmetic-Expression-Mutators)
# * `Mutator` class &mdash; [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Greybox Fuzzing (Mutators)](GreyboxFuzzer.ipynb#Mutators), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * MyPy &mdash; [Fuzzing: Breaking Things with Random Inputs (Static Code Checkers)](Fuzzer.ipynb#Static-Code-Checkers)
# * Mypy &mdash; [Mining Function Specifications (Static Type Checking)](DynamicInvariants.ipynb#Static-Type-Checking)
# * `MysteryRunner` class &mdash; [Reducing Failure-Inducing Inputs (Why Reducing?)](Reducer.ipynb#Why-Reducing?)
# * `my_edge_attr()` &mdash; [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class)
# * `my_eval()` &mdash; [Tracking Information Flow (Selecting Data)](InformationFlow.ipynb#Selecting-Data), [Tracking Information Flow (TaintedDB)](InformationFlow.ipynb#TaintedDB), [Tracking Information Flow (TrackingDB)](InformationFlow.ipynb#TrackingDB)
# * `my_extract_node()` &mdash; [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class)
# * `my_fn()` &mdash; [Concolic Fuzzing (Exercise 2: Bit Manipulation)](ConcolicFuzzer.ipynb#Exercise-2:-Bit-Manipulation)
# * `my_parser()` &mdash; [Greybox Fuzzing (A Complex Example: HTMLParser)](GreyboxFuzzer.ipynb#A-Complex-Example:-HTMLParser), [Greybox Fuzzing with Grammars (Background)](GreyboxGrammarFuzzer.ipynb#Background), [When To Stop Fuzzing (Measuring Trace Coverage over Time)](WhenToStopFuzzing.ipynb#Measuring-Trace-Coverage-over-Time)
# * `my_sqrt()` &mdash; [Introduction to Software Testing (Simple Testing)](Intro_Testing.ipynb#Simple-Testing), [Parsing Inputs (Fixpoint)](Parser.ipynb#Fixpoint), [Mining Function Specifications (Why Generic Error Checking is Not Enough)](DynamicInvariants.ipynb#Why-Generic-Error-Checking-is-Not-Enough)
# * `_my_sqrt()` &mdash; [Parsing Inputs (Fixpoint)](Parser.ipynb#Fixpoint)
# * `my_sqrt_annotated()` &mdash; [Mining Function Specifications (Getting Types)](DynamicInvariants.ipynb#Getting-Types)
# * `my_sqrt_checked()` &mdash; [Introduction to Software Testing (Run-Time Verification)](Intro_Testing.ipynb#Run-Time-Verification)
# * `my_sqrt_fixed()` &mdash; [Introduction to Software Testing (The Limits of Testing)](Intro_Testing.ipynb#The-Limits-of-Testing), [Introduction to Software Testing (Exercise 4: To Infinity and Beyond)](Intro_Testing.ipynb#Exercise-4:-To-Infinity-and-Beyond)
# * `my_sqrt_with_invariants()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * `my_sqrt_with_local_types()` &mdash; [Mining Function Specifications (Exercise 2: Types for Local Variables)](DynamicInvariants.ipynb#Exercise-2:-Types-for-Local-Variables)
# * `my_sqrt_with_log()` &mdash; [Introduction to Software Testing (Debugging a Function)](Intro_Testing.ipynb#Debugging-a-Function)
# * `my_sqrt_with_postcondition()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * `my_sqrt_with_precondition()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * `my_sqrt_with_type_annotations()` &mdash; [Mining Function Specifications (Specifying and Checking Data Types)](DynamicInvariants.ipynb#Specifying-and-Checking-Data-Types)
# * `my_sqrt_with_union_type()` &mdash; [Mining Function Specifications (Exercise 1: Union Types)](DynamicInvariants.ipynb#Exercise-1:-Union-Types)

# %% [markdown]
# ### N
#
# * $n$]` syntax to access the $n$-th child of type `<a>`. To access the first child, $n$ is equal to one, not zero, as in the [XPath abbreviated syntax &mdash; [Fuzzing with Constraints (Accessing Elements)](FuzzingWithConstraints.ipynb#Accessing-Elements)
# * `names()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * natural language &mdash; [Fuzzing with Grammars (A Natural Language Grammar)](Grammars.ipynb#A-Natural-Language-Grammar)
# * `naval_enigma()` &mdash; [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma)
# * neighbors &mdash; [Search-Based Fuzzing (Representing Program Inputs as a Search Problem)](SearchBasedFuzzer.ipynb#Representing-Program-Inputs-as-a-Search-Problem)
# * `neighbors()` &mdash; [Search-Based Fuzzing (Representing Program Inputs as a Search Problem)](SearchBasedFuzzer.ipynb#Representing-Program-Inputs-as-a-Search-Problem)
# * `neighbor_strings()` &mdash; [Search-Based Fuzzing (CGI Decoder as a Search Problem)](SearchBasedFuzzer.ipynb#CGI-Decoder-as-a-Search-Problem)
# * `__neq__()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * networkx &mdash; [Greybox Fuzzing (Computing Function-Level Distance)](GreyboxFuzzer.ipynb#Computing-Function-Level-Distance)
# * Newton–Raphson method &mdash; [Introduction to Software Testing (Simple Testing)](Intro_Testing.ipynb#Simple-Testing)
# * `new_child_coverage()` &mdash; [Grammar Coverage (Determining yet Uncovered Children)](GrammarCoverageFuzzer.ipynb#Determining-yet-Uncovered-Children)
# * `_new_child_coverage()` &mdash; [Grammar Coverage (Determining yet Uncovered Children)](GrammarCoverageFuzzer.ipynb#Determining-yet-Uncovered-Children)
# * `new_coverages()` &mdash; [Grammar Coverage (Excursion: Implementing `new_coverage()`)](GrammarCoverageFuzzer.ipynb#Excursion:-Implementing-`new_coverage()`)
# * `new_expansion_cost()` &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * `new_gcd()` &mdash; [Mutation Analysis (The Problem of  Equivalent Mutants)](MutationAnalysis.ipynb#The-Problem-of--Equivalent-Mutants)
# * `new_state_symbol()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `new_symbol()` &mdash; [Fuzzing with Grammars (Creating New Symbols)](Grammars.ipynb#Creating-New-Symbols)
# * `new_symbol_cost()` &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * `__new__()` &mdash; [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (Part 1: Creation)](InformationFlow.ipynb#Part-1:-Creation), [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (A Proxy Class for Strings)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Strings), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `next_choice()` &mdash; [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class)
# * `__next__()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Tracking Information Flow (Slices)](InformationFlow.ipynb#Slices), [Concolic Fuzzing (An Iterator Class for Strings)](ConcolicFuzzer.ipynb#An-Iterator-Class-for-Strings)
# * `__ne__()` &mdash; [Concolic Fuzzing (Equality between Integers)](ConcolicFuzzer.ipynb#Equality-between-Integers), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `no()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * nodes &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * NodeTransformer &mdash; [Symbolic Fuzzing (Dealing with Reassignments)](SymbolicFuzzer.ipynb#Dealing-with-Reassignments)
# * Nonparametric estimation of the number of classes in a population &mdash; [When To Stop Fuzzing (Background)](WhenToStopFuzzing.ipynb#Background)
# * nonterminal symbol &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `nonterminals()` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * `NonTerminal` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `non_canonical()` &mdash; [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars)
# * normalize &mdash; [Search-Based Fuzzing (Fitness Function to Create Valid Hexadecimal Inputs)](SearchBasedFuzzer.ipynb#Fitness-Function-to-Create-Valid-Hexadecimal-Inputs)
# * `normalize()` &mdash; [Search-Based Fuzzing (Fitness Function to Create Valid Hexadecimal Inputs)](SearchBasedFuzzer.ipynb#Fitness-Function-to-Create-Valid-Hexadecimal-Inputs)
# * `normalizedEnergy()` &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules)
# * not &mdash; [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing), [Parsing Inputs (Exercise 3: PEG Predicates)](Parser.ipynb#Exercise-3:-PEG-Predicates)
# * `not_found()` &mdash; [Testing Web Applications (Page Not Found)](WebFuzzer.ipynb#Page-Not-Found)
# * `__not__()` &mdash; [Concolic Fuzzing (Negation of Encoded formula)](ConcolicFuzzer.ipynb#Negation-of-Encoded-formula)
# * `no_8bit()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 1: Simulate Troff)](Fuzzer.ipynb#Exercise-1:-Simulate-Troff)
# * `no_backslash_d()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 1: Simulate Troff)](Fuzzer.ipynb#Exercise-1:-Simulate-Troff)
# * `no_dot()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 1: Simulate Troff)](Fuzzer.ipynb#Exercise-1:-Simulate-Troff)
# * `nt_var()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `nullable()` &mdash; [Parsing Inputs (Nullable)](Parser.ipynb#Nullable)
# * `nullable_()` &mdash; [Parsing Inputs (Nullable)](Parser.ipynb#Nullable)
# * `nullable_expr()` &mdash; [Parsing Inputs (Nullable)](Parser.ipynb#Nullable)
# * `number_of_nodes()` &mdash; [Reducing Failure-Inducing Inputs (A Few Helpers)](Reducer.ipynb#A-Few-Helpers)

# %% [markdown]
# ### O
#
# * `OBJECT` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * observed &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * `offsets_from_entry()` &mdash; [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer)
# * `OneOrMore` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `on_annassign()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_assign()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_augassign()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_binop()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_break()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_call()` &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_compare()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_continue()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_event()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `on_exception()` &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `on_expr()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_for()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_functiondef()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_if()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_line()` &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `on_module()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_pass()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_return()` &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_unaryop()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `on_while()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * Optimize &mdash; [Fuzzing in the Large (End of Excursion)](FuzzingInTheLarge.ipynb#End-of-Excursion)
# * `Optional()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `OptionalSequence` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `OptionFuzzer` class &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `OptionGrammarMiner` class &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `OptionRunner` class &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `options()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Advanced Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Advanced-Symbolic-Fuzzing)
# * `OPTION_SYMBOL` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `opts()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `opts()`)](Grammars.ipynb#Excursion:-Implementing-`opts()`)
# * `opts_used()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `is_valid_grammar()`)](Grammars.ipynb#Excursion:-Implementing-`is_valid_grammar()`)
# * or more &mdash; [When To Stop Fuzzing (Exercises)](WhenToStopFuzzing.ipynb#Exercises)
# * oracle &mdash; [Code Coverage (Finding Errors with Basic Fuzzing)](Coverage.ipynb#Finding-Errors-with-Basic-Fuzzing), [Fuzzing APIs (Synthesizing Oracles)](APIFuzzer.ipynb#Synthesizing-Oracles)
# * `oracle()` &mdash; [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations)
# * oracles &mdash; [Mining Function Specifications (Checking Specifications)](DynamicInvariants.ipynb#Checking-Specifications)
# * ordered choice &mdash; [Parsing Inputs (Synopsis)](Parser.ipynb#Synopsis), [Parsing Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars), [Parsing Inputs (Synopsis)](Parser.ipynb#Synopsis)
# * ordering of expansions &mdash; [Fuzzing with Generators (Ordering Expansions)](GeneratorGrammarFuzzer.ipynb#Ordering-Expansions)
# * `orders_db_is_empty()` &mdash; [Testing Web Applications (Fully Automatic Web Attacks)](WebFuzzer.ipynb#Fully-Automatic-Web-Attacks)
# * `ORDERS_DB` &mdash; [Testing Web Applications (Storing Orders)](WebFuzzer.ipynb#Storing-Orders)
# * `ORDER_GRAMMAR_WITH_SQL_INJECTION` &mdash; [Testing Web Applications (SQL Injection Attacks)](WebFuzzer.ipynb#SQL-Injection-Attacks)
# * `ORDER_GRAMMAR` &mdash; [Testing Web Applications (Fuzzing with Expected Values)](WebFuzzer.ipynb#Fuzzing-with-Expected-Values)
# * `ostr_iterator` class &mdash; [Tracking Information Flow (Slices)](InformationFlow.ipynb#Slices)
# * `ostr` class &mdash; [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (Create)](InformationFlow.ipynb#Create), [Tracking Information Flow (Index)](InformationFlow.ipynb#Index), [Tracking Information Flow (Slices)](InformationFlow.ipynb#Slices), [Tracking Information Flow (Concatenation)](InformationFlow.ipynb#Concatenation), [Tracking Information Flow (Concatenation)](InformationFlow.ipynb#Concatenation), [Tracking Information Flow (Extract Origin String)](InformationFlow.ipynb#Extract-Origin-String), [Tracking Information Flow (Replace)](InformationFlow.ipynb#Replace), [Tracking Information Flow (Split)](InformationFlow.ipynb#Split), [Tracking Information Flow (Strip)](InformationFlow.ipynb#Strip), [Tracking Information Flow (Expand Tabs)](InformationFlow.ipynb#Expand-Tabs), [Tracking Information Flow (Expand Tabs)](InformationFlow.ipynb#Expand-Tabs), [Tracking Information Flow (Partitions)](InformationFlow.ipynb#Partitions), [Tracking Information Flow (Justify)](InformationFlow.ipynb#Justify), [Tracking Information Flow (Justify)](InformationFlow.ipynb#Justify), [Tracking Information Flow (mod)](InformationFlow.ipynb#mod), [Tracking Information Flow (mod)](InformationFlow.ipynb#mod), [Tracking Information Flow (String methods that do not change origin)](InformationFlow.ipynb#String-methods-that-do-not-change-origin)
# * `overloaded_class_methods()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * OWASP Zed Attack Proxy Project &mdash; [Testing Web Applications (Background)](WebFuzzer.ipynb#Background)

# %% [markdown]
# ## P - T

# %% [markdown]
# ### P
#
# * `P1` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree)
# * packrat &mdash; [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG)
# * `PackratParser` class &mdash; [Parsing Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * page &mdash; [Testing Graphical User Interfaces (User Interface Actions)](GUIFuzzer.ipynb#User-Interface-Actions)
# * `pairwise()` &mdash; [Testing Configurations (Combinatorial Testing)](ConfigurationFuzzer.ipynb#Combinatorial-Testing)
# * `parameters()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `params()` &mdash; [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations)
# * `parenthesized_expressions()` &mdash; [Fuzzing with Grammars (Expanding Parenthesized Expressions)](Grammars.ipynb#Expanding-Parenthesized-Expressions)
# * `parsable()` &mdash; [Greybox Fuzzing with Grammars (Focusing on Valid Seeds)](GreyboxGrammarFuzzer.ipynb#Focusing-on-Valid-Seeds)
# * parse tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees), [Greybox Fuzzing with Grammars (Parsing and Recombining HTML)](GreyboxGrammarFuzzer.ipynb#Parsing-and-Recombining-HTML)
# * `parse()` &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class), [Parsing Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser), [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `parseCSSGrammar()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `ParseInterrupt` class &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * parser &mdash; [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * Parser &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * parsers &mdash; [Efficient Grammar Fuzzing (Background)](GrammarFuzzer.ipynb#Background)
# * `Parser` class &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class), [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars), [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars)
# * `parse_csv()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `parse_forest()` &mdash; [Parsing Inputs (Parsing Forests)](Parser.ipynb#Parsing-Forests), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 6: Filtered Earley Parser)](Parser.ipynb#Exercise-6:-Filtered-Earley-Parser)
# * `parse_helper()` &mdash; [Parsing Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser)
# * `parse_on()` &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * `parse_paths()` &mdash; [Parsing Inputs (Parsing Paths)](Parser.ipynb#Parsing-Paths), [Parsing Inputs (Exercise 7: Iterative Earley Parser)](Parser.ipynb#Exercise-7:-Iterative-Earley-Parser)
# * `parse_prefix()` &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class), [Parsing Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars), [Parsing Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * `parse_quote()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `parse_sexp()` &mdash; [Concolic Fuzzing (Using the Command Line)](ConcolicFuzzer.ipynb#Using-the-Command-Line)
# * `parse_table()` &mdash; [Parsing Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table), [Parsing Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * `parse_type()` &mdash; [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types)
# * parsing &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * Parsing Expression Grammar &mdash; [Parsing Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * Parsing Expression Grammars &mdash; [Parsing Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * `partition()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow), [Tracking Information Flow (Partitions)](InformationFlow.ipynb#Partitions)
# * `partition_by_part()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `PASS` &mdash; [Fuzzing: Breaking Things with Random Inputs (Synopsis)](Fuzzer.ipynb#Synopsis), [Fuzzing: Breaking Things with Random Inputs (Synopsis)](Fuzzer.ipynb#Synopsis), [Fuzzing: Breaking Things with Random Inputs (Synopsis)](Fuzzer.ipynb#Synopsis), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runners)](Fuzzer.ipynb#Runners), [Fuzzing: Breaking Things with Random Inputs (Runners)](Fuzzer.ipynb#Runners), [Fuzzing: Breaking Things with Random Inputs (Runners)](Fuzzer.ipynb#Runners)
# * path to insanity &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `paths()` &mdash; [Parsing Inputs (Parsing Paths)](Parser.ipynb#Parsing-Paths)
# * `path_expression()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * `Path` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `pattern()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * PEG &mdash; [Parsing Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars), [Parsing Inputs (End of Excursion)](Parser.ipynb#End-of-Excursion), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `PEG1` &mdash; [Parsing Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `PEG2` &mdash; [Parsing Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `PEGParser` class &mdash; [Parsing Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars), [Parsing Inputs (Unify Key)](Parser.ipynb#Unify-Key), [Parsing Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing Inputs (Unify Rule)](Parser.ipynb#Unify-Rule)
# * PEGs &mdash; [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing Inputs (Background)](Parser.ipynb#Background), [Parsing Inputs (Background)](Parser.ipynb#Background)
# * PEP 8 Style Guide for Python Code &mdash; [Testing Configurations (Testing Autopep8)](ConfigurationFuzzer.ipynb#Testing-Autopep8)
# * `permutation()` &mdash; [Concolic Fuzzing (Example: Binomial Coefficient)](ConcolicFuzzer.ipynb#Example:-Binomial-Coefficient)
# * `PGGCFuzzer` class &mdash; [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage)
# * `PICKED_US_PHONE_GRAMMAR` &mdash; [Fuzzing with Generators (Synopsis)](GeneratorGrammarFuzzer.ipynb#Synopsis)
# * `pick_area_code()` &mdash; [Fuzzing with Generators (Synopsis)](GeneratorGrammarFuzzer.ipynb#Synopsis)
# * `PlausibleChild` class &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * Plots &mdash; [Academic Prototyping (Replicable Experiments)](AcademicPrototyping.ipynb#Replicable-Experiments)
# * `plotting_hillclimber()` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `PMIterator` class &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `PNode` class &mdash; [Symbolic Fuzzing (Tracking Assignments)](SymbolicFuzzer.ipynb#Tracking-Assignments), [Symbolic Fuzzing (Tracking Assignments)](SymbolicFuzzer.ipynb#Tracking-Assignments), [Symbolic Fuzzing (Stepwise Exploration of Paths)](SymbolicFuzzer.ipynb#Stepwise-Exploration-of-Paths), [Symbolic Fuzzing (Stepwise Exploration of Paths)](SymbolicFuzzer.ipynb#Stepwise-Exploration-of-Paths), [Symbolic Fuzzing (Stepwise Exploration of Paths)](SymbolicFuzzer.ipynb#Stepwise-Exploration-of-Paths)
# * `PooledGrammarFuzzer` class &mdash; [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * `population_branch_coverage()` &mdash; [Code Coverage (Part 2: Comparing statement coverage and branch coverage)](Coverage.ipynb#Part-2:-Comparing-statement-coverage-and-branch-coverage)
# * `population_coverage()` &mdash; [Code Coverage ( Coverage of Basic Fuzzing)](Coverage.ipynb#-Coverage-of-Basic-Fuzzing)
# * `population_stmt_coverage()` &mdash; [When To Stop Fuzzing (Part 1: Population Coverage)](WhenToStopFuzzing.ipynb#Part-1:-Population-Coverage)
# * `population_trace_coverage()` &mdash; [When To Stop Fuzzing (Measuring Trace Coverage over Time)](WhenToStopFuzzing.ipynb#Measuring-Trace-Coverage-over-Time)
# * `possible_combinations()` &mdash; [Reducing Failure-Inducing Inputs (A Few Helpers)](Reducer.ipynb#A-Few-Helpers)
# * `possible_expansions()` &mdash; [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree)
# * post-order &mdash; [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `postcondition()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * `postconditions()` &mdash; [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `POST` &mdash; [Testing Web Applications (A Fuzzer for Web Forms)](WebFuzzer.ipynb#A-Fuzzer-for-Web-Forms)
# * `__pos__()` &mdash; [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers)
# * power operator &mdash; [When To Stop Fuzzing (The Kenngruppenbuch)](WhenToStopFuzzing.ipynb#The-Kenngruppenbuch)
# * power schedule &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules), [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules), [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing), [Greybox Fuzzing (Lessons Learned)](GreyboxFuzzer.ipynb#Lessons-Learned)
# * `power()` &mdash; [Carving Unit Tests (From Calls to Grammars)](Carver.ipynb#From-Calls-to-Grammars)
# * `PowerSchedule` class &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules)
# * `POWER_GRAMMAR` &mdash; [Carving Unit Tests (From Calls to Grammars)](Carver.ipynb#From-Calls-to-Grammars)
# * pre-computed &mdash; [Greybox Fuzzing (Directed Power Schedule)](GreyboxFuzzer.ipynb#Directed-Power-Schedule)
# * pre-order &mdash; [Parsing Inputs (Background)](Parser.ipynb#Background)
# * `precompute_costs()` &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * `precondition()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions)
# * `preconditions()` &mdash; [Mining Function Specifications (Converting Mined Invariants to Annotations)](DynamicInvariants.ipynb#Converting-Mined-Invariants-to-Annotations), [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `PreconditionTransformer` class &mdash; [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * predict &mdash; [When To Stop Fuzzing (Extrapolating Fuzzing Success)](WhenToStopFuzzing.ipynb#Extrapolating-Fuzzing-Success)
# * `predict()` &mdash; [Parsing Inputs (Predicting States)](Parser.ipynb#Predicting-States), [Parsing Inputs (Nullable)](Parser.ipynb#Nullable), [Parsing Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * Predicting the Number of New Species in Further Taxonomic Sampling &mdash; [When To Stop Fuzzing (Background)](WhenToStopFuzzing.ipynb#Background)
# * prefix &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * `prefix_vars()` &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * `pretty_invariants()` &mdash; [Mining Function Specifications (Extracting Invariants)](DynamicInvariants.ipynb#Extracting-Invariants)
# * previous chapter](MutationFuzzer.ipynb), we have introduced _mutation-based fuzzing_, a technique that generates fuzz inputs by applying small mutations to given inputs. In this chapter, we show how to _guide_ these mutations towards specific goals such as coverage. The algorithms in this chapter stem from the popular [American Fuzzy Lop](http://lcamtuf.coredump.cx/afl/) (AFL) fuzzer, in particular from its [AFLFast](https://github.com/mboehme/aflfast) and [AFLGo &mdash; [Greybox Fuzzing](GreyboxFuzzer.ipynb#Greybox-Fuzzing)
# * `PrintRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `print_httpd_messages()` &mdash; [Testing Web Applications (Logging)](WebFuzzer.ipynb#Logging)
# * `print_maze()` &mdash; [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * `print_more_stats()` &mdash; [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing)
# * `print_stats()` &mdash; [Greybox Fuzzing (A First Attempt)](GreyboxFuzzer.ipynb#A-First-Attempt), [Greybox Fuzzing with Grammars (Fragment-Based Fuzzing)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Fuzzing)
# * `print_sum()` &mdash; [Mining Function Specifications (Some Examples)](DynamicInvariants.ipynb#Some-Examples)
# * `print_url()` &mdash; [Testing Web Applications (Direct Browser Access)](WebFuzzer.ipynb#Direct-Browser-Access)
# * `ProbabilisticGeneratorGrammarCoverageFuzzer` class &mdash; [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage), [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage), [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage)
# * `ProbabilisticGeneratorGrammarFuzzer` class &mdash; [Fuzzing with Generators (Generators and Probabilistic Fuzzing)](GeneratorGrammarFuzzer.ipynb#Generators-and-Probabilistic-Fuzzing)
# * `ProbabilisticGrammarCoverageFuzzer` class &mdash; [Probabilistic Grammar Fuzzing (Exercise 1: Probabilistic Fuzzing with Coverage)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1:-Probabilistic-Fuzzing-with-Coverage)
# * `ProbabilisticGrammarFuzzer` class &mdash; [Probabilistic Grammar Fuzzing (Expanding by Probability)](ProbabilisticGrammarFuzzer.ipynb#Expanding-by-Probability), [Probabilistic Grammar Fuzzing (Expanding by Probability)](ProbabilisticGrammarFuzzer.ipynb#Expanding-by-Probability)
# * `ProbabilisticGrammarMiner` class &mdash; [Probabilistic Grammar Fuzzing (Assigning Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Assigning-Probabilities), [Probabilistic Grammar Fuzzing (Assigning Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Assigning-Probabilities)
# * `prob_distribution()` &mdash; [Probabilistic Grammar Fuzzing (Distributing Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Distributing-Probabilities)
# * `prob_leading_digit()` &mdash; [Probabilistic Grammar Fuzzing (The Law of Leading Digits)](ProbabilisticGrammarFuzzer.ipynb#The-Law-of-Leading-Digits)
# * `process()` &mdash; [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Generating All Possible Paths)](SymbolicFuzzer.ipynb#Generating-All-Possible-Paths)
# * `process_arg()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `process_argument()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `process_car()` &mdash; [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * `process_car_with_obj()` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `process_chosen_children()` &mdash; [Efficient Grammar Fuzzing (Excursion: `expand_node_randomly()` implementation)](GrammarFuzzer.ipynb#Excursion:-`expand_node_randomly()`-implementation), [Fuzzing with Generators (Generating Elements before Expansion)](GeneratorGrammarFuzzer.ipynb#Generating-Elements-before-Expansion)
# * `process_inventory()` &mdash; [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * `process_inventory_with_obj()` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `process_numbers()` &mdash; [Testing Configurations (Options in Python)](ConfigurationFuzzer.ipynb#Options-in-Python)
# * `PROCESS_NUMBERS_EBNF_GRAMMAR` &mdash; [Testing Configurations (A Grammar for Configurations)](ConfigurationFuzzer.ipynb#A-Grammar-for-Configurations)
# * `PROCESS_NUMBERS_GRAMMAR` &mdash; [Testing Configurations (A Grammar for Configurations)](ConfigurationFuzzer.ipynb#A-Grammar-for-Configurations)
# * `process_van()` &mdash; [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * `process_van_with_obj()` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `process_vehicle()` &mdash; [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * `process_vehicle_with_obj()` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `prod_line_grammar()` &mdash; [Parsing Inputs (Excursion: Testing the Parsers)](Parser.ipynb#Excursion:-Testing-the-Parsers)
# * Program Spectra &mdash; [Academic Prototyping (Replicable Experiments)](AcademicPrototyping.ipynb#Replicable-Experiments)
# * `ProgramRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * progress of the fuzzing campaign towards completion &mdash; [When To Stop Fuzzing (Discovery Probability Quantifies Residual Risk)](WhenToStopFuzzing.ipynb#Discovery-Probability-Quantifies-Residual-Risk)
# * `prop_function()` &mdash; [Mining Function Specifications (Evaluating Properties)](DynamicInvariants.ipynb#Evaluating-Properties)
# * `prop_function_text()` &mdash; [Mining Function Specifications (Evaluating Properties)](DynamicInvariants.ipynb#Evaluating-Properties)
# * `proxy()` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators), [Tracking Information Flow (Splits)](InformationFlow.ipynb#Splits), [Tracking Information Flow (General wrappers)](InformationFlow.ipynb#General-wrappers), [Tracking Information Flow (Methods yet to be translated)](InformationFlow.ipynb#Methods-yet-to-be-translated), [Tracking Information Flow (Part 2: Arithmetic expressions)](InformationFlow.ipynb#Part-2:-Arithmetic-expressions), [Concolic Fuzzing (Binary Operators for Integers)](ConcolicFuzzer.ipynb#Binary-Operators-for-Integers), [Concolic Fuzzing (Integer Unary Operators)](ConcolicFuzzer.ipynb#Integer-Unary-Operators), [Concolic Fuzzing (Trip Wire)](ConcolicFuzzer.ipynb#Trip-Wire), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Concolic Fuzzing (Exercise 2: Bit Manipulation)](ConcolicFuzzer.ipynb#Exercise-2:-Bit-Manipulation)
# * `prune_tokens()` &mdash; [Concolic Fuzzing (Pruning and Updating)](ConcolicFuzzer.ipynb#Pruning-and-Updating)
# * `prune_tree()` &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class), [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars), [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * `public_class_methods()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `PUBLIC` &mdash; [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks)
# * PyAnnotate &mdash; [Mining Function Specifications (Background)](DynamicInvariants.ipynb#Background)
# * `PYAN` &mdash; [Control Flow Graph (Call Graph Helpers)](ControlFlow.ipynb#Call-Graph-Helpers), [Control Flow Graph (Call Graph Helpers)](ControlFlow.ipynb#Call-Graph-Helpers)
# * `PyCFG` class &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * Python &mdash; [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining)
# * Python documentation &mdash; [Concolic Fuzzing (Binary Operators for Integers)](ConcolicFuzzer.ipynb#Binary-Operators-for-Integers)
# * Python tutorial &mdash; [Introduction to Software Testing (Understanding Python Programs)](Intro_Testing.ipynb#Understanding-Python-Programs), [Fuzzing: Breaking Things with Random Inputs](Fuzzer.ipynb#Fuzzing:-Breaking-Things-with Random Inputs)
# * Python type to Z3 type &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)

# %% [markdown]
# ### Q
#
# * `Q0` &mdash; [When To Stop Fuzzing (Part 3: Compute and Evaluate Extrapolator)](WhenToStopFuzzing.ipynb#Part-3:-Compute-and-Evaluate-Extrapolator)
# * `Q1` &mdash; [When To Stop Fuzzing (Part 2: Compute Estimate)](WhenToStopFuzzing.ipynb#Part-2:-Compute-Estimate)
# * `Q2` &mdash; [When To Stop Fuzzing (Part 2: Compute Estimate)](WhenToStopFuzzing.ipynb#Part-2:-Compute-Estimate)
# * QEMU](https://github.com/mirrorer/afl/blob/master/qemu_mode)) or a dynamic instrumentation tool (e.g., [Intel PinTool &mdash; [Greybox Fuzzing (AFL: An Effective Greybox Fuzzer)](GreyboxFuzzer.ipynb#AFL:-An-Effective-Greybox-Fuzzer)
# * `quadratic_solver()` &mdash; [Introduction to Software Testing (Exercise 3: Quadratic Solver)](Intro_Testing.ipynb#Exercise-3:-Quadratic-Solver)
# * `quadratic_solver_fixed()` &mdash; [Introduction to Software Testing (Part 2: Fix the problem)](Intro_Testing.ipynb#Part-2:-Fix-the-problem)
# * `quad_solver()` &mdash; [Control Flow Graph (quad_solver)](ControlFlow.ipynb#quad_solver)
# * `qualified()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `quux()` &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)
# * `qux()` &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)

# %% [markdown]
# ### R
#
# * `__radd__()` &mdash; [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators), [Tracking Information Flow (Concatenation)](InformationFlow.ipynb#Concatenation), [Concolic Fuzzing (Concatenation of Strings)](ConcolicFuzzer.ipynb#Concatenation-of-Strings)
# * Railroad diagrams &mdash; [Academic Prototyping (Replicable Experiments)](AcademicPrototyping.ipynb#Replicable-Experiments)
# * random restarts &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `RandomFuzzer` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * `randomized_hillclimb()` &mdash; [Search-Based Fuzzing (Global Search)](SearchBasedFuzzer.ipynb#Global-Search)
# * `random_list()` &mdash; [Introduction to Software Testing (Part 2: Random Inputs)](Intro_Testing.ipynb#Part-2:-Random-Inputs)
# * `random_string()` &mdash; [Search-Based Fuzzing (Hillclimbing Valid Hexadecimal Inputs)](SearchBasedFuzzer.ipynb#Hillclimbing-Valid-Hexadecimal-Inputs)
# * `random_unicode_string()` &mdash; [Search-Based Fuzzing (Evolutionary Search)](SearchBasedFuzzer.ipynb#Evolutionary-Search)
# * `reachable_nonterminals()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `is_valid_grammar()`)](Grammars.ipynb#Excursion:-Implementing-`is_valid_grammar()`)
# * `readable()` &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees)
# * `readable_rule()` &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees)
# * `read_gcov_coverage()` &mdash; [Code Coverage (Getting Coverage from External Programs)](Coverage.ipynb#Getting-Coverage-from-External-Programs)
# * `rearrange()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `recover_grammar()` &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining)
# * `recover_grammar_with_taints()` &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `recurse_grammar()` &mdash; [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars)
# * recursion &mdash; [Parsing Inputs (Excursion: Recursion)](Parser.ipynb#Excursion:-Recursion)
# * recursive &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * `recursive_delete()` &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation)
# * `recursive_swap()` &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation)
# * red-black tree &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `RedBlackTree` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `reduce()` &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy)
# * `Reducer` class &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * `reduce_subtree()` &mdash; [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy)
# * `reduce_tree()` &mdash; [Reducing Failure-Inducing Inputs (The Reduction Strategy)](Reducer.ipynb#The-Reduction-Strategy), [Reducing Failure-Inducing Inputs (A Depth-Oriented Strategy)](Reducer.ipynb#A-Depth-Oriented-Strategy)
# * "Reducing Failure-Inducing Inputs" in the Debugging Book &mdash; [Reducing Failure-Inducing Inputs (Background)](Reducer.ipynb#Background)
# * region &mdash; [Greybox Fuzzing with Grammars (Fuzzing with Input Regions)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Input-Regions), [Greybox Fuzzing with Grammars (Determining Symbol Regions)](GreyboxGrammarFuzzer.ipynb#Determining-Symbol-Regions)
# * region-based mutators &mdash; [Greybox Fuzzing with Grammars (Fuzzing with Input Regions)](GreyboxGrammarFuzzer.ipynb#Fuzzing-with-Input-Regions)
# * `RegionMutator` class &mdash; [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation), [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation), [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation)
# * `register()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `register_event()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `register_node()` &mdash; [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry)
# * `REGISTRY_IDX` &mdash; [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry), [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry)
# * `REGISTRY` &mdash; [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry), [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry)
# * Regular Expression &mdash; [Parsing Inputs (Background)](Parser.ipynb#Background)
# * Regular expressions &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * regular expressions &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * regular language &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * remove &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation)
# * `remove_first_char()` &mdash; [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers), [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers)
# * `rename_variables()` &mdash; [Symbolic Fuzzing (Dealing with Reassignments)](SymbolicFuzzer.ipynb#Dealing-with-Reassignments)
# * repair &mdash; [Fuzzing with Generators (Functions Called After Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-After-Expansion)
# * `replace()` &mdash; [Tracking Information Flow (Replace)](InformationFlow.ipynb#Replace)
# * `replace_symbol()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `repOK()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * represent &mdash; [Search-Based Fuzzing (Test Generation as a Search Problem)](SearchBasedFuzzer.ipynb#Test-Generation-as-a-Search-Problem)
# * representation invariant &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * representative path &mdash; [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer)
# * `__repr__()` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (Part 3: Passing taints from integers to strings)](InformationFlow.ipynb#Part-3:-Passing-taints-from-integers-to-strings), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Symbolic Fuzzing (Tracking Assignments)](SymbolicFuzzer.ipynb#Tracking-Assignments), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `REQUIRED_FIELDS` &mdash; [Testing Web Applications (Part 4: A Robust Server)](WebFuzzer.ipynb#Part-4:-A-Robust-Server)
# * `__req__()` &mdash; [Concolic Fuzzing (Equality between Integers)](ConcolicFuzzer.ipynb#Equality-between-Integers), [Concolic Fuzzing (Equality between Strings)](ConcolicFuzzer.ipynb#Equality-between-Strings)
# * `reset()` &mdash; [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Greybox Fuzzing (Advanced Blackbox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Advanced-Blackbox-Mutation-based-Fuzzing), [Greybox Fuzzing (Greybox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Greybox-Mutation-based-Fuzzing), [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing), [Probabilistic Grammar Fuzzing (Counting Expansions)](ProbabilisticGrammarFuzzer.ipynb#Counting-Expansions), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results), [Testing Web Applications (Searching HTML for Input Fields)](WebFuzzer.ipynb#Searching-HTML-for-Input-Fields), [Testing Web Applications (Crawling User Interfaces)](WebFuzzer.ipynb#Crawling-User-Interfaces), [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma)
# * `reset_counter()` &mdash; [Concolic Fuzzing (Generating Fresh Names)](ConcolicFuzzer.ipynb#Generating-Fresh-Names)
# * `reset_coverage()` &mdash; [Grammar Coverage (Keeping Track of Expansions)](GrammarCoverageFuzzer.ipynb#Keeping-Track-of-Expansions)
# * `reset_generators()` &mdash; [Fuzzing with Generators (Support for Python Generators)](GeneratorGrammarFuzzer.ipynb#Support-for-Python-Generators)
# * `reset_registry()` &mdash; [Control Flow Graph (Registry)](ControlFlow.ipynb#Registry)
# * residual risk &mdash; [When To Stop Fuzzing](WhenToStopFuzzing.ipynb#When-To-Stop-Fuzzing), [When To Stop Fuzzing (Discovery Probability Quantifies Residual Risk)](WhenToStopFuzzing.ipynb#Discovery-Probability-Quantifies-Residual-Risk)
# * `restart()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `RestartExpansionException` class &mdash; [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing)
# * `restarting_hillclimber()` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `restart_expansion()` &mdash; [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion), [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing), [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage)
# * `result()` &mdash; [Carving Unit Tests (Part 2: Access results)](Carver.ipynb#Part-2:-Access-results)
# * `ResultCarver` class &mdash; [Carving Unit Tests (Exercises)](Carver.ipynb#Exercises), [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results), [Carving Unit Tests (Part 2: Access results)](Carver.ipynb#Part-2:-Access-results)
# * results checker &mdash; [Code Coverage (Finding Errors with Basic Fuzzing)](Coverage.ipynb#Finding-Errors-with-Basic-Fuzzing)
# * return &mdash; [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations), [Mining Input Grammars (Tracking variable assignment locations)](GrammarMiner.ipynb#Tracking-variable-assignment-locations)
# * `RETURN_VALUE` &mdash; [Mining Function Specifications (Extracting Invariants)](DynamicInvariants.ipynb#Extracting-Invariants)
# * `RE_EXTENDED_NONTERMINAL` &mdash; [Fuzzing with Grammars (Expanding Operators)](Grammars.ipynb#Expanding-Operators)
# * `RE_NONTERMINAL` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * `RE_PARENTHESIZED_EXPR` &mdash; [Fuzzing with Grammars (Expanding Parenthesized Expressions)](Grammars.ipynb#Expanding-Parenthesized-Expressions)
# * RFC 4180 &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `right()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `RISKY_NUMBERS` &mdash; [Probabilistic Grammar Fuzzing (Exercise 2: Learning from Past Bugs)](ProbabilisticGrammarFuzzer.ipynb#Exercise-2:-Learning-from-Past-Bugs), [Probabilistic Grammar Fuzzing (Exercise 2: Learning from Past Bugs)](ProbabilisticGrammarFuzzer.ipynb#Exercise-2:-Learning-from-Past-Bugs)
# * `rjust()` &mdash; [Tracking Information Flow (Justify)](InformationFlow.ipynb#Justify)
# * `__rmod__()` &mdash; [Tracking Information Flow (mod)](InformationFlow.ipynb#mod)
# * root node &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `rootIsBlack()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `roots()` &mdash; [Symbolic Fuzzing (Example: Roots of a Quadratic Equation)](SymbolicFuzzer.ipynb#Example:-Roots-of-a-Quadratic-Equation)
# * `roots2()` &mdash; [Symbolic Fuzzing ( Roots - Check Before Divide)](SymbolicFuzzer.ipynb#-Roots---Check-Before-Divide)
# * `roots3()` &mdash; [Symbolic Fuzzing ( Roots - Eliminating the Zero Division Error)](SymbolicFuzzer.ipynb#-Roots---Eliminating-the-Zero-Division-Error)
# * `round10()` &mdash; [Concolic Fuzzing (Example: Round)](ConcolicFuzzer.ipynb#Example:-Round)
# * `rpartition()` &mdash; [Tracking Information Flow (Partitions)](InformationFlow.ipynb#Partitions)
# * `RR_GRAMMAR2` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR3` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR4` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR5` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR6` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR7` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR8` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR9` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `rsplit()` &mdash; [Tracking Information Flow (Split)](InformationFlow.ipynb#Split)
# * `rstrip()` &mdash; [Tracking Information Flow (Strip)](InformationFlow.ipynb#Strip), [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends)
# * rules &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * `rules()` &mdash; [Parsing Inputs (Nullable)](Parser.ipynb#Nullable), [Parsing Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * `run()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Exercise 2: Run Simulated Troff)](Fuzzer.ipynb#Exercise-2:-Run-Simulated-Troff), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Greybox Fuzzing (Greybox Mutation-based Fuzzing)](GreyboxFuzzer.ipynb#Greybox-Mutation-based-Fuzzing), [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing), [Reducing Failure-Inducing Inputs (Why Reducing?)](Reducer.ipynb#Why-Reducing?), [Reducing Failure-Inducing Inputs (Lexical Reduction vs. Syntactic Rules)](Reducer.ipynb#Lexical-Reduction-vs.-Syntactic-Rules), [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Web Applications (Fuzzing with Unexpected Values)](WebFuzzer.ipynb#Fuzzing-with-Unexpected-Values), [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [When To Stop Fuzzing (Fuzzing the Enigma)](WhenToStopFuzzing.ipynb#Fuzzing-the-Enigma)
# * `Runner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `runs()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * `runTest()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `run_function()` &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `run_fuzzmanager()` &mdash; [Fuzzing in the Large (Excursion: Starting the Server)](FuzzingInTheLarge.ipynb#Excursion:-Starting-the-Server)
# * `run_fuzzmanager_forever()` &mdash; [Fuzzing in the Large (Excursion: Starting the Server)](FuzzingInTheLarge.ipynb#Excursion:-Starting-the-Server)
# * `run_generator()` &mdash; [Fuzzing with Generators (Generating Elements before Expansion)](GeneratorGrammarFuzzer.ipynb#Generating-Elements-before-Expansion), [Fuzzing with Generators (Support for Python Generators)](GeneratorGrammarFuzzer.ipynb#Support-for-Python-Generators)
# * `run_httpd_forever()` &mdash; [Testing Web Applications (Running the Server)](WebFuzzer.ipynb#Running-the-Server)
# * `run_post_functions()` &mdash; [Fuzzing with Generators (Checking and Repairing Elements after Expansion)](GeneratorGrammarFuzzer.ipynb#Checking-and-Repairing-Elements-after-Expansion)
# * `run_post_functions_locally()` &mdash; [Fuzzing with Generators (Local Checking and Repairing)](GeneratorGrammarFuzzer.ipynb#Local-Checking-and-Repairing)
# * `run_process()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)

# %% [markdown]
# ### S
#
# * S-EXP &mdash; [Concolic Fuzzing (Translating to the SMT Expression Format)](ConcolicFuzzer.ipynb#Translating-to-the-SMT-Expression-Format), [Concolic Fuzzing (Translating to the SMT Expression Format)](ConcolicFuzzer.ipynb#Translating-to-the-SMT-Expression-Format)
# * SAGE &mdash; [Symbolic Fuzzing (Background)](SymbolicFuzzer.ipynb#Background)
# * sample coverage &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * `sample_db()` &mdash; [Tracking Information Flow (Representing Tables)](InformationFlow.ipynb#Representing-Tables)
# * sanitization &mdash; [Tracking Information Flow (Tracking Untrusted Input)](InformationFlow.ipynb#Tracking-Untrusted-Input)
# * `sanitize()` &mdash; [Tracking Information Flow (Tracking Untrusted Input)](InformationFlow.ipynb#Tracking-Untrusted-Input)
# * Save &mdash; [Fuzzing in the Large (Crash Buckets)](FuzzingInTheLarge.ipynb#Crash-Buckets)
# * Scalene &mdash; [Symbolic Fuzzing (The CFG with Path Taken)](SymbolicFuzzer.ipynb#The-CFG-with-Path-Taken)
# * `scan()` &mdash; [Parsing Inputs (Scanning Tokens)](Parser.ipynb#Scanning-Tokens)
# * scanner &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * scope &mdash; [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `ScopedGrammarMiner` class &mdash; [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining)
# * `ScopedVars` class &mdash; [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `ScopeTracker` class &mdash; [Mining Input Grammars (Scope Tracker)](GrammarMiner.ipynb#Scope-Tracker), [Mining Input Grammars (Scope Tracker)](GrammarMiner.ipynb#Scope-Tracker)
# * `ScopeTreeMiner` class &mdash; [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `score()` &mdash; [Mutation Analysis (Evaluating Mutations)](MutationAnalysis.ipynb#Evaluating-Mutations), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * search &mdash; [Search-Based Fuzzing](SearchBasedFuzzer.ipynb#Search-Based-Fuzzing)
# * search space &mdash; [Search-Based Fuzzing (Test Generation as a Search Problem)](SearchBasedFuzzer.ipynb#Test-Generation-as-a-Search-Problem)
# * Search-based Fuzzing](SearchBasedFuzzer.ipynb). If you are interested, how to solve the problems above, you can have a look at our paper on "[Directed Greybox Fuzzing &mdash; [Greybox Fuzzing (Computing Function-Level Distance)](GreyboxFuzzer.ipynb#Computing-Function-Level-Distance)
# * `search_superclasses()` &mdash; [Class Diagrams (Getting Methods and Variables)](ClassDiagram.ipynb#Getting-Methods-and-Variables)
# * `second()` &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)
# * `SECRET_ORIGIN` &mdash; [Tracking Information Flow (Privacy Leaks Revisited)](InformationFlow.ipynb#Privacy-Leaks-Revisited), [Tracking Information Flow (Privacy Leaks Revisited)](InformationFlow.ipynb#Privacy-Leaks-Revisited), [Tracking Information Flow (Privacy Leaks Revisited)](InformationFlow.ipynb#Privacy-Leaks-Revisited)
# * `SECRET` &mdash; [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks)
# * seeds &mdash; [Fuzzing with Grammars (Grammars as Mutation Seeds)](Grammars.ipynb#Grammars-as-Mutation-Seeds)
# * `SeedWithRegions` class &mdash; [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation)
# * `SeedWithStructure` class &mdash; [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool)
# * `Seed` class &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules)
# * `selection()` &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * selective pressure &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * Selenium &mdash; [Testing Graphical User Interfaces (Automated GUI Interaction)](GUIFuzzer.ipynb#Automated-GUI-Interaction)
# * Selenium tests &mdash; [Testing Graphical User Interfaces (Writing Test Cases)](GUIFuzzer.ipynb#Writing-Test-Cases)
# * Selenium](https://www.seleniumhq.org) is a framework for testing Web applications by _automating interaction in the browser_.  Selenium provides an API that allows one to launch a Web browser, query the state of the user interface, and interact with individual user interface elements.  The Selenium API is available in a number of languages; we use the [Selenium API for Python &mdash; [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium)
# * `send_back()` &mdash; [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks)
# * `send_order_form()` &mdash; [Testing Web Applications (Order Form)](WebFuzzer.ipynb#Order-Form)
# * `send_order_received()` &mdash; [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders), [Testing Web Applications (Part 2: Sanitized HTML)](WebFuzzer.ipynb#Part-2:-Sanitized-HTML)
# * `send_terms_and_conditions()` &mdash; [Testing Web Applications (Order Form)](WebFuzzer.ipynb#Order-Form)
# * `Sequence` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `seq_vars()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * session cookie &mdash; [Testing Web Applications (Cross-Site Scripting Attacks)](WebFuzzer.ipynb#Cross-Site-Scripting-Attacks)
# * `__setitem__()` &mdash; [Mining Input Grammars (Vars)](GrammarMiner.ipynb#Vars)
# * `set_arguments()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `set_expansion_probabilities()` &mdash; [Probabilistic Grammar Fuzzing (Assigning Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Assigning-Probabilities)
# * `set_flatten_depth()` &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `set_grammar()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `set_invocation()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `_set_kv()` &mdash; [Mining Input Grammars (Vars)](GrammarMiner.ipynb#Vars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `set_opts()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `opts()`)](Grammars.ipynb#Excursion:-Implementing-`opts()`)
# * `set_parents()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `set_prob()` &mdash; [Probabilistic Grammar Fuzzing (Directed Fuzzing)](ProbabilisticGrammarFuzzer.ipynb#Directed-Fuzzing)
# * `set_probabilities()` &mdash; [Probabilistic Grammar Fuzzing (Assigning Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Assigning-Probabilities)
# * `SEXPR_TOKEN` &mdash; [Concolic Fuzzing (Using the Command Line)](ConcolicFuzzer.ipynb#Using-the-Command-Line)
# * Shellsort &mdash; [Introduction to Software Testing (Exercise 2: Testing Shellsort)](Intro_Testing.ipynb#Exercise-2:-Testing-Shellsort)
# * `shellsort()` &mdash; [Introduction to Software Testing (Exercise 2: Testing Shellsort)](Intro_Testing.ipynb#Exercise-2:-Testing-Shellsort)
# * short-circuit evaluation &mdash; [Search-Based Fuzzing (Dealing with Complex Conditions)](SearchBasedFuzzer.ipynb#Dealing-with-Complex-Conditions)
# * showast &mdash; [Mutation Analysis (Mutating Python Code)](MutationAnalysis.ipynb#Mutating-Python-Code), [Mining Function Specifications (Accessing Function Structure)](DynamicInvariants.ipynb#Accessing-Function-Structure)
# * `show_ast()` &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries), [Academic Prototyping (Static Analysis in Python: Still Easy)](AcademicPrototyping.ipynb#Static-Analysis-in-Python:-Still-Easy), [Prototyping with Python (Static Analysis in Python: Still Easy)](PrototypingWithPython.ipynb#Static-Analysis-in-Python:-Still-Easy)
# * `show_cfg()` &mdash; [Symbolic Fuzzing (The Control Flow Graph)](SymbolicFuzzer.ipynb#The-Control-Flow-Graph)
# * `show_coverage()` &mdash; [Mutation Analysis (Structural Coverage Adequacy by Example)](MutationAnalysis.ipynb#Structural-Coverage-Adequacy-by-Example), [Symbolic Fuzzing (Visualizing the Coverage)](SymbolicFuzzer.ipynb#Visualizing-the-Coverage)
# * `show_diagram()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `show_grammar()` &mdash; [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars)
# * `show_table()` &mdash; [Parsing Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * `SIGALRM` &mdash; [Timeout (Synopsis)](Timeout.ipynb#Synopsis), [Timeout (Synopsis)](Timeout.ipynb#Synopsis)
# * `SIGALRM` signals](https://docs.python.org/3.10/library/signal.html) (interrupts) to implement timeouts; this has no effect on performance of the tracked code. On other systems (notably Windows), `Timeout` uses the [`sys.settrace()` &mdash; [Timeout (Synopsis)](Timeout.ipynb#Synopsis), [Timeout (Synopsis)](Timeout.ipynb#Synopsis)
# * `SignalTimeout` class &mdash; [Timeout (Variant 1: Unix (using signals, efficient))](Timeout.ipynb#Variant-1:-Unix-(using-signals,-efficient))
# * Signatures &mdash; [Fuzzing in the Large (Crash Signatures)](FuzzingInTheLarge.ipynb#Crash-Signatures)
# * simple-crash &mdash; [Fuzzing in the Large (Collecting Crashes)](FuzzingInTheLarge.ipynb#Collecting-Crashes)
# * `SimpleConcolicFuzzer` class &mdash; [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class), [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class), [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class), [Concolic Fuzzing (The fuzzing method)](ConcolicFuzzer.ipynb#The-fuzzing-method)
# * `SimpleExtractor` class &mdash; [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor)
# * `SimpleGrammarCoverageFuzzer` class &mdash; [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions)
# * `SimpleHTTPRequestHandler` class &mdash; [Testing Web Applications (Excursion: Implementing a Web Server)](WebFuzzer.ipynb#Excursion:-Implementing-a-Web-Server), [Testing Web Applications (Handling HTTP Requests)](WebFuzzer.ipynb#Handling-HTTP-Requests), [Testing Web Applications (Order Form)](WebFuzzer.ipynb#Order-Form), [Testing Web Applications (Order Form)](WebFuzzer.ipynb#Order-Form), [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders), [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders), [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders), [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders), [Testing Web Applications (Other HTTP commands)](WebFuzzer.ipynb#Other-HTTP-commands), [Testing Web Applications (Page Not Found)](WebFuzzer.ipynb#Page-Not-Found), [Testing Web Applications (Internal Errors)](WebFuzzer.ipynb#Internal-Errors), [Testing Web Applications (Logging)](WebFuzzer.ipynb#Logging)
# * SimpleSymbolicFuzzer &mdash; [Symbolic Fuzzing (Problems with the Simple Fuzzer)](SymbolicFuzzer.ipynb#Problems-with-the-Simple-Fuzzer)
# * `SimpleSymbolicFuzzer` class &mdash; [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing), [Symbolic Fuzzing (Generating All Possible Paths)](SymbolicFuzzer.ipynb#Generating-All-Possible-Paths), [Symbolic Fuzzing (Generating All Possible Paths)](SymbolicFuzzer.ipynb#Generating-All-Possible-Paths), [Symbolic Fuzzing (Extracting All Constraints)](SymbolicFuzzer.ipynb#Extracting-All-Constraints), [Symbolic Fuzzing (Fuzzing with Simple Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Simple-Symbolic-Fuzzer), [Symbolic Fuzzing (Fuzzing with Simple Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Simple-Symbolic-Fuzzer), [Symbolic Fuzzing (Fuzzing with Simple Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Simple-Symbolic-Fuzzer)
# * `simple_call_string()` &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Carving Unit Tests (Recording my_sqrt())](Carver.ipynb#Recording-my_sqrt())
# * `simple_grammar_fuzzer()` &mdash; [Fuzzing with Grammars (A Simple Grammar Fuzzer)](Grammars.ipynb#A-Simple-Grammar-Fuzzer)
# * `simple_parse_csv()` &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * single &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * single-alternative &mdash; [Parsing Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser)
# * singleton species &mdash; [When To Stop Fuzzing (Exercises)](WhenToStopFuzzing.ipynb#Exercises)
# * `single_char_tokens()` &mdash; [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars)
# * sinks &mdash; [Tracking Information Flow (The Evil of Eval)](InformationFlow.ipynb#The-Evil-of-Eval)
# * `Skip` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * smaller number of valid inputs &mdash; [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing)
# * Smart Greybox Fuzzing](https://arxiv.org/abs/1811.09447)" by Pham and co-authors. Download and improve AFLSmart: [https://github.com/aflsmart/aflsmart &mdash; [Greybox Fuzzing with Grammars (Focusing on Valid Seeds)](GreyboxGrammarFuzzer.ipynb#Focusing-on-Valid-Seeds)
# * SMT Solver &mdash; [Concolic Fuzzing (Concolic Execution)](ConcolicFuzzer.ipynb#Concolic-Execution)
# * SMT solvers &mdash; [Concolic Fuzzing](ConcolicFuzzer.ipynb#Concolic-Fuzzing)
# * SMT solvers](https://en.wikipedia.org/wiki/Satisfiability_modulo_theories), especially [Z3 &mdash; [Symbolic Fuzzing](SymbolicFuzzer.ipynb#Symbolic-Fuzzing)
# * SMT-LIB &mdash; [Concolic Fuzzing (Translating to the SMT Expression Format)](ConcolicFuzzer.ipynb#Translating-to-the-SMT-Expression-Format)
# * SMT-LIB string library &mdash; [Fuzzing with Constraints (Part 2: Semantics)](FuzzingWithConstraints.ipynb#Part-2:-Semantics)
# * `smt_expr()` &mdash; [Concolic Fuzzing (Translating to the SMT Expression Format)](ConcolicFuzzer.ipynb#Translating-to-the-SMT-Expression-Format)
# * `smt_val()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * `solve_path_constraint()` &mdash; [Symbolic Fuzzing (Fuzzing with Simple Symbolic Fuzzer)](SymbolicFuzzer.ipynb#Fuzzing-with-Simple-Symbolic-Fuzzer), [Symbolic Fuzzing (Solving Path Constraints)](SymbolicFuzzer.ipynb#Solving-Path-Constraints)
# * some &mdash; [Greybox Fuzzing (AFL: An Effective Greybox Fuzzer)](GreyboxFuzzer.ipynb#AFL:-An-Effective-Greybox-Fuzzer), [Greybox Fuzzing with Grammars (Integration with Greybox Fuzzing)](GreyboxGrammarFuzzer.ipynb#Integration-with-Greybox-Fuzzing)
# * `some_long_running_function()` &mdash; [Timer (Measuring Time)](Timer.ipynb#Measuring-Time), [Timeout (Variant 1: Unix (using signals, efficient))](Timeout.ipynb#Variant-1:-Unix-(using-signals,-efficient))
# * sooo very slow &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Fuzzing)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Fuzzing)
# * `sort_by_prob()` &mdash; [Probabilistic Grammar Fuzzing (Testing Uncommon Features)](ProbabilisticGrammarFuzzer.ipynb#Testing-Uncommon-Features)
# * `source()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * sources &mdash; [Tracking Information Flow (The Evil of Eval)](InformationFlow.ipynb#The-Evil-of-Eval)
# * `span()` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * specific &mdash; [Search-Based Fuzzing](SearchBasedFuzzer.ipynb#Search-Based-Fuzzing)
# * `split()` &mdash; [Parsing Inputs (Excursion: Canonical Grammars)](Parser.ipynb#Excursion:-Canonical-Grammars), [Tracking Information Flow (Split)](InformationFlow.ipynb#Split), [Concolic Fuzzing (Splitting Strings)](ConcolicFuzzer.ipynb#Splitting-Strings)
# * `_split_helper()` &mdash; [Tracking Information Flow (Split)](InformationFlow.ipynb#Split)
# * `_split_space()` &mdash; [Tracking Information Flow (Split)](InformationFlow.ipynb#Split)
# * SQL commands &mdash; [Testing Web Applications (Storing Orders)](WebFuzzer.ipynb#Storing-Orders)
# * SQL injection &mdash; [Testing Web Applications (SQL Injection Attacks)](WebFuzzer.ipynb#SQL-Injection-Attacks)
# * `sql()` &mdash; [Tracking Information Flow (Executing SQL Statements)](InformationFlow.ipynb#Executing-SQL-Statements), [Tracking Information Flow (Tracking Untrusted Input)](InformationFlow.ipynb#Tracking-Untrusted-Input)
# * `SQLException` class &mdash; [Tracking Information Flow (A Vulnerable Database)](InformationFlow.ipynb#A-Vulnerable-Database)
# * `SQLInjectionFuzzer` class &mdash; [Testing Web Applications (Fully Automatic Web Attacks)](WebFuzzer.ipynb#Fully-Automatic-Web-Attacks)
# * `SQLInjectionGrammarMiner` class &mdash; [Testing Web Applications (Fully Automatic Web Attacks)](WebFuzzer.ipynb#Fully-Automatic-Web-Attacks)
# * `sqrt_program()` &mdash; [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input), [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input), [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input)
# * `srange()` &mdash; [Fuzzing with Grammars (Character Classes)](Grammars.ipynb#Character-Classes)
# * `src()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `stack_to_tree()` &mdash; [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack)
# * `Stack` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * STADS: Software Testing as Species Discovery &mdash; [When To Stop Fuzzing (Background)](WhenToStopFuzzing.ipynb#Background)
# * start symbol &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions), [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `startswith()` &mdash; [Concolic Fuzzing (Checking for String Prefixes)](ConcolicFuzzer.ipynb#Checking-for-String-Prefixes)
# * `start_httpd()` &mdash; [Testing Web Applications (Running the Server)](WebFuzzer.ipynb#Running-the-Server)
# * `START_STATE` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `start_symbol()` &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * `START_SYMBOL` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * `start_webdriver()` &mdash; [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium)
# * `Start` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * state &mdash; [Testing Graphical User Interfaces (End of Excursion)](GUIFuzzer.ipynb#End-of-Excursion)
# * State Machines &mdash; [Academic Prototyping (Replicable Experiments)](AcademicPrototyping.ipynb#Replicable-Experiments)
# * Statement coverage &mdash; [Code Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * states &mdash; [Testing Graphical User Interfaces (User Interfaces as Finite State Machines)](GUIFuzzer.ipynb#User-Interfaces-as-Finite-State-Machines)
# * `State` class &mdash; [Parsing Inputs (States)](Parser.ipynb#States), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * steepest ascent hillclimbing &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `steepest_ascent_hillclimber()` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `StmtDeletionMutator` class &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `store_order()` &mdash; [Testing Web Applications (Processing Orders)](WebFuzzer.ipynb#Processing-Orders), [Testing Web Applications (Part 3: Sanitized SQL)](WebFuzzer.ipynb#Part-3:-Sanitized-SQL)
# * String &mdash; [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining)
# * string inclusion &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `string_part_of_value()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `strip()` &mdash; [Tracking Information Flow (Strip)](InformationFlow.ipynb#Strip), [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends)
# * `strip_all_info()` &mdash; [Tracking Information Flow (Conversions)](InformationFlow.ipynb#Conversions)
# * `strip_all_info_again()` &mdash; [Tracking Information Flow (Implicit Information Flow)](InformationFlow.ipynb#Implicit-Information-Flow)
# * `STROKE_ODD_PIXEL_LENGTH` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `StrongShapeTest` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `strong_oracle()` &mdash; [Mutation Analysis (Structural Coverage Adequacy by Example)](MutationAnalysis.ipynb#Structural-Coverage-Adequacy-by-Example)
# * `__str__()` &mdash; [Greybox Fuzzing (Seeds and Power Schedules)](GreyboxFuzzer.ipynb#Seeds-and-Power-Schedules), [Parsing Inputs (Columns)](Parser.ipynb#Columns), [Parsing Inputs (States)](Parser.ipynb#States), [Parsing Inputs (Tree Extractor)](Parser.ipynb#Tree-Extractor), [Mining Input Grammars (CallStack)](GrammarMiner.ipynb#CallStack), [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (Taint Aware Fuzzing)](InformationFlow.ipynb#Taint-Aware-Fuzzing), [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (Part 3: Passing taints from integers to strings)](InformationFlow.ipynb#Part-3:-Passing-taints-from-integers-to-strings), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Symbolic Fuzzing (Stepwise Exploration of Paths)](SymbolicFuzzer.ipynb#Stepwise-Exploration-of-Paths), [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `Style` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * subclasses &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `submit()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Executing UI Actions)](GUIFuzzer.ipynb#Excursion:-Implementing-Executing-UI-Actions)
# * `subtrees_with_symbol()` &mdash; [Reducing Failure-Inducing Inputs (Finding Subtrees)](Reducer.ipynb#Finding-Subtrees)
# * `suite()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `sum()` &mdash; [Mining Function Specifications (Synopsis)](DynamicInvariants.ipynb#Synopsis)
# * `sum2()` &mdash; [Mining Function Specifications (Some Examples)](DynamicInvariants.ipynb#Some-Examples)
# * `sum3()` &mdash; [Mining Function Specifications (Multiple Types)](DynamicInvariants.ipynb#Multiple-Types)
# * `supported_opts()` &mdash; [Efficient Grammar Fuzzing (Excursion: `check_grammar()` implementation)](GrammarFuzzer.ipynb#Excursion:-`check_grammar()`-implementation), [Probabilistic Grammar Fuzzing (Expanding by Probability)](ProbabilisticGrammarFuzzer.ipynb#Expanding-by-Probability), [Fuzzing with Generators (A Class for Integrating Constraints)](GeneratorGrammarFuzzer.ipynb#A-Class-for-Integrating-Constraints), [Fuzzing with Generators (Generators and Probabilistic Fuzzing)](GeneratorGrammarFuzzer.ipynb#Generators-and-Probabilistic-Fuzzing), [Fuzzing with Generators (Generators and Grammar Coverage)](GeneratorGrammarFuzzer.ipynb#Generators-and-Grammar-Coverage)
# * `swapcase()` &mdash; [Tracking Information Flow (String methods that do not change origin)](InformationFlow.ipynb#String-methods-that-do-not-change-origin)
# * `swap_fragment()` &mdash; [Greybox Fuzzing with Grammars (Fragment-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Fragment-Based-Mutation), [Greybox Fuzzing with Grammars (Region-Based Mutation)](GreyboxGrammarFuzzer.ipynb#Region-Based-Mutation)
# * symbol table &mdash; [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses)
# * symbolic &mdash; [Symbolic Fuzzing (Check Before You Loop)](SymbolicFuzzer.ipynb#Check-Before-You-Loop)
# * symbolic fuzzer &mdash; [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing)
# * symbolic shadow variables &mdash; [Concolic Fuzzing (Solving Constraints)](ConcolicFuzzer.ipynb#Solving-Constraints)
# * symbolically &mdash; [Symbolic Fuzzing (Simple Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Simple-Symbolic-Fuzzing)
# * SymbolicFuzzer &mdash; [Symbolic Fuzzing ( Roots - Eliminating the Zero Division Error)](SymbolicFuzzer.ipynb#-Roots---Eliminating-the-Zero-Division-Error)
# * `SymbolicFuzzer` class &mdash; [Symbolic Fuzzing (Advanced Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Advanced-Symbolic-Fuzzing), [Symbolic Fuzzing (Check Before You Loop)](SymbolicFuzzer.ipynb#Check-Before-You-Loop), [Symbolic Fuzzing (Solving Path Constraints)](SymbolicFuzzer.ipynb#Solving-Path-Constraints), [Symbolic Fuzzing (Generating All Paths)](SymbolicFuzzer.ipynb#Generating-All-Paths), [Symbolic Fuzzing (Generating All Paths)](SymbolicFuzzer.ipynb#Generating-All-Paths), [Symbolic Fuzzing (Exercise 2: Statically checking if a loop should be unrolled further)](SymbolicFuzzer.ipynb#Exercise-2:-Statically-checking-if-a-loop-should-be-unrolled-further), [Symbolic Fuzzing (Exercise 2: Statically checking if a loop should be unrolled further)](SymbolicFuzzer.ipynb#Exercise-2:-Statically-checking-if-a-loop-should-be-unrolled-further)
# * `symbol_cost()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing Cost Functions)](GrammarFuzzer.ipynb#Excursion:-Implementing-Cost-Functions)
# * `SYMBOL_NAME` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `symbol_reductions()` &mdash; [Reducing Failure-Inducing Inputs (Both Strategies Together)](Reducer.ipynb#Both-Strategies-Together)
# * `SYMBOL_TABLE` &mdash; [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses)
# * `sym_to_float()` &mdash; [Symbolic Fuzzing (Example: Roots of a Quadratic Equation)](SymbolicFuzzer.ipynb#Example:-Roots-of-a-Quadratic-Equation)
# * `SYM_VARS_STR` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `SYM_VARS` &mdash; [Symbolic Fuzzing (The Control Flow Graph)](SymbolicFuzzer.ipynb#The-Control-Flow-Graph)
# * syntactical structure &mdash; [Fuzzing with Grammars (Grammars)](Grammars.ipynb#Grammars)
# * `syntax_diagram()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `syntax_diagram()`)](Grammars.ipynb#Excursion:-Implementing-`syntax_diagram()`)
# * `syntax_diagram_alt()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `syntax_diagram()`)](Grammars.ipynb#Excursion:-Implementing-`syntax_diagram()`)
# * `syntax_diagram_expr()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `syntax_diagram()`)](Grammars.ipynb#Excursion:-Implementing-`syntax_diagram()`)
# * `syntax_diagram_symbol()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `syntax_diagram()`)](Grammars.ipynb#Excursion:-Implementing-`syntax_diagram()`)
# * system input &mdash; [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input)

# %% [markdown]
# ### T
#
# * `_t()` &mdash; [Parsing Inputs (States)](Parser.ipynb#States), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `table()` &mdash; [Tracking Information Flow (Representing Tables)](InformationFlow.ipynb#Representing-Tables), [Concolic Fuzzing (Example: Database)](ConcolicFuzzer.ipynb#Example:-Database)
# * taint &mdash; [Tracking Information Flow (The Evil of Eval)](InformationFlow.ipynb#The-Evil-of-Eval)
# * taint sanitizers &mdash; [Tracking Information Flow (The Evil of Eval)](InformationFlow.ipynb#The-Evil-of-Eval)
# * `TaintedDB` class &mdash; [Tracking Information Flow (TaintedDB)](InformationFlow.ipynb#TaintedDB)
# * `TaintedGrammarFuzzer` class &mdash; [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer)
# * `TaintedInputStack` class &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow), [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `TaintedScopedGrammarMiner` class &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `TaintedScopedVars` class &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `TaintedScopeTracker` class &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `TaintedScopeTreeMiner` class &mdash; [Mining Input Grammars (Exercise 2: Incorporating Taints from InformationFlow)](GrammarMiner.ipynb#Exercise-2:-Incorporating-Taints-from-InformationFlow)
# * `Tainted` class &mdash; [Tracking Information Flow (Taint Aware Fuzzing)](InformationFlow.ipynb#Taint-Aware-Fuzzing)
# * `target_tile()` &mdash; [Greybox Fuzzing (Solving the Maze)](GreyboxFuzzer.ipynb#Solving-the-Maze), [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze), [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * terminal symbol &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `terminals()` &mdash; [Parsing Inputs (Nullable)](Parser.ipynb#Nullable)
# * `terminal_repr()` &mdash; [Search-Based Fuzzing (Evolutionary Search)](SearchBasedFuzzer.ipynb#Evolutionary-Search)
# * `Terminal` class &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * test &mdash; [Introduction to Software Testing (Running a Function)](Intro_Testing.ipynb#Running-a-Function)
# * `test()` &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * `TestGCD` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Synopsis)](MutationAnalysis.ipynb#Synopsis)
# * `test_equilateral()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `test_isosceles()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `test_me()` &mdash; [Search-Based Fuzzing (Representing Program Inputs as a Search Problem)](SearchBasedFuzzer.ipynb#Representing-Program-Inputs-as-a-Search-Problem)
# * `test_me2()` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `test_me2_instrumented()` &mdash; [Search-Based Fuzzing (Hillclimbing the Example)](SearchBasedFuzzer.ipynb#Hillclimbing-the-Example)
# * `test_me_instrumented()` &mdash; [Search-Based Fuzzing (Instrumentation)](SearchBasedFuzzer.ipynb#Instrumentation), [Search-Based Fuzzing (Instrumentation)](SearchBasedFuzzer.ipynb#Instrumentation)
# * `test_mirror()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Synopsis)](MutationAnalysis.ipynb#Synopsis)
# * `test_scalene()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `test_simple()` &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites), [Mutation Analysis (Synopsis)](MutationAnalysis.ipynb#Synopsis)
# * `test_successful_order()` &mdash; [Testing Graphical User Interfaces (Writing Test Cases)](GUIFuzzer.ipynb#Writing-Test-Cases)
# * the ConfigParser documentation &mdash; [Testing Configurations (Exercise 2: .ini Configuration Fuzzing)](ConfigurationFuzzer.ipynb#Exercise-2:-.ini-Configuration-Fuzzing)
# * "The state of type hints in Python" &mdash; [Mining Function Specifications (Background)](DynamicInvariants.ipynb#Background)
# * this &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * this article &mdash; [Probabilistic Grammar Fuzzing (Background)](ProbabilisticGrammarFuzzer.ipynb#Background)
# * this commit &mdash; [Concolic Fuzzing (Hack to use the ASCII value of a character.)](ConcolicFuzzer.ipynb#Hack-to-use-the-ASCII-value-of-a-character.)
# * this handy trick &mdash; [Fuzzing in the Large (Excursion: Setting up the Server)](FuzzingInTheLarge.ipynb#Excursion:-Setting-up-the-Server)
# * throw away the result &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `tile_()` &mdash; [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze), [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze), [Control Flow Graph (Example: Maze)](ControlFlow.ipynb#Example:-Maze)
# * `timeout_handler()` &mdash; [Timeout (Variant 1: Unix (using signals, efficient))](Timeout.ipynb#Variant-1:-Unix-(using-signals,-efficient))
# * `Timer` class &mdash; [Timer (Measuring Time)](Timer.ipynb#Measuring-Time)
# * `tint` class &mdash; [Tracking Information Flow (Part 1: Creation)](InformationFlow.ipynb#Part-1:-Creation), [Tracking Information Flow (Part 2: Arithmetic expressions)](InformationFlow.ipynb#Part-2:-Arithmetic-expressions), [Tracking Information Flow (Part 3: Passing taints from integers to strings)](InformationFlow.ipynb#Part-3:-Passing-taints-from-integers-to-strings), [Tracking Information Flow (Part 3: Passing taints from integers to strings)](InformationFlow.ipynb#Part-3:-Passing-taints-from-integers-to-strings), [Tracking Information Flow (Part 4: Passing taints from strings to integers)](InformationFlow.ipynb#Part-4:-Passing-taints-from-strings-to-integers)
# * `title()` &mdash; [Tracking Information Flow (String methods that do not change origin)](InformationFlow.ipynb#String-methods-that-do-not-change-origin)
# * together &mdash; [Mutation Analysis (Exercise 4: Estimating Residual Defect Density)](MutationAnalysis.ipynb#Exercise-4:-Estimating-Residual-Defect-Density)
# * tokenizer &mdash; [Parsing Inputs (A Parser Class)](Parser.ipynb#A-Parser-Class)
# * top to bottom &mdash; [Parsing Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * topmost &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * tournament selection &mdash; [Search-Based Fuzzing (Genetic Algorithms)](SearchBasedFuzzer.ipynb#Genetic-Algorithms)
# * `to_graph()` &mdash; [Control Flow Graph (Supporting Functions)](ControlFlow.ipynb#Supporting-Functions)
# * `to_json()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode)
# * `to_nonterminal()` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree)
# * `to_single_assignment_predicates()` &mdash; [Symbolic Fuzzing (Renaming Used Variables)](SymbolicFuzzer.ipynb#Renaming-Used-Variables)
# * `to_src()` &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * `trace()` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * `traceit()` &mdash; [Code Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions), [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Mining Input Grammars (Tracer)](GrammarMiner.ipynb#Tracer), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Concolic Fuzzing (Tracking Constraints)](ConcolicFuzzer.ipynb#Tracking-Constraints), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Carving Unit Tests (Exercises)](Carver.ipynb#Exercises), [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results), [Academic Prototyping (Dynamic Analysis in Python: So Easy it Hurts)](AcademicPrototyping.ipynb#Dynamic-Analysis-in-Python:-So-Easy-it-Hurts), [Prototyping with Python (Dynamic Analysis in Python: So Easy it Hurts)](PrototypingWithPython.ipynb#Dynamic-Analysis-in-Python:-So-Easy-it-Hurts)
# * `TraceNode` class &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * `Tracer` class &mdash; [Mining Input Grammars (Tracer)](GrammarMiner.ipynb#Tracer), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context), [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `TraceTree` class &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions), [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)
# * `trace_call()` &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls)
# * `trace_locals()` &mdash; [Testing Configurations (Tracking Arguments)](ConfigurationFuzzer.ipynb#Tracking-Arguments)
# * `trace_options()` &mdash; [Testing Configurations (Tracking Arguments)](ConfigurationFuzzer.ipynb#Tracking-Arguments)
# * `trace_return()` &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls)
# * tracing function &mdash; [Code Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions)
# * `tracing_context()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `tracing_var()` &mdash; [Mining Input Grammars (Context)](GrammarMiner.ipynb#Context)
# * `Tracker` class &mdash; [Mining Function Specifications (Tracking Calls)](DynamicInvariants.ipynb#Tracking-Calls)
# * `TrackingArcCoverage` class &mdash; [Symbolic Fuzzing (Exercise 3: Implementing a Concolic Fuzzer)](SymbolicFuzzer.ipynb#Exercise-3:-Implementing-a-Concolic-Fuzzer)
# * `TrackingConfigParser` class &mdash; [Testing Configurations (Part 3: Mine a Configuration Grammar)](ConfigurationFuzzer.ipynb#Part-3:-Mine-a-Configuration-Grammar)
# * `TrackingDB` class &mdash; [Tracking Information Flow (TrackingDB)](InformationFlow.ipynb#TrackingDB)
# * `TrackingGrammarCoverageFuzzer` class &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage), [Grammar Coverage (Keeping Track of Expansions)](GrammarCoverageFuzzer.ipynb#Keeping-Track-of-Expansions), [Grammar Coverage (Computing Possible Expansions)](GrammarCoverageFuzzer.ipynb#Computing-Possible-Expansions), [Grammar Coverage (Tracking Expansions while Fuzzing)](GrammarCoverageFuzzer.ipynb#Tracking-Expansions-while-Fuzzing), [Grammar Coverage (Tracking Expansions while Fuzzing)](GrammarCoverageFuzzer.ipynb#Tracking-Expansions-while-Fuzzing)
# * `track_event()` &mdash; [Mining Input Grammars (DefineTracker)](GrammarMiner.ipynb#DefineTracker), [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * transitive &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `translate_to_z3_name()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `traverse()` &mdash; [Academic Prototyping (Static Analysis in Python: Still Easy)](AcademicPrototyping.ipynb#Static-Analysis-in-Python:-Still-Easy), [Academic Prototyping (A Symbolic Test Generator)](AcademicPrototyping.ipynb#A-Symbolic-Test-Generator), [Prototyping with Python (Static Analysis in Python: Still Easy)](PrototypingWithPython.ipynb#Static-Analysis-in-Python:-Still-Easy), [Prototyping with Python (A Symbolic Test Generator)](PrototypingWithPython.ipynb#A-Symbolic-Test-Generator)
# * `traverse_if_children()` &mdash; [Academic Prototyping (A Symbolic Test Generator)](AcademicPrototyping.ipynb#A-Symbolic-Test-Generator), [Prototyping with Python (A Symbolic Test Generator)](PrototypingWithPython.ipynb#A-Symbolic-Test-Generator)
# * `traverse_tree()` &mdash; [Efficient Grammar Fuzzing (Excursion: Implementing `display_tree()`)](GrammarFuzzer.ipynb#Excursion:-Implementing-`display_tree()`), [Class Diagrams (Getting a Class Tree)](ClassDiagram.ipynb#Getting-a-Class-Tree)
# * `traverse_z3()` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * Tree Maps &mdash; [Academic Prototyping (Replicable Experiments)](AcademicPrototyping.ipynb#Replicable-Experiments)
# * `TreeMiner` class &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Recovering a Derivation Tree)](GrammarMiner.ipynb#Recovering-a-Derivation-Tree)
# * `tree_list_to_string()` &mdash; [Reducing Failure-Inducing Inputs (A Few Helpers)](Reducer.ipynb#A-Few-Helpers)
# * `TREE_NODES` &mdash; [Concolic Fuzzing (The SimpleConcolicFuzzer class)](ConcolicFuzzer.ipynb#The-SimpleConcolicFuzzer-class)
# * `tree_to_grammar()` &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining)
# * `tree_to_string()` &mdash; [Efficient Grammar Fuzzing (End of Excursion)](GrammarFuzzer.ipynb#End-of-Excursion), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer), [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * `tree_type()` &mdash; [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer)
# * `TRIALS` &mdash; [Fuzzing in the Large (End of Excursion)](FuzzingInTheLarge.ipynb#End-of-Excursion), [Fuzzing in the Large (Collecting Code Coverage)](FuzzingInTheLarge.ipynb#Collecting-Code-Coverage)
# * `triangle()` &mdash; [Mutation Analysis (Structural Coverage Adequacy by Example)](MutationAnalysis.ipynb#Structural-Coverage-Adequacy-by-Example), [Concolic Fuzzing (Translating to the SMT Expression Format)](ConcolicFuzzer.ipynb#Translating-to-the-SMT-Expression-Format), [Academic Prototyping (Python is Easy)](AcademicPrototyping.ipynb#Python-is-Easy), [Prototyping with Python (Python is Easy)](PrototypingWithPython.ipynb#Python-is-Easy)
# * `triangle_m1()` &mdash; [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults)
# * `triangle_traced()` &mdash; [Academic Prototyping (Dynamic Analysis in Python: So Easy it Hurts)](AcademicPrototyping.ipynb#Dynamic-Analysis-in-Python:-So-Easy-it-Hurts), [Prototyping with Python (Dynamic Analysis in Python: So Easy it Hurts)](PrototypingWithPython.ipynb#Dynamic-Analysis-in-Python:-So-Easy-it-Hurts)
# * trigram &mdash; [When To Stop Fuzzing (The Enigma Machine)](WhenToStopFuzzing.ipynb#The-Enigma-Machine)
# * `TroffRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 2: Run Simulated Troff)](Fuzzer.ipynb#Exercise-2:-Run-Simulated-Troff)
# * `true_property_instantiations()` &mdash; [Mining Function Specifications (Checking Invariants)](DynamicInvariants.ipynb#Checking-Invariants)
# * `TrustedDB` class &mdash; [Tracking Information Flow (Tracking Untrusted Input)](InformationFlow.ipynb#Tracking-Untrusted-Input)
# * `TRUSTED` &mdash; [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks)
# * `TState` class &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `tstr1()` &mdash; [Concolic Fuzzing (Equality between Strings)](ConcolicFuzzer.ipynb#Equality-between-Strings), [Concolic Fuzzing (Equality between Strings)](ConcolicFuzzer.ipynb#Equality-between-Strings)
# * `tstr10()` &mdash; [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends)
# * `tstr11()` &mdash; [Concolic Fuzzing (Splitting Strings)](ConcolicFuzzer.ipynb#Splitting-Strings)
# * `tstr2()` &mdash; [Concolic Fuzzing (Length of Strings)](ConcolicFuzzer.ipynb#Length-of-Strings)
# * `tstr3()` &mdash; [Concolic Fuzzing (An Iterator Class for Strings)](ConcolicFuzzer.ipynb#An-Iterator-Class-for-Strings)
# * `tstr4()` &mdash; [Concolic Fuzzing (Translating to Upper and Lower Equivalents)](ConcolicFuzzer.ipynb#Translating-to-Upper-and-Lower-Equivalents)
# * `tstr5()` &mdash; [Concolic Fuzzing (Translating to Upper and Lower Equivalents)](ConcolicFuzzer.ipynb#Translating-to-Upper-and-Lower-Equivalents)
# * `tstr6()` &mdash; [Concolic Fuzzing (Checking for String Prefixes)](ConcolicFuzzer.ipynb#Checking-for-String-Prefixes)
# * `tstr7()` &mdash; [Concolic Fuzzing (Finding Substrings)](ConcolicFuzzer.ipynb#Finding-Substrings)
# * `tstr8()` &mdash; [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends)
# * `tstr9()` &mdash; [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends)
# * `tstr` class &mdash; [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (A Class for Tainted Strings)](InformationFlow.ipynb#A-Class-for-Tainted-Strings), [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators), [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators), [Tracking Information Flow (String Operators)](InformationFlow.ipynb#String-Operators)
# * Turing machines &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * twice &mdash; [Search-Based Fuzzing (Dealing with Complex Conditions)](SearchBasedFuzzer.ipynb#Dealing-with-Complex-Conditions)
# * `twice()` &mdash; [Testing Configurations (Creating Autopep8 Options)](ConfigurationFuzzer.ipynb#Creating-Autopep8-Options)
# * two &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries), [When To Stop Fuzzing (Measuring Trace Coverage over Time)](WhenToStopFuzzing.ipynb#Measuring-Trace-Coverage-over-Time)
# * type annotations &mdash; [Symbolic Fuzzing](SymbolicFuzzer.ipynb#Symbolic-Fuzzing)
# * `TypeAnnotator` class &mdash; [Mining Function Specifications (All-in-one Annotation)](DynamicInvariants.ipynb#All-in-one-Annotation)
# * `typed_functions()` &mdash; [Mining Function Specifications (All-in-one Annotation)](DynamicInvariants.ipynb#All-in-one-Annotation)
# * `typed_functions_ast()` &mdash; [Mining Function Specifications (All-in-one Annotation)](DynamicInvariants.ipynb#All-in-one-Annotation)
# * `typed_triangle()` &mdash; [Academic Prototyping ((No) Type Checking)](AcademicPrototyping.ipynb#(No)-Type-Checking), [Prototyping with Python ((No) Type Checking)](PrototypingWithPython.ipynb#(No)-Type-Checking)
# * types &mdash; [Mining Function Specifications (Specifying and Checking Data Types)](DynamicInvariants.ipynb#Specifying-and-Checking-Data-Types)
# * `TypeTracker` class &mdash; [Mining Function Specifications (All-in-one Annotation)](DynamicInvariants.ipynb#All-in-one-Annotation)
# * `TypeTransformer` class &mdash; [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types), [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types), [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types)
# * `type_string()` &mdash; [Mining Function Specifications (Annotating Functions with Mined Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Mined-Types)
# * `TYPE` &mdash; [Fuzzing with Constraints (Quantifiers)](FuzzingWithConstraints.ipynb#Quantifiers)

# %% [markdown]
# ## U - Y

# %% [markdown]
# ### U
#
# * `UNEXPLORED_STATE` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing Extracting State Grammars)](GUIFuzzer.ipynb#Excursion:-Implementing-Extracting-State-Grammars)
# * `unhack()` &mdash; [Control Flow Graph (Supporting Functions)](ControlFlow.ipynb#Supporting-Functions)
# * `unicode_escape()` &mdash; [Fuzzing in the Large (Excursion: `escapelines()` implementatipn)](FuzzingInTheLarge.ipynb#Excursion:-`escapelines()`-implementatipn)
# * `unicode_string_neighbors()` &mdash; [Search-Based Fuzzing (Evolutionary Search)](SearchBasedFuzzer.ipynb#Evolutionary-Search)
# * `unify_key()` &mdash; [Parsing Inputs (Unify Key)](Parser.ipynb#Unify-Key), [Parsing Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * `unify_rule()` &mdash; [Parsing Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * `uniq_postdot()` &mdash; [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * universal grammars &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `unknown()` &mdash; [Class Diagrams (Getting Docs)](ClassDiagram.ipynb#Getting-Docs)
# * `UNKNOWN_ORIGIN` &mdash; [Tracking Information Flow (A Class for Tracking Character Origins)](InformationFlow.ipynb#A-Class-for-Tracking-Character-Origins), [Tracking Information Flow (Privacy Leaks Revisited)](InformationFlow.ipynb#Privacy-Leaks-Revisited)
# * unobserved &mdash; [When To Stop Fuzzing (Turing's Observations)](WhenToStopFuzzing.ipynb#Turing's-Observations)
# * unparse &mdash; [Symbolic Fuzzing (Function Summaries)](SymbolicFuzzer.ipynb#Function-Summaries)
# * `unreachable_nonterminals()` &mdash; [Fuzzing with Grammars (Excursion: Implementing `is_valid_grammar()`)](Grammars.ipynb#Excursion:-Implementing-`is_valid_grammar()`)
# * `UNRESOLVED` &mdash; [Fuzzing: Breaking Things with Random Inputs (Synopsis)](Fuzzer.ipynb#Synopsis), [Fuzzing: Breaking Things with Random Inputs (Synopsis)](Fuzzer.ipynb#Synopsis), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runners)](Fuzzer.ipynb#Runners), [Fuzzing: Breaking Things with Random Inputs (Runners)](Fuzzer.ipynb#Runners), [Reducing Failure-Inducing Inputs (End of Excursion)](Reducer.ipynb#End-of-Excursion)
# * unrolling of loops &mdash; [Symbolic Fuzzing (Advanced Symbolic Fuzzing)](SymbolicFuzzer.ipynb#Advanced-Symbolic-Fuzzing)
# * `UNTRUSTED` &mdash; [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks), [Tracking Information Flow (Preventing Privacy Leaks)](InformationFlow.ipynb#Preventing-Privacy-Leaks)
# * unusual paths &mdash; [Greybox Fuzzing (Boosted Greybox Fuzzing)](GreyboxFuzzer.ipynb#Boosted-Greybox-Fuzzing)
# * `unwrap_substrings()` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * `up()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `update()` &mdash; [Mining Input Grammars (Vars)](GrammarMiner.ipynb#Vars), [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `update_cache()` &mdash; [Parsing Inputs (Why Parsing for Fuzzing?)](Parser.ipynb#Why-Parsing-for-Fuzzing?)
# * `update_children()` &mdash; [Control Flow Graph (CFGNode)](ControlFlow.ipynb#CFGNode), [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `update_existing_state()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer), [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `update_functions()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `update_grammar()` &mdash; [Mining Input Grammars (Recovering Grammars from Derivation Trees)](GrammarMiner.ipynb#Recovering-Grammars-from-Derivation-Trees), [Mining Input Grammars (Recover Grammar)](GrammarMiner.ipynb#Recover-Grammar), [Mining Input Grammars (Grammar Mining)](GrammarMiner.ipynb#Grammar-Mining), [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer), [Concolic Fuzzing (Pruning and Updating)](ConcolicFuzzer.ipynb#Pruning-and-Updating)
# * `update_inventory()` &mdash; [Tracking Information Flow (End of Excursion)](InformationFlow.ipynb#End-of-Excursion)
# * `update_maps()` &mdash; [Search-Based Fuzzing (Instrumentation for Atomic Conditions)](SearchBasedFuzzer.ipynb#Instrumentation-for-Atomic-Conditions)
# * `update_new_state()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `update_state()` &mdash; [Testing Graphical User Interfaces (Excursion: Implementing GUIFuzzer)](GUIFuzzer.ipynb#Excursion:-Implementing-GUIFuzzer)
# * `update_tree()` &mdash; [Tracking Information Flow (TaintedGrammarFuzzer)](InformationFlow.ipynb#TaintedGrammarFuzzer)
# * `upper()` &mdash; [Tracking Information Flow (String methods that do not change origin)](InformationFlow.ipynb#String-methods-that-do-not-change-origin), [Concolic Fuzzing (Translating to Upper and Lower Equivalents)](ConcolicFuzzer.ipynb#Translating-to-Upper-and-Lower-Equivalents)
# * urllib/parse.py &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `URLPARSE_ORACLE_GRAMMAR` &mdash; [Fuzzing APIs (Exercise 1: Deep Arguments)](APIFuzzer.ipynb#Exercise-1:-Deep-Arguments)
# * `URLS_X` &mdash; [Mining Input Grammars (Problems with the Simple Miner)](GrammarMiner.ipynb#Problems-with-the-Simple-Miner)
# * `URLS` &mdash; [Mining Input Grammars (Example 2. Recovering URL Grammar)](GrammarMiner.ipynb#Example-2.-Recovering-URL-Grammar)
# * `url_parse()` &mdash; [Mining Input Grammars (Example 2. Recovering URL Grammar)](GrammarMiner.ipynb#Example-2.-Recovering-URL-Grammar)
# * `used_identifiers()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `used_vars()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * user interface elements &mdash; [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium)
# * `use_id()` &mdash; [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses)

# %% [markdown]
# ### V
#
# * `v()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `V1` &mdash; [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree), [Mining Input Grammars (Assembling a Derivation Tree)](GrammarMiner.ipynb#Assembling-a-Derivation-Tree)
# * valid &mdash; [Mutation Analysis (Injecting Artificial Faults)](MutationAnalysis.ipynb#Injecting-Artificial-Faults)
# * `valid_luhn_checksum()` &mdash; [Fuzzing with Generators (Functions Called After Expansion)](GeneratorGrammarFuzzer.ipynb#Functions-Called-After-Expansion)
# * `VALUES` &mdash; [Tracking Information Flow (Inserting Data)](InformationFlow.ipynb#Inserting-Data)
# * `VARIABLE` &mdash; [Code Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Fuzzing with Constraints (Quantifiers)](FuzzingWithConstraints.ipynb#Quantifiers), [Fuzzing with Constraints (Quantifiers)](FuzzingWithConstraints.ipynb#Quantifiers), [Fuzzing with Constraints (Matching Expansion Elements)](FuzzingWithConstraints.ipynb#Matching-Expansion-Elements), [Fuzzing with Constraints (Matching Expansion Elements)](FuzzingWithConstraints.ipynb#Matching-Expansion-Elements)
# * `Vars` class &mdash; [Mining Input Grammars (Vars)](GrammarMiner.ipynb#Vars), [Mining Input Grammars (Vars)](GrammarMiner.ipynb#Vars)
# * `var_access()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `var_assign()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `VAR_GRAMMAR` &mdash; [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses), [Fuzzing with Generators (Definitions and Uses)](GeneratorGrammarFuzzer.ipynb#Definitions-and-Uses)
# * `var_location_register()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `var_name()` &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars), [Mining Input Grammars (ScopedVars)](GrammarMiner.ipynb#ScopedVars)
# * `var_string()` &mdash; [Class Diagrams (Drawing Class Hierarchy with Method Names)](ClassDiagram.ipynb#Drawing-Class-Hierarchy-with-Method-Names)
# * `var_symbol()` &mdash; [Carving Unit Tests (A Grammar from Arguments)](Carver.ipynb#A-Grammar-from-Arguments)
# * `VAR` &mdash; [Class Diagrams (Getting a Class Hierarchy)](ClassDiagram.ipynb#Getting-a-Class-Hierarchy)
# * `VEHICLES` &mdash; [Mining Input Grammars (A Simple Grammar Miner)](GrammarMiner.ipynb#A-Simple-Grammar-Miner), [Tracking Information Flow (A Vulnerable Database)](InformationFlow.ipynb#A-Vulnerable-Database), [Tracking Information Flow (End of Excursion)](InformationFlow.ipynb#End-of-Excursion)
# * `Vehicle` class &mdash; [Mining Input Grammars (Exercise 1: Flattening complex objects)](GrammarMiner.ipynb#Exercise-1:-Flattening-complex-objects)
# * `verbose_condition()` &mdash; [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers)
# * `verbose_postcondition()` &mdash; [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers)
# * `verbose_precondition()` &mdash; [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers)
# * virtual variable &mdash; [Mining Input Grammars (AssignmentTracker)](GrammarMiner.ipynb#AssignmentTracker)
# * `visit_AnnAssign()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Assert()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Assign()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_AugAssign()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_BinOp()` &mdash; [Mutation Analysis (Exercise 1: Arithmetic Expression Mutators)](MutationAnalysis.ipynb#Exercise-1:-Arithmetic-Expression-Mutators)
# * `visit_Break()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Compare()` &mdash; [Search-Based Fuzzing (Instrumenting Source Code Automatically)](SearchBasedFuzzer.ipynb#Instrumenting-Source-Code-Automatically)
# * `visit_Continue()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Delete()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Expr()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions), [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types)
# * `visit_FunctionDef()` &mdash; [Search-Based Fuzzing (Instrumenting Source Code Automatically)](SearchBasedFuzzer.ipynb#Instrumenting-Source-Code-Automatically), [Mining Function Specifications (Annotating Functions with Given Types)](DynamicInvariants.ipynb#Annotating-Functions-with-Given-Types), [Mining Function Specifications (Exercise 9: Embedding Invariants as Assertions)](DynamicInvariants.ipynb#Exercise-9:-Embedding-Invariants-as-Assertions)
# * `visit_Global()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Name()` &mdash; [Mining Function Specifications (Extracting Meta-Variables)](DynamicInvariants.ipynb#Extracting-Meta-Variables), [Mining Function Specifications (Instantiating Properties)](DynamicInvariants.ipynb#Instantiating-Properties)
# * `visit_Nonlocal()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Pass()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Raise()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_Return()` &mdash; [Mutation Analysis (A Simple Mutator for Functions)](MutationAnalysis.ipynb#A-Simple-Mutator-for-Functions)
# * `visit_z3_expr()` &mdash; [Concolic Fuzzing (Hack to use the ASCII value of a character.)](ConcolicFuzzer.ipynb#Hack-to-use-the-ASCII-value-of-a-character.)
# * `VisualCoverage` class &mdash; [Mutation Analysis (Structural Coverage Adequacy by Example)](MutationAnalysis.ipynb#Structural-Coverage-Adequacy-by-Example)
# * `VisualizedArcCoverage` class &mdash; [Symbolic Fuzzing (Visualizing the Coverage)](SymbolicFuzzer.ipynb#Visualizing-the-Coverage)
# * `VS` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)

# %% [markdown]
# ### W
#
# * `walk()` &mdash; [Control Flow Graph (PyCFG)](ControlFlow.ipynb#PyCFG)
# * `was_seen()` &mdash; [Parsing Inputs (Exercise 6: Filtered Earley Parser)](Parser.ipynb#Exercise-6:-Filtered-Earley-Parser)
# * `WeakShapeTest` class &mdash; [Mutation Analysis (Mutator for Modules and Test Suites)](MutationAnalysis.ipynb#Mutator-for-Modules-and-Test-Suites)
# * `weak_oracle()` &mdash; [Mutation Analysis (Structural Coverage Adequacy by Example)](MutationAnalysis.ipynb#Structural-Coverage-Adequacy-by-Example)
# * web driver &mdash; [Testing Graphical User Interfaces (Remote Control with Selenium)](GUIFuzzer.ipynb#Remote-Control-with-Selenium)
# * `webbrowser()` &mdash; [Carving Unit Tests (System Tests vs Unit Tests)](Carver.ipynb#System-Tests-vs-Unit-Tests), [Testing Web Applications (Logging)](WebFuzzer.ipynb#Logging)
# * `WebFormFuzzer` class &mdash; [Testing Web Applications (A Fuzzer for Web Forms)](WebFuzzer.ipynb#A-Fuzzer-for-Web-Forms)
# * `WebRunner` class &mdash; [Testing Web Applications (Fuzzing with Unexpected Values)](WebFuzzer.ipynb#Fuzzing-with-Unexpected-Values)
# * weight &mdash; [When To Stop Fuzzing (The Kenngruppenbuch)](WhenToStopFuzzing.ipynb#The-Kenngruppenbuch)
# * `WHERE` &mdash; [Tracking Information Flow (Deleting Data)](InformationFlow.ipynb#Deleting-Data)
# * white-box testing &mdash; [Code Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * Wikipedia page on file formats &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * Wikipedia page on penetration testing &mdash; [Testing Web Applications (Background)](WebFuzzer.ipynb#Background)
# * Wikipedia pages on Web application security &mdash; [Testing Web Applications (Background)](WebFuzzer.ipynb#Background)
# * within this method &mdash; [Mining Input Grammars (AssignmentVars)](GrammarMiner.ipynb#AssignmentVars)
# * `wrapper()` &mdash; [Mining Function Specifications (Annotating Functions with Pre- and Postconditions)](DynamicInvariants.ipynb#Annotating-Functions-with-Pre--and-Postconditions), [Mining Function Specifications (Exercise 3: Verbose Invariant Checkers)](DynamicInvariants.ipynb#Exercise-3:-Verbose-Invariant-Checkers)
# * `wrapString()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `writeSvg()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation), [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)

# %% [markdown]
# ### X
#
# * `x()` &mdash; [Tracking Information Flow (Extract Origin String)](InformationFlow.ipynb#Extract-Origin-String)
# * XKCD comic &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * XML documents &mdash; [Fuzzing with Generators (Example: Matching XML Tags)](GeneratorGrammarFuzzer.ipynb#Example:-Matching-XML-Tags)
# * `XML_GRAMMAR` &mdash; [Greybox Fuzzing with Grammars (Building the Fragment Pool)](GreyboxGrammarFuzzer.ipynb#Building-the-Fragment-Pool)
# * `XML_UNICODE_WCHAR_T` &mdash; [Testing Configurations (Part 3: C Preprocessor Configuration Fuzzing)](ConfigurationFuzzer.ipynb#Part-3:-C-Preprocessor-Configuration-Fuzzing)
# * XSS &mdash; [Testing Web Applications (Cross-Site Scripting Attacks)](WebFuzzer.ipynb#Cross-Site-Scripting-Attacks)

# %% [markdown]
# ### Y
#
# * `yes()` &mdash; [Concolic Fuzzing (Representing Decisions)](ConcolicFuzzer.ipynb#Representing-Decisions)

# %% [markdown]
# ## Z - Z

# %% [markdown]
# ### Z
#
# * _Z3_ solver &mdash; [Academic Prototyping (Symbolic Reasoning in Python: There's a Package for That)](AcademicPrototyping.ipynb#Symbolic-Reasoning-in-Python:-There's-a-Package-for-That), [Prototyping with Python (Symbolic Reasoning in Python: There's a Package for That)](PrototypingWithPython.ipynb#Symbolic-Reasoning-in-Python:-There's-a-Package-for-That)
# * `z3_as_string()` &mdash; [Concolic Fuzzing (Excursion: Implementing ConcolicGrammarFuzzer)](ConcolicFuzzer.ipynb#Excursion:-Implementing-ConcolicGrammarFuzzer)
# * `Z3_BINARY` &mdash; [Concolic Fuzzing (Using the Command Line)](ConcolicFuzzer.ipynb#Using-the-Command-Line)
# * `z3_chr()` &mdash; [Concolic Fuzzing (Hack to use the ASCII value of a character.)](ConcolicFuzzer.ipynb#Hack-to-use-the-ASCII-value-of-a-character.)
# * `z3_names_and_types()` &mdash; [Symbolic Fuzzing (Get Names and Types of Variables Used)](SymbolicFuzzer.ipynb#Get-Names-and-Types-of-Variables-Used)
# * `Z3_OPTIONS` &mdash; [Concolic Fuzzing (Using the Command Line)](ConcolicFuzzer.ipynb#Using-the-Command-Line)
# * `z3_ord()` &mdash; [Concolic Fuzzing (Hack to use the ASCII value of a character.)](ConcolicFuzzer.ipynb#Hack-to-use-the-ASCII-value-of-a-character.)
# * `zbool` class &mdash; [Concolic Fuzzing (A Proxy Class for Booleans)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Booleans), [Concolic Fuzzing (Negation of Encoded formula)](ConcolicFuzzer.ipynb#Negation-of-Encoded-formula), [Concolic Fuzzing (Registering Predicates on Conditionals)](ConcolicFuzzer.ipynb#Registering-Predicates-on-Conditionals)
# * `zchr()` &mdash; [Concolic Fuzzing (Translating an Ordinal Value to ASCII)](ConcolicFuzzer.ipynb#Translating-an-Ordinal-Value-to-ASCII)
# * `ZeroDivisionRunner` class &mdash; [Reducing Failure-Inducing Inputs (Synopsis)](Reducer.ipynb#Synopsis)
# * `ZeroOrMore()` &mdash; [Railroad Diagrams (Excursion: Railroad diagrams implementation)](RailroadDiagrams.ipynb#Excursion:-Railroad-diagrams-implementation)
# * `zeval()` &mdash; [Concolic Fuzzing (Evaluating the Concolic Expressions)](ConcolicFuzzer.ipynb#Evaluating-the-Concolic-Expressions)
# * `zeval_py()` &mdash; [Concolic Fuzzing (Using the Python API)](ConcolicFuzzer.ipynb#Using-the-Python-API)
# * `zeval_smt()` &mdash; [Concolic Fuzzing (Using the Command Line)](ConcolicFuzzer.ipynb#Using-the-Command-Line)
# * `zfloat` class &mdash; [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
# * `zint` class &mdash; [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (Equality between Integers)](ConcolicFuzzer.ipynb#Equality-between-Integers), [Concolic Fuzzing (Equality between Integers)](ConcolicFuzzer.ipynb#Equality-between-Integers), [Concolic Fuzzing (Comparisons between Integers)](ConcolicFuzzer.ipynb#Comparisons-between-Integers), [Concolic Fuzzing (Comparisons between Integers)](ConcolicFuzzer.ipynb#Comparisons-between-Integers), [Concolic Fuzzing (Using an Integer in a Boolean Context)](ConcolicFuzzer.ipynb#Using-an-Integer-in-a-Boolean-Context), [Concolic Fuzzing (Exercise 2: Bit Manipulation)](ConcolicFuzzer.ipynb#Exercise-2:-Bit-Manipulation)
# * `zord()` &mdash; [Concolic Fuzzing (Retrieving Ordinal Value)](ConcolicFuzzer.ipynb#Retrieving-Ordinal-Value)
# * `zproxy_create()` &mdash; [Concolic Fuzzing (Concolic Proxy Objects)](ConcolicFuzzer.ipynb#Concolic-Proxy-Objects)
# * `zstr_iterator` class &mdash; [Concolic Fuzzing (An Iterator Class for Strings)](ConcolicFuzzer.ipynb#An-Iterator-Class-for-Strings)
# * `zstr` class &mdash; [Concolic Fuzzing (A Proxy Class for Strings)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Strings), [Concolic Fuzzing (A Proxy Class for Strings)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Strings), [Concolic Fuzzing (A Proxy Class for Strings)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Strings), [Concolic Fuzzing (Equality between Strings)](ConcolicFuzzer.ipynb#Equality-between-Strings), [Concolic Fuzzing (Length of Strings)](ConcolicFuzzer.ipynb#Length-of-Strings), [Concolic Fuzzing (Length of Strings)](ConcolicFuzzer.ipynb#Length-of-Strings), [Concolic Fuzzing (Concatenation of Strings)](ConcolicFuzzer.ipynb#Concatenation-of-Strings), [Concolic Fuzzing (Producing Substrings)](ConcolicFuzzer.ipynb#Producing-Substrings), [Concolic Fuzzing (Translating to Upper and Lower Equivalents)](ConcolicFuzzer.ipynb#Translating-to-Upper-and-Lower-Equivalents), [Concolic Fuzzing (Translating to Upper and Lower Equivalents)](ConcolicFuzzer.ipynb#Translating-to-Upper-and-Lower-Equivalents), [Concolic Fuzzing (Checking for String Prefixes)](ConcolicFuzzer.ipynb#Checking-for-String-Prefixes), [Concolic Fuzzing (Finding Substrings)](ConcolicFuzzer.ipynb#Finding-Substrings), [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends), [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends), [Concolic Fuzzing (Remove Space from Ends)](ConcolicFuzzer.ipynb#Remove-Space-from-Ends), [Concolic Fuzzing (Splitting Strings)](ConcolicFuzzer.ipynb#Splitting-Strings)
# * `_zv()` &mdash; [Concolic Fuzzing (A Proxy Class for Integers)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Integers), [Concolic Fuzzing (A Proxy Class for Strings)](ConcolicFuzzer.ipynb#A-Proxy-Class-for-Strings), [Concolic Fuzzing (Exercise 1: Implment a Concolic Float Proxy Class)](ConcolicFuzzer.ipynb#Exercise-1:-Implment-a-Concolic-Float-Proxy-Class)
