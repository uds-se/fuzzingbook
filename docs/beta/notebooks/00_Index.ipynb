# %% [markdown]
# # Index

# %% [markdown]
# ## A-E

# %% [markdown]
# ### A
#
# * `A1_GRAMMAR` &mdash; [Parsing and Recombining Inputs (Grammars)](Parser.ipynb#Grammars), [Parsing and Recombining Inputs (Grammars)](Parser.ipynb#Grammars), [Parsing and Recombining Inputs (Recursion)](Parser.ipynb#Recursion), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (Exercise 6: First Set of a Nonterminal)](Parser.ipynb#Exercise-6:-First-Set-of-a-Nonterminal), [Parsing and Recombining Inputs (Exercise 7: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-7:-Follow-Set-of-a-Nonterminal)
# * `A2_GRAMMAR` &mdash; [Parsing and Recombining Inputs (Grammars)](Parser.ipynb#Grammars), [Parsing and Recombining Inputs (Grammars)](Parser.ipynb#Grammars), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * `A3_GRAMMAR` &mdash; [Parsing and Recombining Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing and Recombining Inputs (Ambiguous Parsing)](Parser.ipynb#Ambiguous-Parsing)
# * Abstract Syntax Tree &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * `add()` &mdash; [Parsing and Recombining Inputs (Columns)](Parser.ipynb#Columns)
# * `add_call()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `add_coverage()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage), [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * `add_element()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `add_group()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_int_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_metavar_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_new_airport()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers), [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `add_parameter()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_result()` &mdash; [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results)
# * `add_str_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `add_tree()` &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * `add_type_rule()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `__add__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `advance()` &mdash; [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items), [Parsing and Recombining Inputs (States)](Parser.ipynb#States)
# * AFL &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `airport_codes_repOK()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `all_terminals()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * alternatives &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * American fuzzy lop &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `annotate_edge()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `annotate_node()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * any &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `any_possible_expansions()` &mdash; [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree)
# * arbitrary &mdash; [Parsing and Recombining Inputs (Testing the Parsers)](Parser.ipynb#Testing-the-Parsers)
# * `arguments()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `ARGUMENTS_SYMBOL` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * arithmetic expressions &mdash; [Fuzzing with Grammars (Arithmetic Expressions)](Grammars.ipynb#Arithmetic-Expressions)
# * `assertEquals()` &mdash; [Introduction to Software Testing (Automating Test Execution)](Intro_Testing.ipynb#Automating-Test-Execution)
# * assertion &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * assignment &mdash; [Fuzzing: Breaking Things with Random Inputs (A Testing Assignment)](Fuzzer.ipynb#A-Testing-Assignment)
# * `at_dot()` &mdash; [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items)
# * Automata theory &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `autopep8()` &mdash; [Testing Configurations (Autopep8 Setup)](ConfigurationFuzzer.ipynb#Autopep8-Setup)
# * `average_length_until_full_coverage()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)

# %% [markdown]
# ### B
#
# * Backus-Naur form &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts)
# * `BAD_ORDER_GRAMMAR` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * `BinaryProgramRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `BIRD` &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * black-box testing &mdash; [Getting Coverage (Black-Box Testing)](Coverage.ipynb#Black-Box-Testing)
# * blog post &mdash; [Mutation-Based Fuzzing (Exercise 3)](MutationFuzzer.ipynb#Exercise-3)
# * BNF &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts)
# * `BODY` &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * Branch coverage &mdash; [Getting Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * `BranchCoverage` class &mdash; [Getting Coverage (Part 1: Compute branch coverage)](Coverage.ipynb#Part-1:-Compute-branch-coverage)
# * `branch_coverage()` &mdash; [Getting Coverage (Part 1: Compute branch coverage)](Coverage.ipynb#Part-1:-Compute-branch-coverage)

# %% [markdown]
# ### C
#
# * `CachingReducer` class &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * call stack &mdash; [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input)
# * `CallCarver` class &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `called_functions()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `CallGrammarMiner` class &mdash; [Fuzzing APIs (A Grammar Miner for Calls)](APIFuzzer.ipynb#A-Grammar-Miner-for-Calls), [Fuzzing APIs (Initial Grammar)](APIFuzzer.ipynb#Initial-Grammar), [Fuzzing APIs (A Grammar from Arguments)](APIFuzzer.ipynb#A-Grammar-from-Arguments), [Fuzzing APIs (A Grammar from Calls)](APIFuzzer.ipynb#A-Grammar-from-Calls), [Fuzzing APIs (A Grammar from all Calls)](APIFuzzer.ipynb#A-Grammar-from-all-Calls)
# * `calls()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `call_string()` &mdash; [Carving Unit Tests (Serializing Objects)](Carver.ipynb#Serializing-Objects)
# * `CALL_SYMBOL` &mdash; [Fuzzing APIs (Initial Grammar)](APIFuzzer.ipynb#Initial-Grammar)
# * `call_value()` &mdash; [Carving Unit Tests (Serializing Objects)](Carver.ipynb#Serializing-Objects)
# * `candidate()` &mdash; [Parsing and Recombining Inputs (Candidate)](Parser.ipynb#Candidate), [Parsing and Recombining Inputs (Exercise 9: A Different LangFuzzer)](Parser.ipynb#Exercise-9:-A-Different-LangFuzzer)
# * `canonical()` &mdash; [Parsing and Recombining Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars)
# * `canonical_expr()` &mdash; [Parsing and Recombining Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars)
# * `capitalize()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `Carver` class &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * CFG &mdash; [Parsing and Recombining Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars), [Parsing and Recombining Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing and Recombining Inputs (Recombining Parsed Inputs)](Parser.ipynb#Recombining-Parsed-Inputs), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser), [Parsing and Recombining Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * CFGs &mdash; [Parsing and Recombining Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * CFLs &mdash; [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * `cgi_decode()` &mdash; [Getting Coverage (A CGI Decoder)](Coverage.ipynb#A-CGI-Decoder), [Getting Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions)
# * `cgi_decode_traced()` &mdash; [Getting Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions)
# * `CGI_GRAMMAR` &mdash; [Fuzzing with Grammars (A CGI Grammar)](Grammars.ipynb#A-CGI-Grammar)
# * `CHARACTERS_WITHOUT_QUOTE` &mdash; [Fuzzing with Grammars (Exercise 1: A JSON Grammar)](Grammars.ipynb#Exercise-1:-A-JSON-Grammar)
# * `chart_parse()` &mdash; [Parsing and Recombining Inputs (The Parsing Algorithm)](Parser.ipynb#The-Parsing-Algorithm)
# * `check_diversity()` &mdash; [Parsing and Recombining Inputs (Exercise 9: A Different LangFuzzer)](Parser.ipynb#Exercise-9:-A-Different-LangFuzzer)
# * `check_single_item()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * child nodes &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * children &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `CHILDREN` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees), [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * choice expressions &mdash; [Parsing and Recombining Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `choose_covered_node_expansion()` &mdash; [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Probabilistic Grammar Fuzzing (Exercise 1)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1)
# * `choose_node_expansion()` &mdash; [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage), [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Grammar Coverage (All Together)](GrammarCoverageFuzzer.ipynb#All-Together), [Probabilistic Grammar Fuzzing (Expanding by Probability)](ProbabilisticGrammarFuzzer.ipynb#Expanding-by-Probability), [Probabilistic Grammar Fuzzing (Exercise 1)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1)
# * `choose_tree_expansion()` &mdash; [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree)
# * `choose_uncovered_node_expansion()` &mdash; [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Probabilistic Grammar Fuzzing (Exercise 1)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1)
# * code coverage &mdash; [Getting Coverage](Coverage.ipynb#Getting-Coverage)
# * `code_repOK()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `collapse_if_too_large()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks)
# * `Column` class &mdash; [Parsing and Recombining Inputs (Columns)](Parser.ipynb#Columns), [Parsing and Recombining Inputs (Columns)](Parser.ipynb#Columns)
# * commas &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `comma_split()` &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `COMPARE_OPERATORS` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * compiler testing &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `complete()` &mdash; [Parsing and Recombining Inputs (Completing Processing)](Parser.ipynb#Completing-Processing), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * composed &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * concrete syntax tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `CONDITION` &mdash; [Getting Coverage (Exercise 2: Branch Coverage)](Coverage.ipynb#Exercise-2:-Branch-Coverage), [Getting Coverage (Exercise 2: Branch Coverage)](Coverage.ipynb#Exercise-2:-Branch-Coverage), [Getting Coverage (Exercise 2: Branch Coverage)](Coverage.ipynb#Exercise-2:-Branch-Coverage)
# * `__contains__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * context-free grammars &mdash; [Fuzzing with Grammars (Grammars)](Grammars.ipynb#Grammars)
# * `convert_ebnf_grammar()` &mdash; [Fuzzing with Grammars (All Together)](Grammars.ipynb#All-Together)
# * `convert_ebnf_operators()` &mdash; [Fuzzing with Grammars (Expanding Operators)](Grammars.ipynb#Expanding-Operators)
# * `convert_ebnf_parentheses()` &mdash; [Fuzzing with Grammars (Expanding Parenthesized Expressions)](Grammars.ipynb#Expanding-Parenthesized-Expressions)
# * `copy()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `count()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `counts()` &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * `count_expansions()` &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * coverage criteria &mdash; [Getting Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * `coverage()` &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Getting Coverage (Part 1: Compute branch coverage)](Coverage.ipynb#Part-1:-Compute-branch-coverage), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `Coverage` class &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * `crange()` &mdash; [Fuzzing with Grammars (Character Classes)](Grammars.ipynb#Character-Classes)
# * `crash_if_too_long()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Buffer Overflows)](Fuzzer.ipynb#Buffer-Overflows)
# * `create_candidate()` &mdash; [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations)
# * `create_foo_py()` &mdash; [Testing Configurations (Creating Autopep8 Options)](ConfigurationFuzzer.ipynb#Creating-Autopep8-Options)
# * CSmith &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * CSV &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `CSV_GRAMMAR` &mdash; [Parsing and Recombining Inputs (Fuzzing a Simple Proram)](Parser.ipynb#Fuzzing-a-Simple-Proram)
# * `C_SAMPLE_GRAMMAR` &mdash; [Parsing and Recombining Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser)

# %% [markdown]
# ### D
#
# * debugger &mdash; [Introduction to Software Testing (Debugging a Function)](Intro_Testing.ipynb#Debugging-a-Function)
# * `decrange()` &mdash; [Probabilistic Grammar Fuzzing (Probabilities in Context)](ProbabilisticGrammarFuzzer.ipynb#Probabilities-in-Context)
# * `default_edge_attr()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `default_graph_attr()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `default_node_attr()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `define_expr()` &mdash; [Fuzzing with Grammars (Part 1 (b): Alternative representations)](Grammars.ipynb#Part-1-(b):-Alternative-representations)
# * `define_ex_grammar()` &mdash; [Fuzzing with Grammars (Part 1 (b): Alternative representations)](Grammars.ipynb#Part-1-(b):-Alternative-representations)
# * `define_grammar()` &mdash; [Fuzzing with Grammars (Part 1 (a): One Single Function)](Grammars.ipynb#Part-1-(a):-One-Single-Function)
# * `define_name()` &mdash; [Fuzzing with Grammars (Part 1 (b): Alternative representations)](Grammars.ipynb#Part-1-(b):-Alternative-representations)
# * `def_used_nonterminals()` &mdash; [Fuzzing with Grammars (Checking Grammars)](Grammars.ipynb#Checking-Grammars)
# * `delete_element()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `delete_random_character()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs)
# * `DeltaDebuggingReducer` class &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * derivation tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `derivation_reductions()` &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * `deterministic_reduction()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `DIGIT_GRAMMAR` &mdash; [Fuzzing with Grammars (Representing Grammars in Python)](Grammars.ipynb#Representing-Grammars-in-Python)
# * `display_annotated_tree()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `display_tree()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * Domato &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `dot_escape()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `do_call()` &mdash; [Fuzzing APIs (Synthesizing Code)](APIFuzzer.ipynb#Synthesizing-Code)
# * `do_GET()` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * `do_HEAD()` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * Dragon Book &mdash; [Efficient Grammar Fuzzing (Background)](GrammarFuzzer.ipynb#Background)
# * `duplicate_context()` &mdash; [Grammar Coverage (Extending Grammars for Context Coverage Programmatically)](GrammarCoverageFuzzer.ipynb#Extending-Grammars-for-Context-Coverage-Programmatically)
# * `_duplicate_context()` &mdash; [Grammar Coverage (Extending Grammars for Context Coverage Programmatically)](GrammarCoverageFuzzer.ipynb#Extending-Grammars-for-Context-Coverage-Programmatically)
# * dynamic analysis &mdash; [Getting Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions)

# %% [markdown]
# ### E
#
# * `EarleyParser` class &mdash; [Parsing and Recombining Inputs (The Parsing Algorithm)](Parser.ipynb#The-Parsing-Algorithm), [Parsing and Recombining Inputs (The Parsing Algorithm)](Parser.ipynb#The-Parsing-Algorithm), [Parsing and Recombining Inputs (Predicting States)](Parser.ipynb#Predicting-States), [Parsing and Recombining Inputs (Scanning Tokens)](Parser.ipynb#Scanning-Tokens), [Parsing and Recombining Inputs (Completing Processing)](Parser.ipynb#Completing-Processing), [Parsing and Recombining Inputs (Filling the Chart)](Parser.ipynb#Filling-the-Chart), [Parsing and Recombining Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing and Recombining Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing and Recombining Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing and Recombining Inputs (Parsing Forests)](Parser.ipynb#Parsing-Forests), [Parsing and Recombining Inputs (Parsing Paths)](Parser.ipynb#Parsing-Paths), [Parsing and Recombining Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing and Recombining Inputs (Ambiguous Parsing)](Parser.ipynb#Ambiguous-Parsing), [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable)
# * `earley_complete()` &mdash; [Parsing and Recombining Inputs (Completing Processing)](Parser.ipynb#Completing-Processing)
# * EBNF &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts)
# * `ebnf_grammar()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * EMI Project &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `endswith()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `__enter__()` &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `EOF` &mdash; [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks), [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks), [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks), [Parsing and Recombining Inputs (Exercise 7: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-7:-Follow-Set-of-a-Nonterminal), [Parsing and Recombining Inputs (Exercise 7: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-7:-Follow-Set-of-a-Nonterminal), [Parsing and Recombining Inputs (Exercise 7: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-7:-Follow-Set-of-a-Nonterminal)
# * epsilon expansion &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node)
# * `EPSILON` &mdash; [Introduction to Software Testing (Automating Test Execution)](Intro_Testing.ipynb#Automating-Test-Execution), [Parsing and Recombining Inputs (The Aycock Epsilon Fix)](Parser.ipynb#The-Aycock-Epsilon-Fix), [Parsing and Recombining Inputs (Exercise 6: First Set of a Nonterminal)](Parser.ipynb#Exercise-6:-First-Set-of-a-Nonterminal)
# * `__eq__()` &mdash; [Parsing and Recombining Inputs (States)](Parser.ipynb#States), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `EQ` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `EvenFasterGrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * `executable()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `ExerciseGrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Exercise 4: Alternate Random Expansions)](GrammarFuzzer.ipynb#Exercise-4:-Alternate-Random-Expansions)
# * `__exit__()` &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `expandtabs()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `expand_node()` &mdash; [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion), [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation)
# * `expand_node_by_cost()` &mdash; [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion)
# * `expand_node_max_cost()` &mdash; [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation)
# * `expand_node_min_cost()` &mdash; [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion)
# * `expand_node_randomly()` &mdash; [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Exercise 4: Alternate Random Expansions)](GrammarFuzzer.ipynb#Exercise-4:-Alternate-Random-Expansions), [Parsing and Recombining Inputs (We need some infrastructure first for viewing the grammar.)](Parser.ipynb#We-need-some-infrastructure-first-for-viewing-the-grammar.)
# * `expand_tree()` &mdash; [Efficient Grammar Fuzzing (Three Expansion Phases)](GrammarFuzzer.ipynb#Three-Expansion-Phases)
# * `expand_tree_once()` &mdash; [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree)
# * `expand_tree_with_strategy()` &mdash; [Efficient Grammar Fuzzing (Three Expansion Phases)](GrammarFuzzer.ipynb#Three-Expansion-Phases)
# * expansion alternatives &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * expansion rules &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * `ExpansionCountMiner` class &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples), [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * `ExpansionError` class &mdash; [Fuzzing with Grammars (A Simple Grammar Fuzzer)](Grammars.ipynb#A-Simple-Grammar-Fuzzer)
# * `expansion_cost()` &mdash; [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion)
# * `expansion_coverage()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)
# * `expansion_key()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)
# * `expansion_to_children()` &mdash; [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Exercise 1: Caching Method Results)](GrammarFuzzer.ipynb#Exercise-1:-Caching-Method-Results)
# * `expression_grammar_fn()` &mdash; [Fuzzing with Grammars (Exercise 4: Defining Grammars as Functions (Advanced))](Grammars.ipynb#Exercise-4:-Defining-Grammars-as-Functions-(Advanced))
# * `EXPR_EBNF_GRAMMAR` &mdash; [Fuzzing with Grammars (Grammar Shortcuts)](Grammars.ipynb#Grammar-Shortcuts)
# * `EXPR_GRAMMAR_BNF` &mdash; [Efficient Grammar Fuzzing (An Insufficient Algorithm)](GrammarFuzzer.ipynb#An-Insufficient-Algorithm)
# * `EXPR_GRAMMAR` &mdash; [Fuzzing with Grammars (Representing Grammars in Python)](Grammars.ipynb#Representing-Grammars-in-Python), [Grammar Coverage (Covering Grammar Elements)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Elements), [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Grammar Coverage (Extending Grammars for Context Coverage Programmatically)](GrammarCoverageFuzzer.ipynb#Extending-Grammars-for-Context-Coverage-Programmatically), [Parsing and Recombining Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars)
# * `exp_opts()` &mdash; [Probabilistic Grammar Fuzzing (Specifying Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Specifying-Probabilities)
# * `exp_prob()` &mdash; [Probabilistic Grammar Fuzzing (Specifying Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Specifying-Probabilities)
# * `exp_probabilities()` &mdash; [Probabilistic Grammar Fuzzing (Distributing Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Distributing-Probabilities)
# * `exp_string()` &mdash; [Probabilistic Grammar Fuzzing (Specifying Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Specifying-Probabilities)
# * `extended_nonterminals()` &mdash; [Fuzzing with Grammars (Expanding Operators)](Grammars.ipynb#Expanding-Operators)
# * `extract_a_tree()` &mdash; [Parsing and Recombining Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees)
# * `extract_node()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `extract_trees()` &mdash; [Parsing and Recombining Inputs (Extracting Trees)](Parser.ipynb#Extracting-Trees), [Parsing and Recombining Inputs (Ambiguous Parsing)](Parser.ipynb#Ambiguous-Parsing)
# * `E_GRAMMAR_1` &mdash; [Parsing and Recombining Inputs (The Aycock Epsilon Fix)](Parser.ipynb#The-Aycock-Epsilon-Fix), [Parsing and Recombining Inputs (The Aycock Epsilon Fix)](Parser.ipynb#The-Aycock-Epsilon-Fix)
# * `E_GRAMMAR` &mdash; [Parsing and Recombining Inputs (The Aycock Epsilon Fix)](Parser.ipynb#The-Aycock-Epsilon-Fix)

# %% [markdown]
# ## F-J

# %% [markdown]
# ### F
#
# * `FAIL` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `FasterGrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Exercise 1: Caching Method Results)](GrammarFuzzer.ipynb#Exercise-1:-Caching-Method-Results)
# * `FILE` &mdash; [Fuzzing: Breaking Things with Random Inputs (Creating Input Files)](Fuzzer.ipynb#Creating-Input-Files)
# * `fill_chart()` &mdash; [Parsing and Recombining Inputs (Filling the Chart)](Parser.ipynb#Filling-the-Chart)
# * `filter_states()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `find()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `find_comma()` &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `find_contents()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `find_executable()` &mdash; [Testing Configurations (Autopep8 Setup)](ConfigurationFuzzer.ipynb#Autopep8-Setup)
# * `find_grammar()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `FIND_STR` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `finished()` &mdash; [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items)
# * finite state machines &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `firstset()` &mdash; [Parsing and Recombining Inputs (Exercise 6: First Set of a Nonterminal)](Parser.ipynb#Exercise-6:-First-Set-of-a-Nonterminal)
# * `firstset_()` &mdash; [Parsing and Recombining Inputs (Exercise 6: First Set of a Nonterminal)](Parser.ipynb#Exercise-6:-First-Set-of-a-Nonterminal)
# * `first_digit_via_log()` &mdash; [Probabilistic Grammar Fuzzing (The Law of Leading Digits)](ProbabilisticGrammarFuzzer.ipynb#The-Law-of-Leading-Digits)
# * `first_digit_via_string()` &mdash; [Probabilistic Grammar Fuzzing (The Law of Leading Digits)](ProbabilisticGrammarFuzzer.ipynb#The-Law-of-Leading-Digits)
# * `first_expr()` &mdash; [Parsing and Recombining Inputs (Exercise 6: First Set of a Nonterminal)](Parser.ipynb#Exercise-6:-First-Set-of-a-Nonterminal)
# * `first` and `follow` &mdash; [Parsing and Recombining Inputs (Exercise 6: First Set of a Nonterminal)](Parser.ipynb#Exercise-6:-First-Set-of-a-Nonterminal)
# * `fixed_cgi_decode()` &mdash; [Getting Coverage (Exercise 1: Fixing cgi_decode)](Coverage.ipynb#Exercise-1:-Fixing-cgi_decode)
# * `fixpoint()` &mdash; [Parsing and Recombining Inputs (Fixpoint)](Parser.ipynb#Fixpoint)
# * `flip_random_character()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs)
# * `followset()` &mdash; [Parsing and Recombining Inputs (Exercise 7: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-7:-Follow-Set-of-a-Nonterminal)
# * `followset_()` &mdash; [Parsing and Recombining Inputs (Exercise 7: Follow Set of a Nonterminal)](Parser.ipynb#Exercise-7:-Follow-Set-of-a-Nonterminal)
# * formal languages &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages), [Fuzzing with Grammars (A Natural Language Grammar)](Grammars.ipynb#A-Natural-Language-Grammar)
# * `format()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `format_map()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `__format__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `fragment()` &mdash; [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer)
# * `FunctionCoverageRunner` class &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `FunctionRunner` class &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `function_symbol()` &mdash; [Fuzzing APIs (A Grammar from Calls)](APIFuzzer.ipynb#A-Grammar-from-Calls)
# * `FUNCTION` &mdash; [Mining Input Grammars (Function Under Test)](GrammarMiner.ipynb#Function-Under-Test)
# * `funct_parser()` &mdash; [Fuzzing with Grammars (Exercise 4: Defining Grammars as Functions (Advanced))](Grammars.ipynb#Exercise-4:-Defining-Grammars-as-Functions-(Advanced))
# * `fuzz()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Efficient Grammar Fuzzing (Putting it all Together)](GrammarFuzzer.ipynb#Putting-it-all-Together), [Parsing and Recombining Inputs (Fuzz)](Parser.ipynb#Fuzz), [Parsing and Recombining Inputs (Exercise 9: A Different LangFuzzer)](Parser.ipynb#Exercise-9:-A-Different-LangFuzzer)
# * fuzzer &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * `fuzzer()` &mdash; [Fuzzing: Breaking Things with Random Inputs (A Simple Fuzzer)](Fuzzer.ipynb#A-Simple-Fuzzer)
# * `Fuzzer` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * fuzzing &mdash; [Fuzzing: Breaking Things with Random Inputs](Fuzzer.ipynb#Fuzzing:-Breaking-Things-with Random Inputs), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG)
# * fuzzingboook.org &mdash; [Carving Unit Tests (System Tests vs Unit Tests)](Carver.ipynb#System-Tests-vs-Unit-Tests)
# * `fuzz_tree()` &mdash; [Efficient Grammar Fuzzing (Putting it all Together)](GrammarFuzzer.ipynb#Putting-it-all-Together)

# %% [markdown]
# ### G
#
# * `generate_new_tree()` &mdash; [Parsing and Recombining Inputs (Generate New Tree)](Parser.ipynb#Generate-New-Tree), [Parsing and Recombining Inputs (Exercise 9: A Different LangFuzzer)](Parser.ipynb#Exercise-9:-A-Different-LangFuzzer)
# * `get()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `__getitem__()` &mdash; [Testing Configurations (Part 3: Mine a Configuration Grammar)](ConfigurationFuzzer.ipynb#Part-3:-Mine-a-Configuration-Grammar), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `get_above()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `get_alternatives()` &mdash; [Fuzzing with Grammars (Exercise 4: Defining Grammars as Functions (Advanced))](Grammars.ipynb#Exercise-4:-Defining-Grammars-as-Functions-(Advanced))
# * `get_arguments()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `get_first_mapped_char()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `get_grammar()` &mdash; [Mining Input Grammars (Extracting a Grammar)](GrammarMiner.ipynb#Extracting-a-Grammar)
# * `get_mapped_char_idx()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `get_merged_grammar()` &mdash; [Mining Input Grammars (Merging Grammars)](GrammarMiner.ipynb#Merging-Grammars)
# * `get_qualified_name()` &mdash; [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls)
# * `get_t()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `GE` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * GNU bc &mdash; [Mutation-Based Fuzzing (Part 2: Guided Mutations)](MutationFuzzer.ipynb#Part-2:-Guided-Mutations)
# * grammar fuzzing &mdash; [Fuzzing with Grammars (Arithmetic Expressions)](Grammars.ipynb#Arithmetic-Expressions)
# * `grammar()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * `GrammarCoverageFuzzer` class &mdash; [Grammar Coverage (Determining Maximum per-Symbol Coverage)](GrammarCoverageFuzzer.ipynb#Determining-Maximum-per-Symbol-Coverage), [Grammar Coverage (Determining Maximum per-Symbol Coverage)](GrammarCoverageFuzzer.ipynb#Determining-Maximum-per-Symbol-Coverage), [Grammar Coverage (Determining yet Uncovered Children)](GrammarCoverageFuzzer.ipynb#Determining-yet-Uncovered-Children), [Grammar Coverage (Adaptive Lookahead)](GrammarCoverageFuzzer.ipynb#Adaptive-Lookahead), [Grammar Coverage (All Together)](GrammarCoverageFuzzer.ipynb#All-Together)
# * `GrammarFuzzer` class &mdash; [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree), [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree), [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree), [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion), [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion), [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion), [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion), [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation), [Efficient Grammar Fuzzing (Node Inflation)](GrammarFuzzer.ipynb#Node-Inflation), [Efficient Grammar Fuzzing (Three Expansion Phases)](GrammarFuzzer.ipynb#Three-Expansion-Phases), [Efficient Grammar Fuzzing (Putting it all Together)](GrammarFuzzer.ipynb#Putting-it-all-Together)
# * Grammarinator &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `GrammarReducer` class &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction), [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction), [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction), [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction), [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * grammars &mdash; [Fuzzing with Grammars (Grammars)](Grammars.ipynb#Grammars)
# * `graph_attr()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `GT` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)

# %% [markdown]
# ### H
#
# * `hang_if_no_space()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Missing Error Checks)](Fuzzer.ipynb#Missing-Error-Checks)
# * `__hash__()` &mdash; [Parsing and Recombining Inputs (States)](Parser.ipynb#States)
# * `has_taint()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * heartbeat &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * `heartbeat()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Information Leaks)](Fuzzer.ipynb#Information-Leaks)
# * HeartBleed announcement page &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * HeartBleed bug &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * `helper()` &mdash; [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer), [Parsing and Recombining Inputs (Fixpoint)](Parser.ipynb#Fixpoint)
# * `highlight_node()` &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `hl_node()` &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `httpd_url()` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * `http_program()` &mdash; [Mutation-Based Fuzzing (Fuzzing a URL Parser)](MutationFuzzer.ipynb#Fuzzing-a-URL-Parser)
# * `hundred_inputs()` &mdash; [Getting Coverage ( Coverage of Basic Fuzzing)](Coverage.ipynb#-Coverage-of-Basic-Fuzzing)

# %% [markdown]
# ### I
#
# * `identifier_grammar_fn()` &mdash; [Fuzzing with Grammars (Part 2: Extended Grammars)](Grammars.ipynb#Part-2:-Extended-Grammars)
# * in order &mdash; [Parsing and Recombining Inputs (Unify Key)](Parser.ipynb#Unify-Key)
# * `index()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * inherit &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `initial_grammar()` &mdash; [Fuzzing APIs (Initial Grammar)](APIFuzzer.ipynb#Initial-Grammar)
# * `init_tree()` &mdash; [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node)
# * `__init__()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Exercise 2: Run Simulated Troff)](Fuzzer.ipynb#Exercise-2:-Run-Simulated-Troff), [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Efficient Grammar Fuzzing (Expanding a Node)](GrammarFuzzer.ipynb#Expanding-a-Node), [Efficient Grammar Fuzzing (Exercise 1: Caching Method Results)](GrammarFuzzer.ipynb#Exercise-1:-Caching-Method-Results), [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation), [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Parsing and Recombining Inputs (We need some infrastructure first for viewing the grammar.)](Parser.ipynb#We-need-some-infrastructure-first-for-viewing-the-grammar.), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars), [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer), [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer), [Parsing and Recombining Inputs (Columns)](Parser.ipynb#Columns), [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items), [Parsing and Recombining Inputs (States)](Parser.ipynb#States), [Parsing and Recombining Inputs (The Parsing Algorithm)](Parser.ipynb#The-Parsing-Algorithm), [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 9: A Different LangFuzzer)](Parser.ipynb#Exercise-9:-A-Different-LangFuzzer), [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Fuzzing APIs (A Grammar Miner for Calls)](APIFuzzer.ipynb#A-Grammar-Miner-for-Calls), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `INPUTS` &mdash; [Mining Input Grammars (Function Under Test)](GrammarMiner.ipynb#Function-Under-Test)
# * `insert_random_character()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs)
# * `Instr` class &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `invoker()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `in_()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `IN` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `IP_ADDRESS_GRAMMAR` &mdash; [Probabilistic Grammar Fuzzing (Probabilities in Context)](ProbabilisticGrammarFuzzer.ipynb#Probabilities-in-Context)
# * `isalnum()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isalpha()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isdecimal()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isdigit()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isidentifier()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `islower()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isnumeric()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isprintable()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isspace()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `istitle()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `isupper()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `is_idx_tainted()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `is_nonterminal()` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * `IS_NOT` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `is_permutation()` &mdash; [Introduction to Software Testing (Part 2: Random Inputs)](Intro_Testing.ipynb#Part-2:-Random-Inputs)
# * `is_sorted()` &mdash; [Introduction to Software Testing (Part 2: Random Inputs)](Intro_Testing.ipynb#Part-2:-Random-Inputs)
# * `is_tpos_contained()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `is_valid_grammar()` &mdash; [Fuzzing with Grammars (Checking Grammars)](Grammars.ipynb#Checking-Grammars)
# * `is_valid_probabilistic_grammar()` &mdash; [Probabilistic Grammar Fuzzing (Checking Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Checking-Probabilities)
# * `is_valid_url()` &mdash; [Mutation-Based Fuzzing (Mutating URLs)](MutationFuzzer.ipynb#Mutating-URLs)
# * `IS` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * It is inefficient &mdash; [Efficient Grammar Fuzzing (An Insufficient Algorithm)](GrammarFuzzer.ipynb#An-Insufficient-Algorithm)
# * `Item` class &mdash; [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items), [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items)
# * `__iter__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)

# %% [markdown]
# ### J
#
# * JerryScript &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `join()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * JSON specification &mdash; [Fuzzing with Grammars (Exercise 1: A JSON Grammar)](Grammars.ipynb#Exercise-1:-A-JSON-Grammar)
# * `JSON_EBNF_GRAMMAR` &mdash; [Fuzzing with Grammars (Exercise 1: A JSON Grammar)](Grammars.ipynb#Exercise-1:-A-JSON-Grammar)
# * `JSON_GRAMMAR` &mdash; [Fuzzing with Grammars (Exercise 1: A JSON Grammar)](Grammars.ipynb#Exercise-1:-A-JSON-Grammar)

# %% [markdown]
# ## L-P

# %% [markdown]
# ### L
#
# * LangFuzz &mdash; [Fuzzing with Grammars (Background)](Grammars.ipynb#Background)
# * `LangFuzzer2` class &mdash; [Parsing and Recombining Inputs (Exercise 9: A Different LangFuzzer)](Parser.ipynb#Exercise-9:-A-Different-LangFuzzer)
# * `LangFuzzer` class &mdash; [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer), [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer), [Parsing and Recombining Inputs (Candidate)](Parser.ipynb#Candidate), [Parsing and Recombining Inputs (Generate New Tree)](Parser.ipynb#Generate-New-Tree), [Parsing and Recombining Inputs (Fuzz)](Parser.ipynb#Fuzz)
# * language specifications &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `LD_LIBRARY_PATH` &mdash; [Testing Configurations (Part 1: Getopt Fuzzing)](ConfigurationFuzzer.ipynb#Part-1:-Getopt-Fuzzing)
# * leaf &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * left to right &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `LeoParser` class &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `leo_complete()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * lexer &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * lexing &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * `LE` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `linear_to_tree()` &mdash; [Parsing and Recombining Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser)
# * `ljust()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * LL &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * `LL1Parser` class &mdash; [Parsing and Recombining Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table), [Parsing and Recombining Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table), [Parsing and Recombining Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser)
# * LLVM Address Sanitizer &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
# * `log_tree()` &mdash; [Efficient Grammar Fuzzing (Three Expansion Phases)](GrammarFuzzer.ipynb#Three-Expansion-Phases)
# * Loup Vaillant &mdash; [Parsing and Recombining Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `lower()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * LR &mdash; [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * LR parsing &mdash; [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items)
# * LR(k) &mdash; [Parsing and Recombining Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser)
# * `LR0` &mdash; [Parsing and Recombining Inputs (Items)](Parser.ipynb#Items)
# * `LR_GRAMMAR` &mdash; [Parsing and Recombining Inputs (Recursion)](Parser.ipynb#Recursion), [Parsing and Recombining Inputs (Recursion)](Parser.ipynb#Recursion), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `lr_graph()` &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `lstrip()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `LS_EBNF_GRAMMAR` &mdash; [Grammar Coverage (Exercise 1: Testing ls)](GrammarCoverageFuzzer.ipynb#Exercise-1:-Testing-ls), [Grammar Coverage (Exercise 1: Testing ls)](GrammarCoverageFuzzer.ipynb#Exercise-1:-Testing-ls)
# * `LS_GRAMMAR` &mdash; [Grammar Coverage (Exercise 1: Testing ls)](GrammarCoverageFuzzer.ipynb#Exercise-1:-Testing-ls)
# * `LT` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)

# %% [markdown]
# ### M
#
# * `make_grammar()` &mdash; [Parsing and Recombining Inputs (Testing the Parsers)](Parser.ipynb#Testing-the-Parsers)
# * `make_rule()` &mdash; [Parsing and Recombining Inputs (Testing the Parsers)](Parser.ipynb#Testing-the-Parsers)
# * `make_str_wrapper()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * Marpa parser &mdash; [Parsing and Recombining Inputs (More Earley Parsing)](Parser.ipynb#More-Earley-Parsing)
# * `_max_expansion_coverage()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)
# * `max_expansion_coverage()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)
# * `_max_symbol_expansion_coverage()` &mdash; [Grammar Coverage (Determining Maximum per-Symbol Coverage)](GrammarCoverageFuzzer.ipynb#Determining-Maximum-per-Symbol-Coverage)
# * `max_symbol_expansion_coverage()` &mdash; [Grammar Coverage (Determining Maximum per-Symbol Coverage)](GrammarCoverageFuzzer.ipynb#Determining-Maximum-per-Symbol-Coverage)
# * `merge_grammars()` &mdash; [Mining Input Grammars (Merging Grammars)](GrammarMiner.ipynb#Merging-Grammars)
# * `mine_arguments_grammar()` &mdash; [Fuzzing APIs (A Grammar from Arguments)](APIFuzzer.ipynb#A-Grammar-from-Arguments)
# * `mine_call_grammar()` &mdash; [Fuzzing APIs (A Grammar from all Calls)](APIFuzzer.ipynb#A-Grammar-from-all-Calls)
# * `mine_ebnf_grammar()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `mine_function_grammar()` &mdash; [Fuzzing APIs (A Grammar from Calls)](APIFuzzer.ipynb#A-Grammar-from-Calls)
# * `mine_grammar()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `mine_probabilistic_grammar()` &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * `missing_expansion_coverage()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)
# * `__mod__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `mutate()` &mdash; [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations)
# * mutational fuzzing &mdash; [Mutation-Based Fuzzing](MutationFuzzer.ipynb#Mutation-Based-Fuzzing), [Mutation-Based Fuzzing (Mutating Inputs)](MutationFuzzer.ipynb#Mutating-Inputs)
# * `MutationCoverageFuzzer` class &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `MutationFuzzer` class &mdash; [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations)
# * `MyHTTPRequestHandler` class &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface), [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface), [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface), [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * MyPy &mdash; [Fuzzing: Breaking Things with Random Inputs (Static Code Checkers)](Fuzzer.ipynb#Static-Code-Checkers)
# * `MysteryRunner` class &mdash; [Reducing Failure-Inducing Inputs (Why Reducing?)](Reducer.ipynb#Why-Reducing?)
# * `my_sqrt()` &mdash; [Introduction to Software Testing (Simple Testing)](Intro_Testing.ipynb#Simple-Testing), [Parsing and Recombining Inputs (Fixpoint)](Parser.ipynb#Fixpoint)
# * `_my_sqrt()` &mdash; [Parsing and Recombining Inputs (Fixpoint)](Parser.ipynb#Fixpoint)
# * `my_sqrt_checked()` &mdash; [Introduction to Software Testing (Run-Time Verification)](Intro_Testing.ipynb#Run-Time-Verification)
# * `my_sqrt_fixed()` &mdash; [Introduction to Software Testing (The Limits of Testing)](Intro_Testing.ipynb#The-Limits-of-Testing)
# * `my_sqrt_with_log()` &mdash; [Introduction to Software Testing (Debugging a Function)](Intro_Testing.ipynb#Debugging-a-Function)

# %% [markdown]
# ### N
#
# * natural language &mdash; [Fuzzing with Grammars (A Natural Language Grammar)](Grammars.ipynb#A-Natural-Language-Grammar)
# * Newton–Raphson method &mdash; [Introduction to Software Testing (Simple Testing)](Intro_Testing.ipynb#Simple-Testing)
# * `_new_child_coverage()` &mdash; [Grammar Coverage (Determining yet Uncovered Children)](GrammarCoverageFuzzer.ipynb#Determining-yet-Uncovered-Children)
# * `new_child_coverage()` &mdash; [Grammar Coverage (Determining yet Uncovered Children)](GrammarCoverageFuzzer.ipynb#Determining-yet-Uncovered-Children)
# * `new_coverages()` &mdash; [Grammar Coverage (Adaptive Lookahead)](GrammarCoverageFuzzer.ipynb#Adaptive-Lookahead)
# * `new_expansion_cost()` &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * `new_symbol()` &mdash; [Fuzzing with Grammars (Creating New Symbols)](Grammars.ipynb#Creating-New-Symbols)
# * `new_symbol_cost()` &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * `__new__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `__next__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `__ne__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `NE` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * nodes &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * nonterminal symbol &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `nonterminal()` &mdash; [Mining Input Grammars (Extracting a Grammar)](GrammarMiner.ipynb#Extracting-a-Grammar)
# * `nonterminals()` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * not &mdash; [Parsing and Recombining Inputs (Exercise 3: PEG Predicates)](Parser.ipynb#Exercise-3:-PEG-Predicates)
# * `not_found()` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * `NOT_IN` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `no_8bit()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 1: Simulate Troff)](Fuzzer.ipynb#Exercise-1:-Simulate-Troff)
# * `no_backslash_d()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 1: Simulate Troff)](Fuzzer.ipynb#Exercise-1:-Simulate-Troff)
# * `no_dot()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 1: Simulate Troff)](Fuzzer.ipynb#Exercise-1:-Simulate-Troff)
# * `nullable()` &mdash; [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable)
# * `nullable_()` &mdash; [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable)
# * `nullable_expr()` &mdash; [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable)
# * `number_of_nodes()` &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)

# %% [markdown]
# ### O
#
# * `o()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `OBJECT` &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * `opS()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `OptionFuzzer` class &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `OptionGrammarMiner` class &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `OptionRunner` class &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `OPTION_SYMBOL` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `opts()` &mdash; [Probabilistic Grammar Fuzzing (Specifying Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Specifying-Probabilities)
# * `op_A()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `op_B()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `Op` class &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * oracle &mdash; [Getting Coverage (Finding Errors with Basic Fuzzing)](Coverage.ipynb#Finding-Errors-with-Basic-Fuzzing)
# * ordered choice &mdash; [Parsing and Recombining Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `ORDER_GRAMMAR` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)

# %% [markdown]
# ### P
#
# * packrat &mdash; [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG)
# * `PackratParser` class &mdash; [Parsing and Recombining Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * `pairwise()` &mdash; [Testing Configurations (Combinatorial Testing)](ConfigurationFuzzer.ipynb#Combinatorial-Testing)
# * `parenthesized_expressions()` &mdash; [Fuzzing with Grammars (Expanding Parenthesized Expressions)](Grammars.ipynb#Expanding-Parenthesized-Expressions)
# * parse tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `parse()` &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing and Recombining Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser), [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * `ParseInterrupt` class &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * Parser &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * parsers &mdash; [Efficient Grammar Fuzzing (Background)](GrammarFuzzer.ipynb#Background)
# * `Parser` class &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars)
# * `parse_csv()` &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser), [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `parse_forest()` &mdash; [Parsing and Recombining Inputs (Parsing Forests)](Parser.ipynb#Parsing-Forests)
# * `parse_helper()` &mdash; [Parsing and Recombining Inputs (Part 2: The Parser)](Parser.ipynb#Part-2:-The-Parser)
# * `parse_paths()` &mdash; [Parsing and Recombining Inputs (Parsing Paths)](Parser.ipynb#Parsing-Paths), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `parse_prefix()` &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity), [Parsing and Recombining Inputs (The Parser)](Parser.ipynb#The-Parser), [Parsing and Recombining Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method), [Parsing and Recombining Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * `parse_quote()` &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `parse_table()` &mdash; [Parsing and Recombining Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table), [Parsing and Recombining Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * parsing &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * Parsing Expression Grammar &mdash; [Parsing and Recombining Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `partition()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `PASS` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * path to insanity &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * PEG &mdash; [Parsing and Recombining Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars), [Parsing and Recombining Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * `PEG1` &mdash; [Parsing and Recombining Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `PEG2` &mdash; [Parsing and Recombining Inputs (Parsing Expression Grammars)](Parser.ipynb#Parsing-Expression-Grammars)
# * `PEGParser` class &mdash; [Parsing and Recombining Inputs (The Parser)](Parser.ipynb#The-Parser), [Parsing and Recombining Inputs (Unify Key)](Parser.ipynb#Unify-Key), [Parsing and Recombining Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing and Recombining Inputs (Unify Rule)](Parser.ipynb#Unify-Rule)
# * PEGs &mdash; [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background), [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * `PEG_SURPRISE` &mdash; [Parsing and Recombining Inputs ( Problems with PEG)](Parser.ipynb#-Problems-with-PEG)
# * PEP 8 Style Guide for Python Code &mdash; [Testing Configurations (Testing Autopep8)](ConfigurationFuzzer.ipynb#Testing-Autopep8)
# * `PooledGrammarFuzzer` class &mdash; [Parsing and Recombining Inputs (We need some infrastructure first for viewing the grammar.)](Parser.ipynb#We-need-some-infrastructure-first-for-viewing-the-grammar.)
# * `population_branch_coverage()` &mdash; [Getting Coverage (Part 2: Comparing statement coverage and branch coverage)](Coverage.ipynb#Part-2:-Comparing-statement-coverage-and-branch-coverage)
# * `population_coverage()` &mdash; [Getting Coverage ( Coverage of Basic Fuzzing)](Coverage.ipynb#-Coverage-of-Basic-Fuzzing)
# * `possible_combinations()` &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * `possible_expansions()` &mdash; [Efficient Grammar Fuzzing (Expanding a Tree)](GrammarFuzzer.ipynb#Expanding-a-Tree)
# * post-order &mdash; [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * `power()` &mdash; [Fuzzing APIs (From Calls to Grammars)](APIFuzzer.ipynb#From-Calls-to-Grammars)
# * `POWER_GRAMMAR` &mdash; [Fuzzing APIs (From Calls to Grammars)](APIFuzzer.ipynb#From-Calls-to-Grammars), [Fuzzing APIs (From Calls to Grammars)](APIFuzzer.ipynb#From-Calls-to-Grammars)
# * pre-order &mdash; [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * `precompute_costs()` &mdash; [Efficient Grammar Fuzzing (Exercise 2: Grammar Pre-Compilation)](GrammarFuzzer.ipynb#Exercise-2:-Grammar-Pre-Compilation)
# * `predict()` &mdash; [Parsing and Recombining Inputs (Predicting States)](Parser.ipynb#Predicting-States), [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable), [Parsing and Recombining Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * `PrintRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `ProbabilisticGrammarCoverageFuzzer` class &mdash; [Probabilistic Grammar Fuzzing (Exercise 1)](ProbabilisticGrammarFuzzer.ipynb#Exercise-1)
# * `ProbabilisticGrammarFuzzer` class &mdash; [Probabilistic Grammar Fuzzing (Expanding by Probability)](ProbabilisticGrammarFuzzer.ipynb#Expanding-by-Probability)
# * `ProbabilisticGrammarMiner` class &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * `PROBABILISTIC_EXPR_GRAMMAR` &mdash; [Probabilistic Grammar Fuzzing (Specifying Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Specifying-Probabilities)
# * `prob_distribution()` &mdash; [Probabilistic Grammar Fuzzing (Distributing Probabilities)](ProbabilisticGrammarFuzzer.ipynb#Distributing-Probabilities)
# * `prob_leading_digit()` &mdash; [Probabilistic Grammar Fuzzing (The Law of Leading Digits)](ProbabilisticGrammarFuzzer.ipynb#The-Law-of-Leading-Digits)
# * `process_arg()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `process_argument()` &mdash; [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments)
# * `process_numbers()` &mdash; [Testing Configurations (Options in Python)](ConfigurationFuzzer.ipynb#Options-in-Python)
# * `PROCESS_NUMBERS_EBNF_GRAMMAR` &mdash; [Testing Configurations (A Grammar for Configurations)](ConfigurationFuzzer.ipynb#A-Grammar-for-Configurations), [Testing Configurations (A Grammar for Configurations)](ConfigurationFuzzer.ipynb#A-Grammar-for-Configurations)
# * `PROCESS_NUMBERS_GRAMMAR` &mdash; [Testing Configurations (A Grammar for Configurations)](ConfigurationFuzzer.ipynb#A-Grammar-for-Configurations)
# * `process_vehicle()` &mdash; [Parsing and Recombining Inputs (Fuzzing a Simple Proram)](Parser.ipynb#Fuzzing-a-Simple-Proram)
# * `prod_line_grammar()` &mdash; [Parsing and Recombining Inputs (Testing the Parsers)](Parser.ipynb#Testing-the-Parsers)
# * `ProgramRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `proxy()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `prune_tree()` &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * Python tutorial &mdash; [Introduction to Software Testing (Understanding Python Programs)](Intro_Testing.ipynb#Understanding-Python-Programs), [Fuzzing: Breaking Things with Random Inputs](Fuzzer.ipynb#Fuzzing:-Breaking-Things-with Random Inputs)

# %% [markdown]
# ## Q-U

# %% [markdown]
# ### Q
#
# * `quadratic_solver()` &mdash; [Introduction to Software Testing (Exercise 2: Quadratic Solver)](Intro_Testing.ipynb#Exercise-2:-Quadratic-Solver)
# * `quadratic_solver_fixed()` &mdash; [Introduction to Software Testing (Part 2: Fix the problem)](Intro_Testing.ipynb#Part-2:-Fix-the-problem)
# * `queue_to_string()` &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)

# %% [markdown]
# ### R
#
# * `__radd__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `RandomFuzzer` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * `random_list()` &mdash; [Introduction to Software Testing (Part 2: Random Inputs)](Intro_Testing.ipynb#Part-2:-Random-Inputs)
# * `read_gcov_coverage()` &mdash; [Getting Coverage (Getting Coverage from External Programs)](Coverage.ipynb#Getting-Coverage-from-External-Programs)
# * recursive &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * red &mdash; [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer), [Parsing and Recombining Inputs (Candidate)](Parser.ipynb#Candidate)
# * red-black tree &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `RedBlackTree` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `reduce()` &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * `Reducer` class &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * `reduce_tree()` &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * `reductions()` &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * Regular Expression &mdash; [Parsing and Recombining Inputs (Background)](Parser.ipynb#Background)
# * Regular expressions &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * regular expressions &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * regular language &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * `replace()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `repOK()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * representation invariant &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `__repr__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `reset()` &mdash; [Mutation-Based Fuzzing (Multiple Mutations)](MutationFuzzer.ipynb#Multiple-Mutations), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results)
# * `reset_coverage()` &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)
# * `result()` &mdash; [Carving Unit Tests (Part 2: Access results)](Carver.ipynb#Part-2:-Access-results)
# * `ResultCarver` class &mdash; [Carving Unit Tests (Exercises)](Carver.ipynb#Exercises), [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results), [Carving Unit Tests (Part 2: Access results)](Carver.ipynb#Part-2:-Access-results)
# * results checker &mdash; [Getting Coverage (Finding Errors with Basic Fuzzing)](Coverage.ipynb#Finding-Errors-with-Basic-Fuzzing)
# * `reverse()` &mdash; [Parsing and Recombining Inputs (The Parse Method)](Parser.ipynb#The-Parse-Method)
# * `RE_EXTENDED_NONTERMINAL` &mdash; [Fuzzing with Grammars (Expanding Operators)](Grammars.ipynb#Expanding-Operators)
# * `RE_NONTERMINAL` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * `RE_PARENTHESIZED_EXPR` &mdash; [Fuzzing with Grammars (Expanding Parenthesized Expressions)](Grammars.ipynb#Expanding-Parenthesized-Expressions)
# * `rfind()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `rindex()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `rjust()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `__rmod__()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * root node &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `rootIsBlack()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Program-Specific Checkers)](Fuzzer.ipynb#Program-Specific-Checkers)
# * `rpartition()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `RR_GRAMMAR2` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR3` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `RR_GRAMMAR` &mdash; [Parsing and Recombining Inputs (Recursion)](Parser.ipynb#Recursion), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `rsplit()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `rstrip()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * rules &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions)
# * `rules()` &mdash; [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable), [Parsing and Recombining Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * `run()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes), [Fuzzing: Breaking Things with Random Inputs (Exercise 2: Run Simulated Troff)](Fuzzer.ipynb#Exercise-2:-Run-Simulated-Troff), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options), [Reducing Failure-Inducing Inputs (Why Reducing?)](Reducer.ipynb#Why-Reducing?)
# * `Runner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `runs()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Fuzzer Classes)](Fuzzer.ipynb#Fuzzer-Classes)
# * `run_function()` &mdash; [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage), [Mutation-Based Fuzzing (Guiding by Coverage)](MutationFuzzer.ipynb#Guiding-by-Coverage)
# * `run_httpd()` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * `run_process()` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes), [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)

# %% [markdown]
# ### S
#
# * `SAMPLE_GRAMMAR` &mdash; [Parsing and Recombining Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser)
# * `scan()` &mdash; [Parsing and Recombining Inputs (Scanning Tokens)](Parser.ipynb#Scanning-Tokens)
# * scanner &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * seeds &mdash; [Fuzzing with Grammars (Grammars as Mutation Seeds)](Grammars.ipynb#Grammars-as-Mutation-Seeds)
# * `send_order_form()` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * `send_order_received()` &mdash; [Web GUI Fuzzing (A Web User Interface)](WebFuzzer.ipynb#A-Web-User-Interface)
# * `set_arguments()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `set_expansion_probabilities()` &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * `set_invocation()` &mdash; [Testing Configurations (Classes for Fuzzing Configuration Options)](ConfigurationFuzzer.ipynb#Classes-for-Fuzzing-Configuration-Options)
# * `set_opts()` &mdash; [Probabilistic Grammar Fuzzing (Directed Fuzzing)](ProbabilisticGrammarFuzzer.ipynb#Directed-Fuzzing)
# * `set_prob()` &mdash; [Probabilistic Grammar Fuzzing (Directed Fuzzing)](ProbabilisticGrammarFuzzer.ipynb#Directed-Fuzzing)
# * `set_probabilities()` &mdash; [Probabilistic Grammar Fuzzing (Learning Probabilities from Samples)](ProbabilisticGrammarFuzzer.ipynb#Learning-Probabilities-from-Samples)
# * Shellsort &mdash; [Introduction to Software Testing (Exercise 1: Testing Shellsort)](Intro_Testing.ipynb#Exercise-1:-Testing-Shellsort)
# * `shellsort()` &mdash; [Introduction to Software Testing (Exercise 1: Testing Shellsort)](Intro_Testing.ipynb#Exercise-1:-Testing-Shellsort)
# * `show_table()` &mdash; [Parsing and Recombining Inputs (Part 1: A LL(1) Parsing Table)](Parser.ipynb#Part-1:-A-LL(1)-Parsing-Table)
# * `SimpleGrammarCoverageFuzzer` class &mdash; [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions), [Grammar Coverage (Covering Grammar Expansions)](GrammarCoverageFuzzer.ipynb#Covering-Grammar-Expansions)
# * `simple_call_string()` &mdash; [Carving Unit Tests (Recording my_sqrt())](Carver.ipynb#Recording-my_sqrt())
# * `simple_grammar_fuzzer()` &mdash; [Fuzzing with Grammars (A Simple Grammar Fuzzer)](Grammars.ipynb#A-Simple-Grammar-Fuzzer)
# * single-alternative &mdash; [Parsing and Recombining Inputs (The Earley Parser)](Parser.ipynb#The-Earley-Parser)
# * `split()` &mdash; [Parsing and Recombining Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `splitlst()` &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `_split_space()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `sqrt_program()` &mdash; [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input), [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input), [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input)
# * `srange()` &mdash; [Fuzzing with Grammars (Character Classes)](Grammars.ipynb#Character-Classes)
# * start symbol &mdash; [Fuzzing with Grammars (Rules and Expansions)](Grammars.ipynb#Rules-and-Expansions), [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `startswith()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `START_SYMBOL` &mdash; [Fuzzing with Grammars (Some Definitions)](Grammars.ipynb#Some-Definitions)
# * Statement coverage &mdash; [Getting Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * `State` class &mdash; [Parsing and Recombining Inputs (States)](Parser.ipynb#States), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `strip()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `__str__()` &mdash; [Parsing and Recombining Inputs (Columns)](Parser.ipynb#Columns), [Parsing and Recombining Inputs (States)](Parser.ipynb#States), [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker), [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * subclasses &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `substrings()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `subtrees_with_symbol()` &mdash; [Reducing Failure-Inducing Inputs (Grammar-Based Input Reduction)](Reducer.ipynb#Grammar-Based-Input-Reduction)
# * `swapcase()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `symbol_cost()` &mdash; [Efficient Grammar Fuzzing (Closing the Expansion)](GrammarFuzzer.ipynb#Closing-the-Expansion)
# * `SYMBOL_NAME` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * syntactical structure &mdash; [Fuzzing with Grammars (Grammars)](Grammars.ipynb#Grammars)
# * `syntax_diagram()` &mdash; [Fuzzing with Grammars (Visualizing Grammars as Railroad Diagrams)](Grammars.ipynb#Visualizing-Grammars-as-Railroad-Diagrams)
# * `syntax_diagram_alt()` &mdash; [Fuzzing with Grammars (Visualizing Grammars as Railroad Diagrams)](Grammars.ipynb#Visualizing-Grammars-as-Railroad-Diagrams)
# * `syntax_diagram_expr()` &mdash; [Fuzzing with Grammars (Visualizing Grammars as Railroad Diagrams)](Grammars.ipynb#Visualizing-Grammars-as-Railroad-Diagrams)
# * `syntax_diagram_symbol()` &mdash; [Fuzzing with Grammars (Visualizing Grammars as Railroad Diagrams)](Grammars.ipynb#Visualizing-Grammars-as-Railroad-Diagrams)
# * system input &mdash; [Introduction to Software Testing (System Input vs Function Input)](Intro_Testing.ipynb#System-Input-vs-Function-Input)

# %% [markdown]
# ### T
#
# * `_t()` &mdash; [Parsing and Recombining Inputs (States)](Parser.ipynb#States)
# * `Tagged` class &mdash; [Parsing and Recombining Inputs (Exercise 5: Leo Parser)](Parser.ipynb#Exercise-5:-Leo-Parser)
# * `TaintException` class &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * terminal symbol &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `terminals()` &mdash; [Parsing and Recombining Inputs (Nullable)](Parser.ipynb#Nullable)
# * test &mdash; [Introduction to Software Testing (Running a Function)](Intro_Testing.ipynb#Running-a-Function)
# * `test()` &mdash; [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging), [Reducing Failure-Inducing Inputs (Delta Debugging)](Reducer.ipynb#Delta-Debugging)
# * the ConfigParser documentation &mdash; [Testing Configurations (Exercise 1: Configuration Files)](ConfigurationFuzzer.ipynb#Exercise-1:-Configuration-Files)
# * this article &mdash; [Probabilistic Grammar Fuzzing (Background)](ProbabilisticGrammarFuzzer.ipynb#Background)
# * `title()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `TITLE_GRAMMAR` &mdash; [Fuzzing with Grammars (A Natural Language Grammar)](Grammars.ipynb#A-Natural-Language-Grammar)
# * `tokenize()` &mdash; [Parsing and Recombining Inputs (The Packrat Parser for Predicate Expression Grammars)](Parser.ipynb#The-Packrat-Parser-for-Predicate-Expression-Grammars)
# * tokenizer &mdash; [Parsing and Recombining Inputs (Ambiguity)](Parser.ipynb#Ambiguity)
# * top to bottom &mdash; [Parsing and Recombining Inputs (An Ad Hoc Parser)](Parser.ipynb#An-Ad-Hoc-Parser)
# * `trace()` &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * `traceit()` &mdash; [Getting Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions), [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class), [Testing Configurations (Tracking Arguments)](ConfigurationFuzzer.ipynb#Tracking-Arguments), [Testing Configurations (Tracking Arguments)](ConfigurationFuzzer.ipynb#Tracking-Arguments), [Testing Configurations (A Grammar Miner for Options and Arguments)](ConfigurationFuzzer.ipynb#A-Grammar-Miner-for-Options-and-Arguments), [Carving Unit Tests (Recording Calls)](Carver.ipynb#Recording-Calls), [Carving Unit Tests (Exercises)](Carver.ipynb#Exercises), [Carving Unit Tests (Part 1: Store function results)](Carver.ipynb#Part-1:-Store-function-results), [Mining Input Grammars (Tracing Variable Values)](GrammarMiner.ipynb#Tracing-Variable-Values)
# * `trace_function()` &mdash; [Mining Input Grammars (Tracing Variable Values)](GrammarMiner.ipynb#Tracing-Variable-Values)
# * tracing function &mdash; [Getting Coverage (Tracing Executions)](Coverage.ipynb#Tracing-Executions)
# * `TrackingConfigParser` class &mdash; [Testing Configurations (Part 3: Mine a Configuration Grammar)](ConfigurationFuzzer.ipynb#Part-3:-Mine-a-Configuration-Grammar)
# * `TrackingGrammarCoverageFuzzer` class &mdash; [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage), [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage), [Grammar Coverage (Tracking Grammar Coverage)](GrammarCoverageFuzzer.ipynb#Tracking-Grammar-Coverage)
# * `traverse_tree()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees), [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer)
# * tree &mdash; [Efficient Grammar Fuzzing (Derivation Trees)](GrammarFuzzer.ipynb#Derivation-Trees)
# * `tree_to_string()` &mdash; [Efficient Grammar Fuzzing (Representing Derivation Trees)](GrammarFuzzer.ipynb#Representing-Derivation-Trees)
# * `TroffRunner` class &mdash; [Fuzzing: Breaking Things with Random Inputs (Exercise 2: Run Simulated Troff)](Fuzzer.ipynb#Exercise-2:-Run-Simulated-Troff)
# * `tstr_iterator` class &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `tstr` class &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * Turing machines &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `twice()` &mdash; [Testing Configurations (Creating Autopep8 Options)](ConfigurationFuzzer.ipynb#Creating-Autopep8-Options)

# %% [markdown]
# ### U
#
# * `unify_key()` &mdash; [Parsing and Recombining Inputs (Unify Key)](Parser.ipynb#Unify-Key), [Parsing and Recombining Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing and Recombining Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * `unify_rule()` &mdash; [Parsing and Recombining Inputs (Unify Rule)](Parser.ipynb#Unify-Rule), [Parsing and Recombining Inputs (Exercise 1: An Alternative Packrat)](Parser.ipynb#Exercise-1:-An-Alternative-Packrat)
# * universal grammars &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)
# * `UNRESOLVED` &mdash; [Fuzzing: Breaking Things with Random Inputs (Runner Classes)](Fuzzer.ipynb#Runner-Classes)
# * `untaint()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `update_cache()` &mdash; [Parsing and Recombining Inputs (We need some infrastructure first for viewing the grammar.)](Parser.ipynb#We-need-some-infrastructure-first-for-viewing-the-grammar.)
# * `upper()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `URLPARSE_C_GRAMMAR` &mdash; [Fuzzing APIs (Synthesizing Code)](APIFuzzer.ipynb#Synthesizing-Code)
# * `URLPARSE_GRAMMAR` &mdash; [Fuzzing APIs (Synthesizing Code)](APIFuzzer.ipynb#Synthesizing-Code)
# * `URL_GRAMMAR` &mdash; [Fuzzing with Grammars (A URL Grammar)](Grammars.ipynb#A-URL-Grammar)

# %% [markdown]
# ## V-X

# %% [markdown]
# ### V
#
# * `VARIABLE` &mdash; [Getting Coverage (A Coverage Class)](Coverage.ipynb#A-Coverage-Class)
# * `VAR_GRAMMAR` &mdash; [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer)
# * `var_symbol()` &mdash; [Fuzzing APIs (A Grammar from Arguments)](APIFuzzer.ipynb#A-Grammar-from-Arguments)
# * `VAR_TOKENS` &mdash; [Parsing and Recombining Inputs (A Grammar-based Mutational Fuzzer)](Parser.ipynb#A-Grammar-based-Mutational-Fuzzer)

# %% [markdown]
# ### W
#
# * `webbrowser()` &mdash; [Carving Unit Tests (System Tests vs Unit Tests)](Carver.ipynb#System-Tests-vs-Unit-Tests)
# * white-box testing &mdash; [Getting Coverage (White-Box Testing)](Coverage.ipynb#White-Box-Testing)
# * Wikipedia page on file formats &mdash; [Fuzzing with Grammars (Input Languages)](Grammars.ipynb#Input-Languages)

# %% [markdown]
# ### X
#
# * `x()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * `_x()` &mdash; [Information Flow (A Simple Taint Tracker)](InformationFlow.ipynb#A-Simple-Taint-Tracker)
# * XKCD comic &mdash; [Fuzzing: Breaking Things with Random Inputs (Checking Memory Accesses)](Fuzzer.ipynb#Checking-Memory-Accesses)
